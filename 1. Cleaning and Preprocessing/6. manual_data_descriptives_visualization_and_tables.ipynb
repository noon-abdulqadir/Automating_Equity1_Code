# %% [markdown]
# # ATTN: This script should be run AFTER all embeddings are completed.

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_FOR_TRAINNING
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %% [markdown]
# # Descriptives and visualization

# %%
import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

mod = sys.modules[__name__]

code_dir = None
code_dir_name = 'Code'
unwanted_subdir_name = 'Analysis'

for _ in range(5):

    parent_path = str(Path.cwd().parents[_]).split('/')[-1]

    if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

        code_dir = str(Path.cwd().parents[_])

        if code_dir is not None:
            break

sys.path.append(code_dir)
# %load_ext autoreload
# %autoreload 2

# %%
from setup_module.imports import * # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# Out:
# Using MPS
# 0it [00:00, ?it/s]

# %%
def get_df_info(df, ivs_all=None):
    if ivs_all is None:
        ivs_all = [
            'Gender',
            'Gender_Num',
            'Gender_Female',
            'Gender_Mixed',
            'Gender_Male',
            'Gender_Female_n',
            'Gender_Male_n',
            'Gender_Female_% per Sector',
            'Gender_Male_% per Sector',
            'Age',
            'Age_Num',
            'Age_Older',
            'Age_Mixed',
            'Age_Younger',
            'Age_Older_n',
            'Age_Younger_n',
            'Age_Older_% per Sector',
            'Age_Younger_% per Sector',
        ]
    # Print Info
    print('\nDF INFO:\n')
    df.info()

    for iv in ivs_all:
        try:
            print('='*20)
            print(f'{iv}:')
            print('-'*20)
            if len(df[iv].value_counts()) < 5:
                print(f'{iv} Counts:\n{df[iv].value_counts()}')
                print('-'*20)
                print(f'{iv} Percentages:\n{df[iv].value_counts(normalize=True).mul(100).round(1).astype(float)}')
                print('-'*20)
            print(f'Min {iv} value: {df[iv].min()}')
            print(f'Max {iv} value: {df[iv].max()}')
            with contextlib.suppress(Exception):
                print('-'*20)
                print(f'{iv} Mean: {df[iv].mean().round(2).astype(float)}')
                print('-'*20)
                print(f'{iv} Standard Deviation: {df[iv].std().round(2).astype(float)}')
        except Exception:
            print(f'{iv} not available.')

    print('\n')

# %%
# Function to order categories
def categorize_df_gender_age(df, gender_order=None, age_order=None, ivs=None):
    if gender_order is None:
        gender_order = ['Female', 'Mixed Gender', 'Male']
    if age_order is None:
        age_order = ['Older', 'Mixed Age', 'Younger']
    if ivs is None:
        ivs = ['Gender', 'Age']
    # Arrange Categories
    for iv in ivs:
        if iv == 'Gender':
            order = gender_order
        elif iv == 'Age':
            order = age_order
        with contextlib.suppress(ValueError):
            df[iv] = df[iv].astype('category').cat.reorder_categories(order, ordered=True)

            df[iv] = pd.Categorical(
                df[iv], categories=order, ordered=True
            )
            df[f'{iv}_Num'] = pd.to_numeric(df[iv].cat.codes).astype('int64')

    return df

# %%
def make_barplot(df, iv, dvs_list):
    fig, ax = plt.subplots()
    fig.suptitle(f'Training Dataset: Warmth and Competence Sentence Percentages per {iv}')

    vars_list = [iv]
    vars_list.extend(dvs_list)

    df_pivot = df[
        vars_list
    ].pivot_table(
        index=iv, values=dvs_list, fill_value=0, aggfunc=lambda x: (100*x.sum())/len(df)
    )

    df_pivot.sort_values(by=iv, ascending=False).plot(kind='barh', legend=True, stacked=True, ax=ax, color=['C0', 'C5'])

    for _ in ax.containers:
        ax.set_xlabel('% Job Ad Sentences')
        ax.set_ylabel(iv)

    for image_save_format in ['eps', 'png', 'svg']:
        fig.savefig(
            f'{plot_save_path}Barplot - Manually Annotated {iv} x {dvs_list[0]} and {dvs_list[1]} Sentences.{image_save_format}',
            format=image_save_format, dpi=3000, bbox_inches='tight'
        )

# %%
with open(f'{data_dir}df_manual_len.txt', 'r') as f:
    df_manual_len = int(f.read())

df_manual = pd.read_pickle(f'{df_save_dir}df_manual_for_trainning.pkl')
assert len(df_manual) == df_manual_len, f'DATAFRAME MISSING DATA! DF SHOULD BE OF LENGTH {df_manual_len} BUT IS OF LENGTH {len(df_manual)}'
print(f'Dataframe loaded with shape: {df_manual.shape}')
# Out:
# Dataframe loaded with shape: (5978, 58)

# %%
# All info
analysis_columns = [
    'Warmth',
    'Competence'
]

df_manual = categorize_df_gender_age(df_manual)

df_manual.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5978 entries, 0 to 5977
# Data columns (total 58 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Job ID                                            5978 non-null   object
#  1   Job Description spacy_sentencized                 5978 non-null   object
#  2   Warmth                                            5978 non-null   int64
#  3   Competence                                        5978 non-null   int64
#  4   Dutch Requirement                                 5978 non-null   object
#  5   English Requirement                               5978 non-null   object
#  6   Search Keyword                                    5978 non-null   object
#  7   Platform                                          5978 non-null   object
#  8   Job Title                                         5978 non-null   object
#  9   Company Name                                      5978 non-null   object
#  10  Location                                          5978 non-null   object
#  11  Industry                                          291 non-null    object
#  12  Sector Code                                       5978 non-null   object
#  13  Sector                                            5978 non-null   object
#  14  Keywords Count                                    5978 non-null   float64
#  15  Gender_Female_n                                   5978 non-null   float64
#  16  Gender_Female_% per Sector                        5978 non-null   float64
#  17  Gender_Female_% per Social Category               5978 non-null   float64
#  18  Gender_Female_% per Workforce                     5978 non-null   float64
#  19  Gender_Male_n                                     5978 non-null   float64
#  20  Gender_Male_% per Sector                          5978 non-null   float64
#  21  Gender_Male_% per Social Category                 5978 non-null   float64
#  22  Gender_Male_% per Workforce                       5978 non-null   float64
#  23  Gender                                            5978 non-null   category
#  24  Age_Older_n                                       5978 non-null   float64
#  25  Age_Older_% per Sector                            5978 non-null   float64
#  26  Age_Older_% per Social Category                   5978 non-null   float64
#  27  Age_Older_% per Workforce                         5978 non-null   float64
#  28  Age_Younger_n                                     5978 non-null   float64
#  29  Age_Younger_% per Sector                          5978 non-null   float64
#  30  Age_Younger_% per Social Category                 5978 non-null   float64
#  31  Age_Younger_% per Workforce                       5978 non-null   float64
#  32  Age                                               5978 non-null   category
#  33  Sector_n                                          5978 non-null   float64
#  34  % Sector per Workforce                            5978 non-null   float64
#  35  Gender_Female                                     5978 non-null   int64
#  36  Gender_Male                                       5978 non-null   int64
#  37  Gender_Mixed                                      5978 non-null   int64
#  38  Age_Mixed                                         5978 non-null   int64
#  39  Age_Older                                         5978 non-null   int64
#  40  Age_Younger                                       5978 non-null   int64
#  41  Gender_Num                                        5978 non-null   int64
#  42  Age_Num                                           5978 non-null   int64
#  43  Platform_Num                                      5978 non-null   int64
#  44  Platform_LinkedIn                                 5978 non-null   int64
#  45  Platform_Indeed                                   5978 non-null   int64
#  46  Platform_Glassdoor                                5978 non-null   int64
#  47  Job Description spacy_sentencized_lower           5978 non-null   object
#  48  Job Description spacy_tokenized                   5978 non-null   object
#  49  Job Description spacy_sentencized_cleaned         5978 non-null   object
#  50  Job Description num_words                         5978 non-null   int64
#  51  Job Description num_unique_words                  5978 non-null   int64
#  52  Job Description num_chars                         5978 non-null   int64
#  53  Job Description num_chars_no_whitespact_and_punt  5978 non-null   int64
#  54  Job Description num_punctuations                  5978 non-null   int64
#  55  Job Description nltk_tokenized                    5978 non-null   object
#  56  Job Description gensim_tokenized                  5978 non-null   object
#  57  Job Description bert_tokenized                    5978 non-null   object
# dtypes: category(2), float64(19), int64(19), object(18)
# memory usage: 2.6+ MB

# %%
# Gender and Age info by sentence
print('='*30)
print('Gender and Age info at Sentence Level')
print('-'*30)
get_df_info(df_manual, ivs_all=ivs_all)
# Out:
# ==============================
# Gender and Age info at Sentence Level
# ------------------------------
#
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5978 entries, 0 to 5977
# Data columns (total 58 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Job ID                                            5978 non-null   object
#  1   Job Description spacy_sentencized                 5978 non-null   object
#  2   Warmth                                            5978 non-null   int64
#  3   Competence                                        5978 non-null   int64
#  4   Dutch Requirement                                 5978 non-null   object
#  5   English Requirement                               5978 non-null   object
#  6   Search Keyword                                    5978 non-null   object
#  7   Platform                                          5978 non-null   object
#  8   Job Title                                         5978 non-null   object
#  9   Company Name                                      5978 non-null   object
#  10  Location                                          5978 non-null   object
#  11  Industry                                          291 non-null    object
#  12  Sector Code                                       5978 non-null   object
#  13  Sector                                            5978 non-null   object
#  14  Keywords Count                                    5978 non-null   float64
#  15  Gender_Female_n                                   5978 non-null   float64
#  16  Gender_Female_% per Sector                        5978 non-null   float64
#  17  Gender_Female_% per Social Category               5978 non-null   float64
#  18  Gender_Female_% per Workforce                     5978 non-null   float64
#  19  Gender_Male_n                                     5978 non-null   float64
#  20  Gender_Male_% per Sector                          5978 non-null   float64
#  21  Gender_Male_% per Social Category                 5978 non-null   float64
#  22  Gender_Male_% per Workforce                       5978 non-null   float64
#  23  Gender                                            5978 non-null   category
#  24  Age_Older_n                                       5978 non-null   float64
#  25  Age_Older_% per Sector                            5978 non-null   float64
#  26  Age_Older_% per Social Category                   5978 non-null   float64
#  27  Age_Older_% per Workforce                         5978 non-null   float64
#  28  Age_Younger_n                                     5978 non-null   float64
#  29  Age_Younger_% per Sector                          5978 non-null   float64
#  30  Age_Younger_% per Social Category                 5978 non-null   float64
#  31  Age_Younger_% per Workforce                       5978 non-null   float64
#  32  Age                                               5978 non-null   category
#  33  Sector_n                                          5978 non-null   float64
#  34  % Sector per Workforce                            5978 non-null   float64
#  35  Gender_Female                                     5978 non-null   int64
#  36  Gender_Male                                       5978 non-null   int64
#  37  Gender_Mixed                                      5978 non-null   int64
#  38  Age_Mixed                                         5978 non-null   int64
#  39  Age_Older                                         5978 non-null   int64
#  40  Age_Younger                                       5978 non-null   int64
#  41  Gender_Num                                        5978 non-null   int64
#  42  Age_Num                                           5978 non-null   int64
#  43  Platform_Num                                      5978 non-null   int64
#  44  Platform_LinkedIn                                 5978 non-null   int64
#  45  Platform_Indeed                                   5978 non-null   int64
#  46  Platform_Glassdoor                                5978 non-null   int64
#  47  Job Description spacy_sentencized_lower           5978 non-null   object
#  48  Job Description spacy_tokenized                   5978 non-null   object
#  49  Job Description spacy_sentencized_cleaned         5978 non-null   object
#  50  Job Description num_words                         5978 non-null   int64
#  51  Job Description num_unique_words                  5978 non-null   int64
#  52  Job Description num_chars                         5978 non-null   int64
#  53  Job Description num_chars_no_whitespact_and_punt  5978 non-null   int64
#  54  Job Description num_punctuations                  5978 non-null   int64
#  55  Job Description nltk_tokenized                    5978 non-null   object
#  56  Job Description gensim_tokenized                  5978 non-null   object
#  57  Job Description bert_tokenized                    5978 non-null   object
# dtypes: category(2), float64(19), int64(19), object(18)
# memory usage: 2.6+ MB
# ====================
# Gender:
# --------------------
# Gender Counts:
# Mixed Gender    3855
# Male            1152
# Female           971
# Name: Gender, dtype: int64
# --------------------
# Gender Percentages:
# Mixed Gender   64.50
# Male           19.30
# Female         16.20
# Name: Gender, dtype: float64
# --------------------
# Min Gender value: Female
# Max Gender value: Male
# --------------------
# ====================
# Gender_Num:
# --------------------
# Gender_Num Counts:
# 1    3855
# 2    1152
# 0     971
# Name: Gender_Num, dtype: int64
# --------------------
# Gender_Num Percentages:
# 1   64.50
# 2   19.30
# 0   16.20
# Name: Gender_Num, dtype: float64
# --------------------
# Min Gender_Num value: 0
# Max Gender_Num value: 2
# --------------------
# Gender_Num Mean: 1.03
# --------------------
# Gender_Num Standard Deviation: 0.6
# ====================
# Gender_Female:
# --------------------
# Gender_Female Counts:
# 0    5007
# 1     971
# Name: Gender_Female, dtype: int64
# --------------------
# Gender_Female Percentages:
# 0   83.80
# 1   16.20
# Name: Gender_Female, dtype: float64
# --------------------
# Min Gender_Female value: 0
# Max Gender_Female value: 1
# --------------------
# Gender_Female Mean: 0.16
# --------------------
# Gender_Female Standard Deviation: 0.37
# ====================
# Gender_Mixed:
# --------------------
# Gender_Mixed Counts:
# 1    3855
# 0    2123
# Name: Gender_Mixed, dtype: int64
# --------------------
# Gender_Mixed Percentages:
# 1   64.50
# 0   35.50
# Name: Gender_Mixed, dtype: float64
# --------------------
# Min Gender_Mixed value: 0
# Max Gender_Mixed value: 1
# --------------------
# Gender_Mixed Mean: 0.64
# --------------------
# Gender_Mixed Standard Deviation: 0.48
# ====================
# Gender_Male:
# --------------------
# Gender_Male Counts:
# 0    4826
# 1    1152
# Name: Gender_Male, dtype: int64
# --------------------
# Gender_Male Percentages:
# 0   80.70
# 1   19.30
# Name: Gender_Male, dtype: float64
# --------------------
# Min Gender_Male value: 0
# Max Gender_Male value: 1
# --------------------
# Gender_Male Mean: 0.19
# --------------------
# Gender_Male Standard Deviation: 0.39
# ====================
# Gender_Female_n:
# --------------------
# Min Gender_Female_n value: 7.0
# Max Gender_Female_n value: 3970.0
# --------------------
# Gender_Female_n Mean: 554.42
# --------------------
# Gender_Female_n Standard Deviation: 756.03
# ====================
# Gender_Male_n:
# --------------------
# Min Gender_Male_n value: 21.0
# Max Gender_Male_n value: 4510.0
# --------------------
# Gender_Male_n Mean: 580.59
# --------------------
# Gender_Male_n Standard Deviation: 685.99
# ====================
# Gender_Female_% per Sector:
# --------------------
# Min Gender_Female_% per Sector value: 19.444444444444446
# Max Gender_Female_% per Sector value: 84.2986741102582
# --------------------
# Gender_Female_% per Sector Mean: 45.19
# --------------------
# Gender_Female_% per Sector Standard Deviation: 15.89
# ====================
# Gender_Male_% per Sector:
# --------------------
# Min Gender_Male_% per Sector value: 15.631542219120725
# Max Gender_Male_% per Sector value: 80.55555555555556
# --------------------
# Gender_Male_% per Sector Mean: 54.79
# --------------------
# Gender_Male_% per Sector Standard Deviation: 15.91
# ====================
# Age:
# --------------------
# Age Counts:
# Younger      3237
# Mixed Age    2059
# Older         682
# Name: Age, dtype: int64
# --------------------
# Age Percentages:
# Younger     54.10
# Mixed Age   34.40
# Older       11.40
# Name: Age, dtype: float64
# --------------------
# Min Age value: Older
# Max Age value: Younger
# --------------------
# ====================
# Age_Num:
# --------------------
# Age_Num Counts:
# 2    3237
# 1    2059
# 0     682
# Name: Age_Num, dtype: int64
# --------------------
# Age_Num Percentages:
# 2   54.10
# 1   34.40
# 0   11.40
# Name: Age_Num, dtype: float64
# --------------------
# Min Age_Num value: 0
# Max Age_Num value: 2
# --------------------
# Age_Num Mean: 1.43
# --------------------
# Age_Num Standard Deviation: 0.69
# ====================
# Age_Older:
# --------------------
# Age_Older Counts:
# 0    5296
# 1     682
# Name: Age_Older, dtype: int64
# --------------------
# Age_Older Percentages:
# 0   88.60
# 1   11.40
# Name: Age_Older, dtype: float64
# --------------------
# Min Age_Older value: 0
# Max Age_Older value: 1
# --------------------
# Age_Older Mean: 0.11
# --------------------
# Age_Older Standard Deviation: 0.32
# ====================
# Age_Mixed:
# --------------------
# Age_Mixed Counts:
# 0    3919
# 1    2059
# Name: Age_Mixed, dtype: int64
# --------------------
# Age_Mixed Percentages:
# 0   65.60
# 1   34.40
# Name: Age_Mixed, dtype: float64
# --------------------
# Min Age_Mixed value: 0
# Max Age_Mixed value: 1
# --------------------
# Age_Mixed Mean: 0.34
# --------------------
# Age_Mixed Standard Deviation: 0.48
# ====================
# Age_Younger:
# --------------------
# Age_Younger Counts:
# 1    3237
# 0    2741
# Name: Age_Younger, dtype: int64
# --------------------
# Age_Younger Percentages:
# 1   54.10
# 0   45.90
# Name: Age_Younger, dtype: float64
# --------------------
# Min Age_Younger value: 0
# Max Age_Younger value: 1
# --------------------
# Age_Younger Mean: 0.54
# --------------------
# Age_Younger Standard Deviation: 0.5
# ====================
# Age_Older_n:
# --------------------
# Min Age_Older_n value: 15.0
# Max Age_Older_n value: 2844.0
# --------------------
# Age_Older_n Mean: 435.57
# --------------------
# Age_Older_n Standard Deviation: 554.23
# ====================
# Age_Younger_n:
# --------------------
# Min Age_Younger_n value: 13.0
# Max Age_Younger_n value: 5228.0
# --------------------
# Age_Younger_n Mean: 698.14
# --------------------
# Age_Younger_n Standard Deviation: 816.35
# ====================
# Age_Older_% per Sector:
# --------------------
# Min Age_Older_% per Sector value: 18.939393939393938
# Max Age_Older_% per Sector value: 58.333333333333336
# --------------------
# Age_Older_% per Sector Mean: 38.13
# --------------------
# Age_Older_% per Sector Standard Deviation: 8.74
# ====================
# Age_Younger_% per Sector:
# --------------------
# Min Age_Younger_% per Sector value: 44.44444444444444
# Max Age_Younger_% per Sector value: 80.8080808080808
# --------------------
# Age_Younger_% per Sector Mean: 61.62
# --------------------
# Age_Younger_% per Sector Standard Deviation: 8.82

# %%
# Gender and Age info by job ad
print('='*30)
print('Gender and Age info at Job Advertisement Level')
print('-'*30)
get_df_info(df_manual.groupby(['Job ID']).first(), ivs_all=ivs_all)
# Out:
# ==============================
# Gender and Age info at Job Advertisement Level
# ------------------------------
#
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 117 entries, 3768944208 to pj_a4ac3e531abef752
# Data columns (total 57 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Job Description spacy_sentencized                 117 non-null    object
#  1   Warmth                                            117 non-null    int64
#  2   Competence                                        117 non-null    int64
#  3   Dutch Requirement                                 117 non-null    object
#  4   English Requirement                               117 non-null    object
#  5   Search Keyword                                    117 non-null    object
#  6   Platform                                          117 non-null    object
#  7   Job Title                                         117 non-null    object
#  8   Company Name                                      117 non-null    object
#  9   Location                                          117 non-null    object
#  10  Industry                                          5 non-null      object
#  11  Sector Code                                       117 non-null    object
#  12  Sector                                            117 non-null    object
#  13  Keywords Count                                    117 non-null    float64
#  14  Gender_Female_n                                   117 non-null    float64
#  15  Gender_Female_% per Sector                        117 non-null    float64
#  16  Gender_Female_% per Social Category               117 non-null    float64
#  17  Gender_Female_% per Workforce                     117 non-null    float64
#  18  Gender_Male_n                                     117 non-null    float64
#  19  Gender_Male_% per Sector                          117 non-null    float64
#  20  Gender_Male_% per Social Category                 117 non-null    float64
#  21  Gender_Male_% per Workforce                       117 non-null    float64
#  22  Gender                                            117 non-null    category
#  23  Age_Older_n                                       117 non-null    float64
#  24  Age_Older_% per Sector                            117 non-null    float64
#  25  Age_Older_% per Social Category                   117 non-null    float64
#  26  Age_Older_% per Workforce                         117 non-null    float64
#  27  Age_Younger_n                                     117 non-null    float64
#  28  Age_Younger_% per Sector                          117 non-null    float64
#  29  Age_Younger_% per Social Category                 117 non-null    float64
#  30  Age_Younger_% per Workforce                       117 non-null    float64
#  31  Age                                               117 non-null    category
#  32  Sector_n                                          117 non-null    float64
#  33  % Sector per Workforce                            117 non-null    float64
#  34  Gender_Female                                     117 non-null    int64
#  35  Gender_Male                                       117 non-null    int64
#  36  Gender_Mixed                                      117 non-null    int64
#  37  Age_Mixed                                         117 non-null    int64
#  38  Age_Older                                         117 non-null    int64
#  39  Age_Younger                                       117 non-null    int64
#  40  Gender_Num                                        117 non-null    int64
#  41  Age_Num                                           117 non-null    int64
#  42  Platform_Num                                      117 non-null    int64
#  43  Platform_LinkedIn                                 117 non-null    int64
#  44  Platform_Indeed                                   117 non-null    int64
#  45  Platform_Glassdoor                                117 non-null    int64
#  46  Job Description spacy_sentencized_lower           117 non-null    object
#  47  Job Description spacy_tokenized                   117 non-null    object
#  48  Job Description spacy_sentencized_cleaned         117 non-null    object
#  49  Job Description num_words                         117 non-null    int64
#  50  Job Description num_unique_words                  117 non-null    int64
#  51  Job Description num_chars                         117 non-null    int64
#  52  Job Description num_chars_no_whitespact_and_punt  117 non-null    int64
#  53  Job Description num_punctuations                  117 non-null    int64
#  54  Job Description nltk_tokenized                    117 non-null    object
#  55  Job Description gensim_tokenized                  117 non-null    object
#  56  Job Description bert_tokenized                    117 non-null    object
# dtypes: category(2), float64(19), int64(19), object(17)
# memory usage: 51.7+ KB
# ====================
# Gender:
# --------------------
# Gender Counts:
# Mixed Gender    72
# Male            27
# Female          18
# Name: Gender, dtype: int64
# --------------------
# Gender Percentages:
# Mixed Gender   61.50
# Male           23.10
# Female         15.40
# Name: Gender, dtype: float64
# --------------------
# Min Gender value: Female
# Max Gender value: Male
# --------------------
# ====================
# Gender_Num:
# --------------------
# Gender_Num Counts:
# 1    72
# 2    27
# 0    18
# Name: Gender_Num, dtype: int64
# --------------------
# Gender_Num Percentages:
# 1   61.50
# 2   23.10
# 0   15.40
# Name: Gender_Num, dtype: float64
# --------------------
# Min Gender_Num value: 0
# Max Gender_Num value: 2
# --------------------
# Gender_Num Mean: 1.08
# --------------------
# Gender_Num Standard Deviation: 0.62
# ====================
# Gender_Female:
# --------------------
# Gender_Female Counts:
# 0    99
# 1    18
# Name: Gender_Female, dtype: int64
# --------------------
# Gender_Female Percentages:
# 0   84.60
# 1   15.40
# Name: Gender_Female, dtype: float64
# --------------------
# Min Gender_Female value: 0
# Max Gender_Female value: 1
# --------------------
# Gender_Female Mean: 0.15
# --------------------
# Gender_Female Standard Deviation: 0.36
# ====================
# Gender_Mixed:
# --------------------
# Gender_Mixed Counts:
# 1    72
# 0    45
# Name: Gender_Mixed, dtype: int64
# --------------------
# Gender_Mixed Percentages:
# 1   61.50
# 0   38.50
# Name: Gender_Mixed, dtype: float64
# --------------------
# Min Gender_Mixed value: 0
# Max Gender_Mixed value: 1
# --------------------
# Gender_Mixed Mean: 0.62
# --------------------
# Gender_Mixed Standard Deviation: 0.49
# ====================
# Gender_Male:
# --------------------
# Gender_Male Counts:
# 0    90
# 1    27
# Name: Gender_Male, dtype: int64
# --------------------
# Gender_Male Percentages:
# 0   76.90
# 1   23.10
# Name: Gender_Male, dtype: float64
# --------------------
# Min Gender_Male value: 0
# Max Gender_Male value: 1
# --------------------
# Gender_Male Mean: 0.23
# --------------------
# Gender_Male Standard Deviation: 0.42
# ====================
# Gender_Female_n:
# --------------------
# Min Gender_Female_n value: 7.0
# Max Gender_Female_n value: 3970.0
# --------------------
# Gender_Female_n Mean: 555.51
# --------------------
# Gender_Female_n Standard Deviation: 785.27
# ====================
# Gender_Male_n:
# --------------------
# Min Gender_Male_n value: 21.0
# Max Gender_Male_n value: 4510.0
# --------------------
# Gender_Male_n Mean: 586.63
# --------------------
# Gender_Male_n Standard Deviation: 728.09
# ====================
# Gender_Female_% per Sector:
# --------------------
# Min Gender_Female_% per Sector value: 19.444444444444446
# Max Gender_Female_% per Sector value: 84.2986741102582
# --------------------
# Gender_Female_% per Sector Mean: 44.39
# --------------------
# Gender_Female_% per Sector Standard Deviation: 16.17
# ====================
# Gender_Male_% per Sector:
# --------------------
# Min Gender_Male_% per Sector value: 15.631542219120725
# Max Gender_Male_% per Sector value: 80.55555555555556
# --------------------
# Gender_Male_% per Sector Mean: 55.59
# --------------------
# Gender_Male_% per Sector Standard Deviation: 16.19
# ====================
# Age:
# --------------------
# Age Counts:
# Younger      60
# Mixed Age    42
# Older        15
# Name: Age, dtype: int64
# --------------------
# Age Percentages:
# Younger     51.30
# Mixed Age   35.90
# Older       12.80
# Name: Age, dtype: float64
# --------------------
# Min Age value: Older
# Max Age value: Younger
# --------------------
# ====================
# Age_Num:
# --------------------
# Age_Num Counts:
# 2    60
# 1    42
# 0    15
# Name: Age_Num, dtype: int64
# --------------------
# Age_Num Percentages:
# 2   51.30
# 1   35.90
# 0   12.80
# Name: Age_Num, dtype: float64
# --------------------
# Min Age_Num value: 0
# Max Age_Num value: 2
# --------------------
# Age_Num Mean: 1.38
# --------------------
# Age_Num Standard Deviation: 0.71
# ====================
# Age_Older:
# --------------------
# Age_Older Counts:
# 0    102
# 1     15
# Name: Age_Older, dtype: int64
# --------------------
# Age_Older Percentages:
# 0   87.20
# 1   12.80
# Name: Age_Older, dtype: float64
# --------------------
# Min Age_Older value: 0
# Max Age_Older value: 1
# --------------------
# Age_Older Mean: 0.13
# --------------------
# Age_Older Standard Deviation: 0.34
# ====================
# Age_Mixed:
# --------------------
# Age_Mixed Counts:
# 0    75
# 1    42
# Name: Age_Mixed, dtype: int64
# --------------------
# Age_Mixed Percentages:
# 0   64.10
# 1   35.90
# Name: Age_Mixed, dtype: float64
# --------------------
# Min Age_Mixed value: 0
# Max Age_Mixed value: 1
# --------------------
# Age_Mixed Mean: 0.36
# --------------------
# Age_Mixed Standard Deviation: 0.48
# ====================
# Age_Younger:
# --------------------
# Age_Younger Counts:
# 1    60
# 0    57
# Name: Age_Younger, dtype: int64
# --------------------
# Age_Younger Percentages:
# 1   51.30
# 0   48.70
# Name: Age_Younger, dtype: float64
# --------------------
# Min Age_Younger value: 0
# Max Age_Younger value: 1
# --------------------
# Age_Younger Mean: 0.51
# --------------------
# Age_Younger Standard Deviation: 0.5
# ====================
# Age_Older_n:
# --------------------
# Min Age_Older_n value: 15.0
# Max Age_Older_n value: 2844.0
# --------------------
# Age_Older_n Mean: 440.05
# --------------------
# Age_Older_n Standard Deviation: 576.53
# ====================
# Age_Younger_n:
# --------------------
# Min Age_Younger_n value: 13.0
# Max Age_Younger_n value: 5228.0
# --------------------
# Age_Younger_n Mean: 700.86
# --------------------
# Age_Younger_n Standard Deviation: 868.11
# ====================
# Age_Older_% per Sector:
# --------------------
# Min Age_Older_% per Sector value: 18.939393939393938
# Max Age_Older_% per Sector value: 58.333333333333336
# --------------------
# Age_Older_% per Sector Mean: 38.68
# --------------------
# Age_Older_% per Sector Standard Deviation: 9.05
# ====================
# Age_Younger_% per Sector:
# --------------------
# Min Age_Younger_% per Sector value: 44.44444444444444
# Max Age_Younger_% per Sector value: 80.8080808080808
# --------------------
# Age_Younger_% per Sector Mean: 61.05
# --------------------
# Age_Younger_% per Sector Standard Deviation: 9.18

# %%
# Warmth and Competence percentages info by sentence
print('='*30)
print('Warmth and Competence info at Sentence Level')
print('-'*30)
get_df_info(df_manual, ivs_all=dvs)
# Out:
# ==============================
# Warmth and Competence info at Sentence Level
# ------------------------------
#
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5978 entries, 0 to 5977
# Data columns (total 58 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Job ID                                            5978 non-null   object
#  1   Job Description spacy_sentencized                 5978 non-null   object
#  2   Warmth                                            5978 non-null   int64
#  3   Competence                                        5978 non-null   int64
#  4   Dutch Requirement                                 5978 non-null   object
#  5   English Requirement                               5978 non-null   object
#  6   Search Keyword                                    5978 non-null   object
#  7   Platform                                          5978 non-null   object
#  8   Job Title                                         5978 non-null   object
#  9   Company Name                                      5978 non-null   object
#  10  Location                                          5978 non-null   object
#  11  Industry                                          291 non-null    object
#  12  Sector Code                                       5978 non-null   object
#  13  Sector                                            5978 non-null   object
#  14  Keywords Count                                    5978 non-null   float64
#  15  Gender_Female_n                                   5978 non-null   float64
#  16  Gender_Female_% per Sector                        5978 non-null   float64
#  17  Gender_Female_% per Social Category               5978 non-null   float64
#  18  Gender_Female_% per Workforce                     5978 non-null   float64
#  19  Gender_Male_n                                     5978 non-null   float64
#  20  Gender_Male_% per Sector                          5978 non-null   float64
#  21  Gender_Male_% per Social Category                 5978 non-null   float64
#  22  Gender_Male_% per Workforce                       5978 non-null   float64
#  23  Gender                                            5978 non-null   category
#  24  Age_Older_n                                       5978 non-null   float64
#  25  Age_Older_% per Sector                            5978 non-null   float64
#  26  Age_Older_% per Social Category                   5978 non-null   float64
#  27  Age_Older_% per Workforce                         5978 non-null   float64
#  28  Age_Younger_n                                     5978 non-null   float64
#  29  Age_Younger_% per Sector                          5978 non-null   float64
#  30  Age_Younger_% per Social Category                 5978 non-null   float64
#  31  Age_Younger_% per Workforce                       5978 non-null   float64
#  32  Age                                               5978 non-null   category
#  33  Sector_n                                          5978 non-null   float64
#  34  % Sector per Workforce                            5978 non-null   float64
#  35  Gender_Female                                     5978 non-null   int64
#  36  Gender_Male                                       5978 non-null   int64
#  37  Gender_Mixed                                      5978 non-null   int64
#  38  Age_Mixed                                         5978 non-null   int64
#  39  Age_Older                                         5978 non-null   int64
#  40  Age_Younger                                       5978 non-null   int64
#  41  Gender_Num                                        5978 non-null   int64
#  42  Age_Num                                           5978 non-null   int64
#  43  Platform_Num                                      5978 non-null   int64
#  44  Platform_LinkedIn                                 5978 non-null   int64
#  45  Platform_Indeed                                   5978 non-null   int64
#  46  Platform_Glassdoor                                5978 non-null   int64
#  47  Job Description spacy_sentencized_lower           5978 non-null   object
#  48  Job Description spacy_tokenized                   5978 non-null   object
#  49  Job Description spacy_sentencized_cleaned         5978 non-null   object
#  50  Job Description num_words                         5978 non-null   int64
#  51  Job Description num_unique_words                  5978 non-null   int64
#  52  Job Description num_chars                         5978 non-null   int64
#  53  Job Description num_chars_no_whitespact_and_punt  5978 non-null   int64
#  54  Job Description num_punctuations                  5978 non-null   int64
#  55  Job Description nltk_tokenized                    5978 non-null   object
#  56  Job Description gensim_tokenized                  5978 non-null   object
#  57  Job Description bert_tokenized                    5978 non-null   object
# dtypes: category(2), float64(19), int64(19), object(18)
# memory usage: 2.6+ MB
# ====================
# Warmth:
# --------------------
# Warmth Counts:
# 0    4477
# 1    1501
# Name: Warmth, dtype: int64
# --------------------
# Warmth Percentages:
# 0   74.90
# 1   25.10
# Name: Warmth, dtype: float64
# --------------------
# Min Warmth value: 0
# Max Warmth value: 1
# --------------------
# Warmth Mean: 0.25
# --------------------
# Warmth Standard Deviation: 0.43
# ====================
# Competence:
# --------------------
# Competence Counts:
# 0    3344
# 1    2634
# Name: Competence, dtype: int64
# --------------------
# Competence Percentages:
# 0   55.90
# 1   44.10
# Name: Competence, dtype: float64
# --------------------
# Min Competence value: 0
# Max Competence value: 1
# --------------------
# Competence Mean: 0.44
# --------------------
# Competence Standard Deviation: 0.5

# %%
# Warmth and Competence info by job ad
print('='*30)
print('Warmth and Competence info at Job Advertisement Level')
print('-'*30)
get_df_info(df_manual.groupby(['Job ID']).first(), ivs_all=ivs_all)
# Out:
# ==============================
# Warmth and Competence info at Job Advertisement Level
# ------------------------------
#
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 117 entries, 3768944208 to pj_a4ac3e531abef752
# Data columns (total 57 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Job Description spacy_sentencized                 117 non-null    object
#  1   Warmth                                            117 non-null    int64
#  2   Competence                                        117 non-null    int64
#  3   Dutch Requirement                                 117 non-null    object
#  4   English Requirement                               117 non-null    object
#  5   Search Keyword                                    117 non-null    object
#  6   Platform                                          117 non-null    object
#  7   Job Title                                         117 non-null    object
#  8   Company Name                                      117 non-null    object
#  9   Location                                          117 non-null    object
#  10  Industry                                          5 non-null      object
#  11  Sector Code                                       117 non-null    object
#  12  Sector                                            117 non-null    object
#  13  Keywords Count                                    117 non-null    float64
#  14  Gender_Female_n                                   117 non-null    float64
#  15  Gender_Female_% per Sector                        117 non-null    float64
#  16  Gender_Female_% per Social Category               117 non-null    float64
#  17  Gender_Female_% per Workforce                     117 non-null    float64
#  18  Gender_Male_n                                     117 non-null    float64
#  19  Gender_Male_% per Sector                          117 non-null    float64
#  20  Gender_Male_% per Social Category                 117 non-null    float64
#  21  Gender_Male_% per Workforce                       117 non-null    float64
#  22  Gender                                            117 non-null    category
#  23  Age_Older_n                                       117 non-null    float64
#  24  Age_Older_% per Sector                            117 non-null    float64
#  25  Age_Older_% per Social Category                   117 non-null    float64
#  26  Age_Older_% per Workforce                         117 non-null    float64
#  27  Age_Younger_n                                     117 non-null    float64
#  28  Age_Younger_% per Sector                          117 non-null    float64
#  29  Age_Younger_% per Social Category                 117 non-null    float64
#  30  Age_Younger_% per Workforce                       117 non-null    float64
#  31  Age                                               117 non-null    category
#  32  Sector_n                                          117 non-null    float64
#  33  % Sector per Workforce                            117 non-null    float64
#  34  Gender_Female                                     117 non-null    int64
#  35  Gender_Male                                       117 non-null    int64
#  36  Gender_Mixed                                      117 non-null    int64
#  37  Age_Mixed                                         117 non-null    int64
#  38  Age_Older                                         117 non-null    int64
#  39  Age_Younger                                       117 non-null    int64
#  40  Gender_Num                                        117 non-null    int64
#  41  Age_Num                                           117 non-null    int64
#  42  Platform_Num                                      117 non-null    int64
#  43  Platform_LinkedIn                                 117 non-null    int64
#  44  Platform_Indeed                                   117 non-null    int64
#  45  Platform_Glassdoor                                117 non-null    int64
#  46  Job Description spacy_sentencized_lower           117 non-null    object
#  47  Job Description spacy_tokenized                   117 non-null    object
#  48  Job Description spacy_sentencized_cleaned         117 non-null    object
#  49  Job Description num_words                         117 non-null    int64
#  50  Job Description num_unique_words                  117 non-null    int64
#  51  Job Description num_chars                         117 non-null    int64
#  52  Job Description num_chars_no_whitespact_and_punt  117 non-null    int64
#  53  Job Description num_punctuations                  117 non-null    int64
#  54  Job Description nltk_tokenized                    117 non-null    object
#  55  Job Description gensim_tokenized                  117 non-null    object
#  56  Job Description bert_tokenized                    117 non-null    object
# dtypes: category(2), float64(19), int64(19), object(17)
# memory usage: 51.7+ KB
# ====================
# Gender:
# --------------------
# Gender Counts:
# Mixed Gender    72
# Male            27
# Female          18
# Name: Gender, dtype: int64
# --------------------
# Gender Percentages:
# Mixed Gender   61.50
# Male           23.10
# Female         15.40
# Name: Gender, dtype: float64
# --------------------
# Min Gender value: Female
# Max Gender value: Male
# --------------------
# ====================
# Gender_Num:
# --------------------
# Gender_Num Counts:
# 1    72
# 2    27
# 0    18
# Name: Gender_Num, dtype: int64
# --------------------
# Gender_Num Percentages:
# 1   61.50
# 2   23.10
# 0   15.40
# Name: Gender_Num, dtype: float64
# --------------------
# Min Gender_Num value: 0
# Max Gender_Num value: 2
# --------------------
# Gender_Num Mean: 1.08
# --------------------
# Gender_Num Standard Deviation: 0.62
# ====================
# Gender_Female:
# --------------------
# Gender_Female Counts:
# 0    99
# 1    18
# Name: Gender_Female, dtype: int64
# --------------------
# Gender_Female Percentages:
# 0   84.60
# 1   15.40
# Name: Gender_Female, dtype: float64
# --------------------
# Min Gender_Female value: 0
# Max Gender_Female value: 1
# --------------------
# Gender_Female Mean: 0.15
# --------------------
# Gender_Female Standard Deviation: 0.36
# ====================
# Gender_Mixed:
# --------------------
# Gender_Mixed Counts:
# 1    72
# 0    45
# Name: Gender_Mixed, dtype: int64
# --------------------
# Gender_Mixed Percentages:
# 1   61.50
# 0   38.50
# Name: Gender_Mixed, dtype: float64
# --------------------
# Min Gender_Mixed value: 0
# Max Gender_Mixed value: 1
# --------------------
# Gender_Mixed Mean: 0.62
# --------------------
# Gender_Mixed Standard Deviation: 0.49
# ====================
# Gender_Male:
# --------------------
# Gender_Male Counts:
# 0    90
# 1    27
# Name: Gender_Male, dtype: int64
# --------------------
# Gender_Male Percentages:
# 0   76.90
# 1   23.10
# Name: Gender_Male, dtype: float64
# --------------------
# Min Gender_Male value: 0
# Max Gender_Male value: 1
# --------------------
# Gender_Male Mean: 0.23
# --------------------
# Gender_Male Standard Deviation: 0.42
# ====================
# Gender_Female_n:
# --------------------
# Min Gender_Female_n value: 7.0
# Max Gender_Female_n value: 3970.0
# --------------------
# Gender_Female_n Mean: 555.51
# --------------------
# Gender_Female_n Standard Deviation: 785.27
# ====================
# Gender_Male_n:
# --------------------
# Min Gender_Male_n value: 21.0
# Max Gender_Male_n value: 4510.0
# --------------------
# Gender_Male_n Mean: 586.63
# --------------------
# Gender_Male_n Standard Deviation: 728.09
# ====================
# Gender_Female_% per Sector:
# --------------------
# Min Gender_Female_% per Sector value: 19.444444444444446
# Max Gender_Female_% per Sector value: 84.2986741102582
# --------------------
# Gender_Female_% per Sector Mean: 44.39
# --------------------
# Gender_Female_% per Sector Standard Deviation: 16.17
# ====================
# Gender_Male_% per Sector:
# --------------------
# Min Gender_Male_% per Sector value: 15.631542219120725
# Max Gender_Male_% per Sector value: 80.55555555555556
# --------------------
# Gender_Male_% per Sector Mean: 55.59
# --------------------
# Gender_Male_% per Sector Standard Deviation: 16.19
# ====================
# Age:
# --------------------
# Age Counts:
# Younger      60
# Mixed Age    42
# Older        15
# Name: Age, dtype: int64
# --------------------
# Age Percentages:
# Younger     51.30
# Mixed Age   35.90
# Older       12.80
# Name: Age, dtype: float64
# --------------------
# Min Age value: Older
# Max Age value: Younger
# --------------------
# ====================
# Age_Num:
# --------------------
# Age_Num Counts:
# 2    60
# 1    42
# 0    15
# Name: Age_Num, dtype: int64
# --------------------
# Age_Num Percentages:
# 2   51.30
# 1   35.90
# 0   12.80
# Name: Age_Num, dtype: float64
# --------------------
# Min Age_Num value: 0
# Max Age_Num value: 2
# --------------------
# Age_Num Mean: 1.38
# --------------------
# Age_Num Standard Deviation: 0.71
# ====================
# Age_Older:
# --------------------
# Age_Older Counts:
# 0    102
# 1     15
# Name: Age_Older, dtype: int64
# --------------------
# Age_Older Percentages:
# 0   87.20
# 1   12.80
# Name: Age_Older, dtype: float64
# --------------------
# Min Age_Older value: 0
# Max Age_Older value: 1
# --------------------
# Age_Older Mean: 0.13
# --------------------
# Age_Older Standard Deviation: 0.34
# ====================
# Age_Mixed:
# --------------------
# Age_Mixed Counts:
# 0    75
# 1    42
# Name: Age_Mixed, dtype: int64
# --------------------
# Age_Mixed Percentages:
# 0   64.10
# 1   35.90
# Name: Age_Mixed, dtype: float64
# --------------------
# Min Age_Mixed value: 0
# Max Age_Mixed value: 1
# --------------------
# Age_Mixed Mean: 0.36
# --------------------
# Age_Mixed Standard Deviation: 0.48
# ====================
# Age_Younger:
# --------------------
# Age_Younger Counts:
# 1    60
# 0    57
# Name: Age_Younger, dtype: int64
# --------------------
# Age_Younger Percentages:
# 1   51.30
# 0   48.70
# Name: Age_Younger, dtype: float64
# --------------------
# Min Age_Younger value: 0
# Max Age_Younger value: 1
# --------------------
# Age_Younger Mean: 0.51
# --------------------
# Age_Younger Standard Deviation: 0.5
# ====================
# Age_Older_n:
# --------------------
# Min Age_Older_n value: 15.0
# Max Age_Older_n value: 2844.0
# --------------------
# Age_Older_n Mean: 440.05
# --------------------
# Age_Older_n Standard Deviation: 576.53
# ====================
# Age_Younger_n:
# --------------------
# Min Age_Younger_n value: 13.0
# Max Age_Younger_n value: 5228.0
# --------------------
# Age_Younger_n Mean: 700.86
# --------------------
# Age_Younger_n Standard Deviation: 868.11
# ====================
# Age_Older_% per Sector:
# --------------------
# Min Age_Older_% per Sector value: 18.939393939393938
# Max Age_Older_% per Sector value: 58.333333333333336
# --------------------
# Age_Older_% per Sector Mean: 38.68
# --------------------
# Age_Older_% per Sector Standard Deviation: 9.05
# ====================
# Age_Younger_% per Sector:
# --------------------
# Min Age_Younger_% per Sector value: 44.44444444444444
# Max Age_Younger_% per Sector value: 80.8080808080808
# --------------------
# Age_Younger_% per Sector Mean: 61.05
# --------------------
# Age_Younger_% per Sector Standard Deviation: 9.18

# %%
# Control variables info by sentence
print('='*30)
print('Control varibales info at Sentence Level')
print('-'*30)
get_df_info(df_manual, ivs_all = controls)
# Out:
# ==============================
# Control varibales info at Sentence Level
# ------------------------------
#
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5978 entries, 0 to 5977
# Data columns (total 58 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Job ID                                            5978 non-null   object
#  1   Job Description spacy_sentencized                 5978 non-null   object
#  2   Warmth                                            5978 non-null   int64
#  3   Competence                                        5978 non-null   int64
#  4   Dutch Requirement                                 5978 non-null   object
#  5   English Requirement                               5978 non-null   object
#  6   Search Keyword                                    5978 non-null   object
#  7   Platform                                          5978 non-null   object
#  8   Job Title                                         5978 non-null   object
#  9   Company Name                                      5978 non-null   object
#  10  Location                                          5978 non-null   object
#  11  Industry                                          291 non-null    object
#  12  Sector Code                                       5978 non-null   object
#  13  Sector                                            5978 non-null   object
#  14  Keywords Count                                    5978 non-null   float64
#  15  Gender_Female_n                                   5978 non-null   float64
#  16  Gender_Female_% per Sector                        5978 non-null   float64
#  17  Gender_Female_% per Social Category               5978 non-null   float64
#  18  Gender_Female_% per Workforce                     5978 non-null   float64
#  19  Gender_Male_n                                     5978 non-null   float64
#  20  Gender_Male_% per Sector                          5978 non-null   float64
#  21  Gender_Male_% per Social Category                 5978 non-null   float64
#  22  Gender_Male_% per Workforce                       5978 non-null   float64
#  23  Gender                                            5978 non-null   category
#  24  Age_Older_n                                       5978 non-null   float64
#  25  Age_Older_% per Sector                            5978 non-null   float64
#  26  Age_Older_% per Social Category                   5978 non-null   float64
#  27  Age_Older_% per Workforce                         5978 non-null   float64
#  28  Age_Younger_n                                     5978 non-null   float64
#  29  Age_Younger_% per Sector                          5978 non-null   float64
#  30  Age_Younger_% per Social Category                 5978 non-null   float64
#  31  Age_Younger_% per Workforce                       5978 non-null   float64
#  32  Age                                               5978 non-null   category
#  33  Sector_n                                          5978 non-null   float64
#  34  % Sector per Workforce                            5978 non-null   float64
#  35  Gender_Female                                     5978 non-null   int64
#  36  Gender_Male                                       5978 non-null   int64
#  37  Gender_Mixed                                      5978 non-null   int64
#  38  Age_Mixed                                         5978 non-null   int64
#  39  Age_Older                                         5978 non-null   int64
#  40  Age_Younger                                       5978 non-null   int64
#  41  Gender_Num                                        5978 non-null   int64
#  42  Age_Num                                           5978 non-null   int64
#  43  Platform_Num                                      5978 non-null   int64
#  44  Platform_LinkedIn                                 5978 non-null   int64
#  45  Platform_Indeed                                   5978 non-null   int64
#  46  Platform_Glassdoor                                5978 non-null   int64
#  47  Job Description spacy_sentencized_lower           5978 non-null   object
#  48  Job Description spacy_tokenized                   5978 non-null   object
#  49  Job Description spacy_sentencized_cleaned         5978 non-null   object
#  50  Job Description num_words                         5978 non-null   int64
#  51  Job Description num_unique_words                  5978 non-null   int64
#  52  Job Description num_chars                         5978 non-null   int64
#  53  Job Description num_chars_no_whitespact_and_punt  5978 non-null   int64
#  54  Job Description num_punctuations                  5978 non-null   int64
#  55  Job Description nltk_tokenized                    5978 non-null   object
#  56  Job Description gensim_tokenized                  5978 non-null   object
#  57  Job Description bert_tokenized                    5978 non-null   object
# dtypes: category(2), float64(19), int64(19), object(18)
# memory usage: 2.6+ MB
# ====================
# % Sector per Workforce:
# --------------------
# Min % Sector per Workforce value: 0.1147605856747131
# Max % Sector per Workforce value: 31.38504155124654
# --------------------
# % Sector per Workforce Mean: 4.49
# --------------------
# % Sector per Workforce Standard Deviation: 5.32
# ====================
# Job Description num_words:
# --------------------
# Min Job Description num_words value: 1
# Max Job Description num_words value: 131
# --------------------
# Job Description num_words Mean: 13.77
# --------------------
# Job Description num_words Standard Deviation: 10.64
# ====================
# English Requirement:
# --------------------
# English Requirement Counts:
# No     5969
# Yes       9
# Name: English Requirement, dtype: int64
# --------------------
# English Requirement Percentages:
# No    99.80
# Yes    0.20
# Name: English Requirement, dtype: float64
# --------------------
# Min English Requirement value: No
# Max English Requirement value: Yes
# --------------------
# ====================
# Dutch Requirement:
# --------------------
# Dutch Requirement Counts:
# No     5971
# Yes       7
# Name: Dutch Requirement, dtype: int64
# --------------------
# Dutch Requirement Percentages:
# No    99.90
# Yes    0.10
# Name: Dutch Requirement, dtype: float64
# --------------------
# Min Dutch Requirement value: No
# Max Dutch Requirement value: Yes
# --------------------

# %%
# Control variables info by job ad
print('='*30)
print('Control varibales info at Job Advertisement Level')
print('-'*30)
get_df_info(df_manual.groupby(['Job ID']).first(), ivs_all = controls)
# Out:
# ==============================
# Control varibales info at Job Advertisement Level
# ------------------------------
#
# DF INFO:
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 117 entries, 3768944208 to pj_a4ac3e531abef752
# Data columns (total 57 columns):
#  #   Column                                            Non-Null Count  Dtype
# ---  ------                                            --------------  -----
#  0   Job Description spacy_sentencized                 117 non-null    object
#  1   Warmth                                            117 non-null    int64
#  2   Competence                                        117 non-null    int64
#  3   Dutch Requirement                                 117 non-null    object
#  4   English Requirement                               117 non-null    object
#  5   Search Keyword                                    117 non-null    object
#  6   Platform                                          117 non-null    object
#  7   Job Title                                         117 non-null    object
#  8   Company Name                                      117 non-null    object
#  9   Location                                          117 non-null    object
#  10  Industry                                          5 non-null      object
#  11  Sector Code                                       117 non-null    object
#  12  Sector                                            117 non-null    object
#  13  Keywords Count                                    117 non-null    float64
#  14  Gender_Female_n                                   117 non-null    float64
#  15  Gender_Female_% per Sector                        117 non-null    float64
#  16  Gender_Female_% per Social Category               117 non-null    float64
#  17  Gender_Female_% per Workforce                     117 non-null    float64
#  18  Gender_Male_n                                     117 non-null    float64
#  19  Gender_Male_% per Sector                          117 non-null    float64
#  20  Gender_Male_% per Social Category                 117 non-null    float64
#  21  Gender_Male_% per Workforce                       117 non-null    float64
#  22  Gender                                            117 non-null    category
#  23  Age_Older_n                                       117 non-null    float64
#  24  Age_Older_% per Sector                            117 non-null    float64
#  25  Age_Older_% per Social Category                   117 non-null    float64
#  26  Age_Older_% per Workforce                         117 non-null    float64
#  27  Age_Younger_n                                     117 non-null    float64
#  28  Age_Younger_% per Sector                          117 non-null    float64
#  29  Age_Younger_% per Social Category                 117 non-null    float64
#  30  Age_Younger_% per Workforce                       117 non-null    float64
#  31  Age                                               117 non-null    category
#  32  Sector_n                                          117 non-null    float64
#  33  % Sector per Workforce                            117 non-null    float64
#  34  Gender_Female                                     117 non-null    int64
#  35  Gender_Male                                       117 non-null    int64
#  36  Gender_Mixed                                      117 non-null    int64
#  37  Age_Mixed                                         117 non-null    int64
#  38  Age_Older                                         117 non-null    int64
#  39  Age_Younger                                       117 non-null    int64
#  40  Gender_Num                                        117 non-null    int64
#  41  Age_Num                                           117 non-null    int64
#  42  Platform_Num                                      117 non-null    int64
#  43  Platform_LinkedIn                                 117 non-null    int64
#  44  Platform_Indeed                                   117 non-null    int64
#  45  Platform_Glassdoor                                117 non-null    int64
#  46  Job Description spacy_sentencized_lower           117 non-null    object
#  47  Job Description spacy_tokenized                   117 non-null    object
#  48  Job Description spacy_sentencized_cleaned         117 non-null    object
#  49  Job Description num_words                         117 non-null    int64
#  50  Job Description num_unique_words                  117 non-null    int64
#  51  Job Description num_chars                         117 non-null    int64
#  52  Job Description num_chars_no_whitespact_and_punt  117 non-null    int64
#  53  Job Description num_punctuations                  117 non-null    int64
#  54  Job Description nltk_tokenized                    117 non-null    object
#  55  Job Description gensim_tokenized                  117 non-null    object
#  56  Job Description bert_tokenized                    117 non-null    object
# dtypes: category(2), float64(19), int64(19), object(17)
# memory usage: 51.7+ KB
# ====================
# % Sector per Workforce:
# --------------------
# Min % Sector per Workforce value: 0.1147605856747131
# Max % Sector per Workforce value: 31.38504155124654
# --------------------
# % Sector per Workforce Mean: 4.52
# --------------------
# % Sector per Workforce Standard Deviation: 5.61
# ====================
# Job Description num_words:
# --------------------
# Min Job Description num_words value: 1
# Max Job Description num_words value: 43
# --------------------
# Job Description num_words Mean: 10.15
# --------------------
# Job Description num_words Standard Deviation: 9.0
# ====================
# English Requirement:
# --------------------
# English Requirement Counts:
# No    117
# Name: English Requirement, dtype: int64
# --------------------
# English Requirement Percentages:
# No   100.00
# Name: English Requirement, dtype: float64
# --------------------
# Min English Requirement value: No
# Max English Requirement value: No
# --------------------
# ====================
# Dutch Requirement:
# --------------------
# Dutch Requirement Counts:
# No    117
# Name: Dutch Requirement, dtype: int64
# --------------------
# Dutch Requirement Percentages:
# No   100.00
# Name: Dutch Requirement, dtype: float64
# --------------------
# Min Dutch Requirement value: No
# Max Dutch Requirement value: No
# --------------------

# %%
# Imbalance Ratio
warmth_imbalance_ratio = df_manual['Warmth'].loc[
    df_manual['Warmth'] == 1].count()/df_manual['Warmth'].loc[df_manual['Warmth'] == 0
].count()
competence_imbalance_ratio = df_manual['Competence'].loc[
    df_manual['Competence'] == 1].count()/df_manual['Competence'].loc[df_manual['Competence'] == 0
].count()

all_imbalance_ratio_dict = {
    'Warmth': warmth_imbalance_ratio,
    'Competence': competence_imbalance_ratio
}

print('='*20)
print('Imabalance Ratios')
print('-'*10)
print(f'Warmth IR: {warmth_imbalance_ratio:.2f}')
print(f'Competence IR: {competence_imbalance_ratio:.2f}')
print('='*20)
# Out:
# ====================
# Imabalance Ratios
# ----------
# Warmth IR: 0.34
# Competence IR: 0.79
# ====================

# %%
# Ploting Warmth and Competence
df_warm_comp_transposed = pd.concat(
    [
        df_manual['Warmth'].value_counts(normalize=True).mul(100).round(2).astype(float).to_frame().T,
        df_manual['Competence'].value_counts(normalize=True).mul(100).round(2).astype(float).to_frame().T,
    ]
)

fig, ax = plt.subplots()
ax.set_title('Training Dataset: Warmth and Competence Sentence Percentages')
ax.set_xlabel('Manually Annotated Sentencence Warmth and Competence Percentage from Total')

df_warm_comp_transposed.plot(
    kind='barh', legend=True, stacked=True, ax=ax, color=['C5', 'C0'],
)
ax.legend(['Absent', 'Present'])

for container in ax.containers:
    labels = [f'{width:.1f}%' for v in container if float(width:= v.get_width())]
    ax.bar_label(container, labels=labels, label_type='center', color='white', weight='bold')
    ax.set_xlabel('% Job Ad Sentences')

for i, tick_label in enumerate(ax.get_ymajorticklabels()):
    ax.annotate(
        f'IR for {tick_label.get_text()} = {all_imbalance_ratio_dict[tick_label.get_text()]:.2f}',
        xy=(48, 0.3+i), ha='center', va='center'
    )

for image_save_format in ['eps', 'png', 'svg']:
    fig.savefig(
        f'{plot_save_path}Manually Annotated Warmth and Competence Sentences.{image_save_format}',
        format=image_save_format, dpi=3000, bbox_inches='tight'
    )
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Ploting Gender and Age
df_gender_transposed = df_manual['Gender'].value_counts(normalize=True).mul(100).round(2).astype(float).to_frame().T
df_age_transposed = df_manual['Age'].value_counts(normalize=True).mul(100).round(2).astype(float).to_frame().T

fig, axs = plt.subplots(1, 2)
fig.suptitle('Training Dataset: Gender and Age Sentence Percentages')

df_gender_transposed.plot(
    kind='bar', legend=True, stacked=True, ax=axs[0], color=['C2', 'C0', 'C5']
)
df_age_transposed.plot(
    kind='bar', legend=True, stacked=True, ax=axs[1], color=['C0', 'C2', 'C5']
)

for ax in axs:
    for container in ax.containers:
        labels = [f'{height:.1f}%' for v in container if float(height:= v.get_height())]
        ax.bar_label(container, labels=labels, label_type='center', color='white', weight='bold')
        ax.set_ylabel('% Job Ad Sentences')
        handles, labels = ax.get_legend_handles_labels()
        order = [2, 1, 0] if 'Older' in labels else [2, 0, 1]
        ax.legend([handles[idx] for idx in order],[labels[idx] for idx in order], loc='upper right', fontsize=8, )

for image_save_format in ['eps', 'png', 'svg']:
    fig.savefig(
        f'{plot_save_path}Manually Annotated Gender and Age Sentences.{image_save_format}',
        format=image_save_format, dpi=3000, bbox_inches='tight'
    )
# Out:
# WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.

# %%
# Make stacked barplots with percentages
dvs_list=['Warmth', 'Competence']

for iv in tqdm.tqdm(['Gender', 'Age', 'Sector']):
    fig, ax = plt.subplots()
    fig.suptitle(f'Training Dataset: Warmth and Competence Sentence Percentages per {iv}')

    vars_list = [iv, *dvs_list]
    df_pivot = df_manual[
        vars_list
    ].pivot_table(
        index=iv, values=dvs_list, fill_value=0, aggfunc=lambda x: (100*x.sum())/len(df_manual)
    )

    df_pivot.sort_values(by=iv, ascending=False).plot(kind='barh', legend=True, stacked=True, ax=ax, color=['C0', 'C5'])

    ax.legend(['Warmth', 'Competence'])

    for container in ax.containers:
        labels = [f'{width:.1f}%' for v in container if float(width:= v.get_width())]
        if iv != 'Sector':
            ax.bar_label(container, labels=labels, label_type='center', color='white', fontsize=8)
        ax.set_xlabel('% Job Ad Sentences')
        ax.set_ylabel(iv)
        ax.legend(loc='upper right', fontsize=8)

    for image_save_format in ['eps', 'png', 'svg']:
        fig.savefig(
            f'{plot_save_path}Barplot - Manually Annotated {iv} x {dvs_list[0]} and {dvs_list[1]} Sentences.{image_save_format}',
            format=image_save_format, dpi=3000, bbox_inches='tight'
        )
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#  33%|███▎      | 1/3 [00:10<00:21, 10.76s/it]WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
#  67%|██████▋   | 2/3 [00:20<00:10, 10.33s/it]WARNING:matplotlib.backends.backend_ps:The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# 100%|██████████| 3/3 [00:35<00:00, 11.70s/it]

# %%
df_manual.groupby(ivs)[dvs].agg('mean')
# Out:
#                         Warmth  Competence
# Gender       Age
# Female       Older        NaN       NaN
#              Mixed Age   0.27      0.43
#              Younger      NaN       NaN
# Mixed Gender Older       0.17      0.43
#              Mixed Age   0.32      0.57
#              Younger     0.25      0.42
# Male         Older       0.21      0.52
#              Mixed Age   0.24      0.43
#              Younger      NaN       NaN

# %%
axs.shape
# Out:
# (2, 2)

# %%
axs[ax[0], ax[1]]
# Out:
# <Axes: >

# %%
i = 0
for ax in np.ndindex(axs.shape):
    print(ax)
    i += 1
# Out:
# (0, 0)
# (0, 1)
# (1, 0)
# (1, 1)

# %%
# Make line plots
fig, axs = plt.subplots(2, 2)
fig.suptitle('Training Dataset: Gender and Age')

for ax, iv, dv in tqdm_product(np.ndindex(axs.shape), ['Gender', 'Age'], ['Warmth', 'Competence']):
    df_manual = categorize_df_gender_age(df_manual)

    title = f'Means of {dv}-related frames in job ads from {iv} segregated sectors'
    data = df_manual.groupby(iv)[dv].agg('mean')

    line_plot = sns.lineplot(
        data=data.astype(float), marker='o', legend='full', color='C0', ax=axs[ax], 
    )
    # line_plot.set(
    #     title=title,
    #     xlabel=f'{iv}-dominated Sector',
    #     ylabel=f'{dv} Mean',
    # )
    # fig = line_plot.get_figure()
    i += 1

    # for image_save_format in ['eps', 'png', 'svg']:
    #     fig.savefig(
    #         f'{plot_save_path}Line Plot - Manually Annotated {iv} x {dv} Sentences.{image_save_format}',
    #         format=image_save_format, dpi=3000, bbox_inches='tight'
    #     )
    # plt.show()
    # plt.clf()
    # plt.cla()
    # plt.close()
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /var/folders/46/q15p556n1dd63z6gkwyh896c0000gn/T/ipykernel_90064/4213040311.py:5 in <module>     │
# │                                                                                                  │
# │ [Errno 2] No such file or directory:                                                             │
# │ '/var/folders/46/q15p556n1dd63z6gkwyh896c0000gn/T/ipykernel_90064/4213040311.py'                 │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# AttributeError: 'Axes' object has no attribute 'shape'

# %%
# Make violin plots
fig = plt.figure(figsize=(10, 5))
fig.suptitle('Distribution of Warmth and Competence Scores')

ax = sns.violinplot(
    data=df_manual, x=['Gender', 'Age'], y='Warmth', palette=['C5', 'C0'], inner='quartile'
)
ax.set(
    xlabel='Warmth and Competence',
    ylabel='Score',
)

for image_save_format in ['eps', 'png', 'svg']:
    fig.savefig(
            f'{plot_save_path}Violin Plot - Manually Annotated {iv} x {dv} Sentences.{image_save_format}',
            format=image_save_format, dpi=3000, bbox_inches='tight'
        )
# Out:
# ╭─────────────────────────────── Traceback (most recent call last) ────────────────────────────────╮
# │ /var/folders/46/q15p556n1dd63z6gkwyh896c0000gn/T/ipykernel_90064/1058869040.py:5 in <module>     │
# │                                                                                                  │
# │ [Errno 2] No such file or directory:                                                             │
# │ '/var/folders/46/q15p556n1dd63z6gkwyh896c0000gn/T/ipykernel_90064/1058869040.py'                 │
# │                                                                                                  │
# │ /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/python3.10/site-packages/seaborn/_de │
# │ corators.py:46 in inner_f                                                                        │
# │                                                                                                  │
# │   43 │   │   │   │   FutureWarning                                                               │
# │   44 │   │   │   )                                                                               │
# │   45 │   │   kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})                     │
# │ ❱ 46 │   │   return f(**kwargs)                                                                  │
# │   47 │   return inner_f                                                                          │
# │   48                                                                                             │
# │   49                                                                                             │
# │                                                                                                  │
# │ /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/python3.10/site-packages/seaborn/cat │
# │ egorical.py:2400 in violinplot                                                                   │
# │                                                                                                  │
# │   2397 │   ax=None, **kwargs,                                                                    │
# │   2398 ):                                                                                        │
# │   2399 │                                                                                         │
# │ ❱ 2400 │   plotter = _ViolinPlotter(x, y, hue, data, order, hue_order,                           │
# │   2401 │   │   │   │   │   │   │    bw, cut, scale, scale_hue, gridsize,                         │
# │   2402 │   │   │   │   │   │   │    width, inner, split, dodge, orient, linewidth,               │
# │   2403 │   │   │   │   │   │   │    color, palette, saturation)                                  │
# │                                                                                                  │
# │ /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/python3.10/site-packages/seaborn/cat │
# │ egorical.py:522 in __init__                                                                      │
# │                                                                                                  │
# │    519 │   │   │   │    width, inner, split, dodge, orient, linewidth,                           │
# │    520 │   │   │   │    color, palette, saturation):                                             │
# │    521 │   │                                                                                     │
# │ ❱  522 │   │   self.establish_variables(x, y, hue, data, orient, order, hue_order)               │
# │    523 │   │   self.establish_colors(color, palette, saturation)                                 │
# │    524 │   │   self.estimate_densities(bw, cut, scale, scale_hue, gridsize)                      │
# │    525                                                                                           │
# │                                                                                                  │
# │ /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/python3.10/site-packages/seaborn/cat │
# │ egorical.py:156 in establish_variables                                                           │
# │                                                                                                  │
# │    153 │   │   │   │   │   raise ValueError(err)                                                 │
# │    154 │   │   │                                                                                 │
# │    155 │   │   │   # Figure out the plotting orientation                                         │
# │ ❱  156 │   │   │   orient = infer_orient(                                                        │
# │    157 │   │   │   │   x, y, orient, require_numeric=self.require_numeric                        │
# │    158 │   │   │   )                                                                             │
# │    159                                                                                           │
# │                                                                                                  │
# │ /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/python3.10/site-packages/seaborn/_co │
# │ re.py:1311 in infer_orient                                                                       │
# │                                                                                                  │
# │   1308 │                                                                                         │
# │   1309 │   """                                                                                   │
# │   1310 │                                                                                         │
# │ ❱ 1311 │   x_type = None if x is None else variable_type(x)                                      │
# │   1312 │   y_type = None if y is None else variable_type(y)                                      │
# │   1313 │                                                                                         │
# │   1314 │   nonnumeric_dv_error = "{} orientation requires numeric `{}` variable."                │
# │                                                                                                  │
# │ /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/python3.10/site-packages/seaborn/_co │
# │ re.py:1229 in variable_type                                                                      │
# │                                                                                                  │
# │   1226 │   │   return "categorical"                                                              │
# │   1227 │                                                                                         │
# │   1228 │   # Special-case all-na data, which is always "numeric"                                 │
# │ ❱ 1229 │   if pd.isna(vector).all():                                                             │
# │   1230 │   │   return "numeric"                                                                  │
# │   1231 │                                                                                         │
# │   1232 │   # Special-case binary/boolean data, allow caller to determine                         │
# │                                                                                                  │
# │ /opt/homebrew/Caskroom/mambaforge/base/envs/study1_3.10/lib/python3.10/site-packages/pandas/core │
# │ /generic.py:1527 in __nonzero__                                                                  │
# │                                                                                                  │
# │    1524 │                                                                                        │
# │    1525 │   @final                                                                               │
# │    1526 │   def __nonzero__(self) -> NoReturn:                                                   │
# │ ❱  1527 │   │   raise ValueError(                                                                │
# │    1528 │   │   │   f"The truth value of a {type(self).__name__} is ambiguous. "                 │
# │    1529 │   │   │   "Use a.empty, a.bool(), a.item(), a.any() or a.all()."                       │
# │    1530 │   │   )                                                                                │
# ╰──────────────────────────────────────────────────────────────────────────────────────────────────╯
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %% [markdown]
# # ATTN: This script should be run AFTER all visualizations are completed.

# %% [markdown]
# ### START HERE IF SOURCING FROM df_manual_FOR_TRAINNING
# ### PLEASE SET CORRECT DIRECTORY PATHS BELOW

# %% [markdown]
# # Make descriptive tables

# %%
import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

mod = sys.modules[__name__]

code_dir = None
code_dir_name = 'Code'
unwanted_subdir_name = 'Analysis'

for _ in range(5):

    parent_path = str(Path.cwd().parents[_]).split('/')[-1]

    if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

        code_dir = str(Path.cwd().parents[_])

        if code_dir is not None:
            break

sys.path.append(code_dir)
# %load_ext autoreload
# %autoreload 2

# %%
from setup_module.imports import *  # type:ignore # isort:skip # fmt:skip # noqa # nopep8

# %%
# Function to order categories
def categorize_df_gender_age(df, gender_order=None, age_order=None, ivs=None):
    if gender_order is None:
        gender_order = ['Female', 'Mixed Gender', 'Male']
    if age_order is None:
        age_order = ['Older', 'Mixed Age', 'Younger']
    if ivs is None:
        ivs = ['Gender', 'Age']

    # Arrange Categories
    for iv in ivs:
        if iv == 'Gender':
            order = gender_order
        elif iv == 'Age':
            order = age_order
        with contextlib.suppress(ValueError):
            df[iv] = df[iv].astype('category').cat.reorder_categories(order, ordered=True)

            df[iv] = pd.Categorical(
                df[iv], categories=order, ordered=True
            )
            df[f'{iv}_Num'] = pd.to_numeric(df[iv].cat.codes).astype('int64')

    return df

# %%
df_manual = pd.read_pickle(f'{df_save_dir}df_manual_for_trainning.pkl')

# %% [markdown]
# ### Gender and Age tables

# %%
df = df_manual.copy()
gender_order = ['Female', 'Male', 'Mixed Gender']
age_order = ['Older', 'Younger', 'Mixed Age']

ivs_dict = {'Gender': gender_order, 'Age': age_order}

df_desc_gender_dict = defaultdict(list)
df_desc_age_dict = defaultdict(list)

variables = ['Gender', 'Age']
levels = ['Job Advertisement', 'Sentence']
data_types = ['Manually Annotated', 'Collected']

for v, level, data_type in tqdm_product(
    variables, levels, data_types
):
    df = categorize_df_gender_age(df)

    if level.title() == 'Job Advertisement':
        level_df = df.groupby(['Job ID']).first()
    elif level.title() == 'Sentence':
        level_df = df

# %%
# Function to make descriptives tables
def genage_make_descriptives_table(df, v, level, gender_order=None, age_order=None):

    if gender_order is None:
        gender_order = ['Female', 'Male', 'Mixed Gender']
    if age_order is None:
        age_order = ['Older', 'Younger', 'Mixed Age']
    
    ivs_dict = {'Gender': gender_order, 'Age': age_order}

    df = categorize_df_gender_age(df)

    if level.title() == 'Job Advertisement':
        level_df = df.groupby(['Job ID']).first()
    elif level.title() == 'Sentence':
        level_df = df
    else:
        raise AssertionError(f'Specified level {level} not in data.')

    if v in list(ivs_dict.keys()):
        cat_dict = ivs_dict
        index = [
            f'{v_cat}-dominated'
            if 'Mixed' not in v_cat
            else
            f'{"-".join(v_cat.split())}'
            for v_cat in cat_dict[v]
        ]
        caption = [
            f'{v}_{v_cat.split()[0]}'
            for v_cat in cat_dict[v]
        ]

    desc_dict = {
        'Sectors': index,
        'n': [
            level_df[v].value_counts()[v_cat]
            for v_cat in cat_dict[v]
        ],
        '%': [
            level_df[v].value_counts(normalize=True).mul(100).round(2).astype(float)[v_cat]
            for v_cat in cat_dict[v]
        ],
        'M': [
            level_df[caption].mean().round(2).astype(float)[i]
            for i in range(len(cat_dict[v]))
        ],
        'S.D.': [
            level_df[caption].std().round(2).astype(float)[i]
            for i in range(len(cat_dict[v]))
        ]
    }

    # Make DF from dict
    df_desc = pd.DataFrame(desc_dict)
    df_desc = df_desc.set_index('Sectors')

    return df_desc

# %%
df_desc_gender_dict = defaultdict(list)
df_desc_age_dict = defaultdict(list)

variables = ['Gender', 'Age']
levels = ['Job Advertisement', 'Sentence']
data_types = ['Manually Annotated', 'Collected']

for v, level, data_type in tqdm_product(
    variables, levels, data_types
):
    cols = [
        (f'{data_type.title()} Job Advertisements', v, level.title(), 'n'),
        (f'{data_type.title()} Job Advertisements', v, level.title(), '%'),
        (f'{data_type.title()} Job Advertisements', v, level.title(), 'M'),
        (f'{data_type.title()} Job Advertisements', v, level.title(), 'S.D.'),
    ]

    df_desc_genage = genage_make_descriptives_table(df=df_manual, v=v, level=level)

    df_desc_genage.columns = pd.MultiIndex.from_tuples(cols)

    if v == 'Gender':
        df_desc_gender_dict[data_type].append(df_desc_genage)
    elif v == 'Age':
        df_desc_age_dict[data_type].append(df_desc_genage)

# %%
df_desc_genage_dict = defaultdict(list)

for df, data_type in tqdm_product(
    [df_desc_gender_dict, df_desc_age_dict],
    data_types,
):
    category = df[data_type][0].columns.get_level_values(level=1)[0]
    if df[data_type][0].columns.get_level_values(level=2).str.contains('Job Advertisement').all():
        df_desc_genage_dict[category].append(
            pd.concat(
                [
                    df[data_type][0], df[data_type][1]
                ],
                axis='columns'
            )
        )
    else:
        df_desc_genage_dict[category].append(
            pd.concat(
                [
                    df[data_type][1], df[data_type][0]
                ],
                axis='columns'
            )
        )

# %%
for cat, df in df_desc_genage_dict.items():
    df = pd.concat([df[0], df[1]], axis='columns')

    if cat == 'Gender':
        df_desc_gender = df
    elif cat == 'Age':
        df_desc_age = df

# %%
# Save Tables
# Gender
df_desc_gender.to_csv(f'{table_save_path}Gender - Job Advertisement Descriptives.csv', index=True)
df_desc_gender.to_pickle(f'{table_save_path}Gender - Job Advertisement Descriptives.pkl')
with pd.option_context('max_colwidth', 10000000000):
    df_desc_gender.to_latex(f'{table_save_path}Gender - Job Advertisement Descriptives.tex', index=True, longtable=True, escape=True, multicolumn=True, multicolumn_format='c', position='H', caption='Number and proportion of job advertisements sample, and resulting sentences for gender and age homogeneous and heterogeneous sectors', label='Descriptives')
df_desc_gender.to_markdown(f'{table_save_path}Gender - Job Advertisement Descriptives.md', index=True)
# save_sector_excel(df_sectors_all, data_save_dir)

# Age
df_desc_age.to_csv(f'{table_save_path}Age - Job Advertisement Descriptives.csv', index=True)
df_desc_age.to_pickle(f'{table_save_path}Age - Job Advertisement Descriptives.pkl')
with pd.option_context('max_colwidth', 10000000000):
    df_desc_age.to_latex(f'{table_save_path}Age - Job Advertisement Descriptives.tex', index=True, longtable=True, escape=True, multicolumn=True, multicolumn_format='c', position='H', caption='Number and proportion of job advertisements sample, and resulting sentences for gender and age homogeneous and heterogeneous sectors', label='Descriptives')
df_desc_age.to_markdown(f'{table_save_path}Age - Job Advertisement Descriptives.md', index=True)
# save_sector_excel(df_sectors_all, data_save_dir)

# %% [markdown]
# ### Warmth and Competence tables

# %%
variables = ['Warmth', 'Competence']

cols = [
    ('Manually Annotated Job Advertisements', 'n'),
    ('Manually Annotated Job Advertisements', '%'),
    ('Manually Annotated Job Advertisements', 'M'),
    ('Manually Annotated Job Advertisements', 'S.D.'),
]

binary_order = [0, 1]
cat_dict = {'Warmth': binary_order, 'Competence': binary_order}

desc_warmcomp_dict = {
    'Frames': list(cat_dict.keys()),
    'n': [
        df_manual[v].value_counts()[1]
        for v in variables
    ],
    '%': [
        df_manual[v].value_counts(normalize=True).mul(100).round(2).astype(float)[1]
        for v in variables
    ],
    'M': list(
        df_manual[variables].mean().round(2).astype(float)
    ),
    'S.D.': list(
        df_manual[variables].std().round(2).astype(float)
    )
}
    
# Make df_manual from dict
df_desc_warmcomp = pd.DataFrame(desc_warmcomp_dict)
df_desc_warmcomp = df_desc_warmcomp.set_index('Frames')
df_desc_warmcomp.columns = pd.MultiIndex.from_tuples(cols)

# %%
# Save Tables
df_desc_warmcomp.to_csv(f'{table_save_path}Warmth and Competence - Job Advertisement Descriptives.csv', index=True)
df_desc_warmcomp.to_pickle(f'{table_save_path}Warmth and Competence - Job Advertisement Descriptives.pkl')
with pd.option_context('max_colwidth', 10000000000):
    df_desc_warmcomp.to_latex(f'{table_save_path}Warmth and Competence - Job Advertisement Descriptives.tex', index=True, longtable=True, escape=True, multicolumn=True, multicolumn_format='c', position='H', caption='Number and proportion of job advertisements sample, and resulting sentences for gender and age homogeneous and heterogeneous sectors', label='Descriptives')
df_desc_warmcomp.to_markdown(f'{table_save_path}Warmth and Competence - Job Advertisement Descriptives.md', index=True)
# save_sector_excel(df_sectors_all, data_save_dir)
