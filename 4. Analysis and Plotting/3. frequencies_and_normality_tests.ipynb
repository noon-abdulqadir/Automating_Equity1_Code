# %%
import os # type:ignore # isort:skip # fmt:skip # noqa # nopep8
import sys # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from pathlib import Path # type:ignore # isort:skip # fmt:skip # noqa # nopep8

mod = sys.modules[__name__]

code_dir = None
code_dir_name = 'Code'
unwanted_subdir_name = 'Analysis'

if code_dir_name not in str(Path.cwd()).split('/')[-1]:
    for _ in range(5):

        parent_path = str(Path.cwd().parents[_]).split('/')[-1]

        if (code_dir_name in parent_path) and (unwanted_subdir_name not in parent_path):

            code_dir = str(Path.cwd().parents[_])

            if code_dir is not None:
                break
else:
    code_dir = str(Path.cwd())
sys.path.append(code_dir)

# %load_ext autoreload
# %autoreload 2

# %%
from setup_module.imports import *  # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from setup_module import researchpy_fork as rp # type:ignore # isort:skip # fmt:skip # noqa # nopep8
from setup_module import specification_curve_fork as specy # type:ignore # isort:skip # fmt:skip # noqa # nopep8
# Out:
# Using MPS
# 0it [00:00, ?it/s]

# %% [markdown]
# # Functions

# %% [markdown]
# # READ DATA

# %%
with open(f'{data_dir}df_manual_len.txt', 'r') as f:
    df_manual_len = int(f.read())

df_manual = pd.read_pickle(f'{df_save_dir}df_manual_for_training.pkl')
assert len(df_manual) == df_manual_len, f'DATAFRAME MISSING DATA! DF SHOULD BE OF LENGTH {df_manual_len} BUT IS OF LENGTH {len(df_manual)}'
print(f'Dataframe loaded with shape: {df_manual.shape}')
df_manual = categorize_df_gender_age(df_manual)
# Out:
# Dataframe loaded with shape: (5947, 72)

# %%
with open(f'{data_dir}df_jobs_for_analysis_len.txt', 'r') as f:
    df_jobs_len = int(f.read())

# df_jobs = pd.read_pickle(f'{df_save_dir}df_jobs_for_analysis.pkl')
df_jobs = pd.read_pickle(f'{df_save_dir}df_jobs_for_analysis.pkl')
assert len(df_jobs) == df_jobs_len, f'DATAFRAME MISSING DATA! DF SHOULD BE OF LENGTH {df_jobs_len} BUT IS OF LENGTH {len(df_jobs)}'
print(f'Dataframe loaded with shape: {df_jobs.shape}')
df_jobs = categorize_df_gender_age(df_jobs)
# Out:
# Dataframe loaded with shape: (307154, 87)

# %% [markdown]
# # Analysis plan:
#
# 1. ## [Descriptives and tables](./1.%20descriptives_and_tables.ipynb)
# 2. ## [Visualization](./2.%20visualization.ipynb)
# 3. ## [Frequencies and Normality tests](./2.%20frequencies_and_normality_test.ipynb)
#    1. ### Frequencies, histograms, and QQ plots
#       * Normal test
#       * Kurtosis test
#       * Shapiro
#       * Anderson
#       * Bartlett
#    2. ### Correlation between independent variables (IVs) and control variables and Multicolinarity test
#       * Pearson's R
#       * VIF
#      - ***ivs_dummy*** (binary nominal) = Social category designation (Female, Male, Mixed Gender)
#      - ***ivs_perc*** (continous ratio) = Social category percentage per sector (0-100)
#      - ***% Sector per Workforce*** (continous ratio) = Sector percentage per worksforce (0-100)
#      - ***num_words*** (continous ratio) = Number of words in job description
#      - ***English Requirement in Job Ad*** (binary nominal) = English requirement in job description (0 vs. 1)
#      - ***Dutch Requirement in Job Ad*** (binary nominal) = Dutch requirement in job description (0 vs. 1)
#      - ***Platform*** (binary dummy) = LinkedIn (0 vs. 1), Indeed (0 vs. 1), Glassdoor (0 vs. 1)
#
# 4. ## [ANOVA and Chi-square (Pearson's R)](./3.%20chisqt_and_anova.ipynb)
#
#    1. ### Chi-square
#       * **df_manual:**
#         - ***dvs*** (binary nominal) = 'Warmth' and 'Competence' (0 vs. 1)
#         - ***ivs*** (binary nominal) = Social category designation (Female, Male, Mixed Gender)
#       * **df_jobs:**
#         - ***dvs*** (binary nominal) = 'Warmth' and 'Competence' (0 vs. 1)
#         - ***ivs*** (binary nominal) = Social category designation (Female, Male, Mixed Gender)
#
#    2. ### One-way ANOVA, interactions, and post-hoc test
#       * **df_manual:**
#         - ***dvs*** (binary nominal) = 'Warmth' and 'Competence' (0 vs. 1)
#         - ***ivs*** (binary nominal) = Social category designation (Female, Male, Mixed Gender)
#           - If Levene's test is *not significant*, use classic ANOVA and Tukey's post hoc test
#           - If Levene's test is *significant*, use Welch's and Kruskal-Wallis ANOVA and Games Howell's post hoc test
#       * **df_jobs:**
#          - ***dvs_prob*** (continous ratio) = 'Warmth' and 'Competence' probabilities (0-1)
#          - ***ivs*** (binary nominal) = Social category designation (Female, Male, Mixed Gender)
#            - If Levene's test is *not significant*, use classic ANOVA and Tukey's post hoc test
#            - If Levene's test is *significant*, use Welch's and Kruskal-Wallis ANOVA and Games Howell's post hoc test
#
# 5. ## [Regression Analysis](./3.%20regression_analysis.ipynb)
#    1. ### Logistic Regression  with all interaction (smf):
#       * **df_manual:**
#         - ***dvs*** (binary nominal) = 'Warmth' and 'Competence' (0 vs. 1)
#         - ***ivs_perc*** (continous ratio) = Social category percentage per sector (0-100)
#       * **df_jobs:**
#         - ***dvs*** (binary nominal) = 'Warmth' and 'Competence' (0 vs. 1)
#         - ***ivs_perc*** (continous ratio) = Social category percentage per sector (0-100)
#    2. ### OLS Regression with all interaction:
#       * **df_jobs:**
#         - ***dvs_prob*** (continous ratio) = 'Warmth' and 'Competence' probabilities (0-1)
#         - ***ivs_perc*** (continous ratio) = Social category percentage per sector (0-100)
#    3. ### Multilevel OLS Regression with all interaction:
#       * **df_jobs:**
#         - ***dvs_prob*** (continous ratio) = 'Warmth' and 'Competence' probabilities (0-1)
#         - ***ivs_perc*** (continous ratio) = Social category percentage per sector (0-100)
#
# 6. ## [Specification Curve Analysis](./4.%20specification_curve_analysis.ipynb)
#
#    1. ### Logistic Specification Curve Analysis:
#       * **df_manual:**
#         - ***dvs*** (binary nominal) = 'Warmth' and 'Competence' (0 vs. 1)
#         - ***ivs_perc*** (continous ratio) = Social category percentage per sector (0-100)
#       * **df_jobs:**
#         - ***dvs*** (binary nominal) = 'Warmth' and 'Competence' (0 vs. 1)
#         - ***ivs_perc*** (continous ratio) = Social category percentage per sector (0-100)
#    2. ### OLS Specification Curve Analysis:
#       * **df_jobs:**
#         - ***dvs_prob*** (continous ratio) = 'Warmth' and 'Competence' probabilities (0-1)
#         - ***ivs_perc*** (continous ratio) = Social category percentage per sector (0-100)

# %% [markdown]
# ## Set dataframes

# %% [markdown]
# #### Dataframes dict

# %%
dataframes = {
    'df_jobs': df_jobs,
    # 'df_manual': df_manual,
}

# %% [markdown]
# # Frequencies

# %%
def run_freq_and_normality_tests(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    data_names = dvs[:]+ ivs_dummy_perc_and_perc_interactions[:]

    if df_name == 'df_manual':
        dvs_ = dvs[:]
    elif df_name == 'df_jobs':
        data_names.extend(dvs_prob[:])
        dvs_ = dvs_all[:]

    print('~'*20)
    # print(rp.codebook(df[data_names]))

    # Gender and Age
    print('-'*20)
    print(f'Categorical Summary {ivs}')
    freq_iv=rp.summary_cat(df[ivs]).round(3)
    print(freq_iv)
    freq_iv.to_csv(f'{table_save_path}frequencies {df_name} - Gender and Age.csv')
    freq_iv.style.to_latex(f'{table_save_path}frequencies {df_name} - Gender and Age.tex', hrules=True)
    print('-'*20)
    print('\n')

    # Gender and Age Percentages
    print('-'*20)
    print(f'Continuous Summary {ivs_perc_and_perc_interactions}')
    freq_iv_perc=rp.summarize(df[ivs_perc_and_perc_interactions], ci_level = 0.95, decimals = 3)
    print(freq_iv_perc)
    freq_iv_perc.to_csv(f'{table_save_path}frequencies {df_name} - Gender and Age Percentages.csv')
    freq_iv_perc.style.to_latex(f'{table_save_path}frequencies {df_name} - Gender and Age Percentages.tex', hrules=True)
    print('-'*20)
    print('\n')

    # Gender and Age Dummies
    print('-'*20)
    print(f'Continuous Summary {ivs_dummy}')
    freq_iv_dummy=rp.summarize(df[ivs_dummy], ci_level = 0.95, decimals = 3)
    print(freq_iv_dummy)
    freq_iv_dummy.to_csv(f'{table_save_path}frequencies {df_name} - Gender and Age Dummies.csv')
    freq_iv_dummy.style.to_latex(f'{table_save_path}frequencies {df_name} - Gender and Age Dummies.tex', hrules=True)
    print('-'*20)
    print('\n')

    # Gender and Age Counts
    print('-'*20)
    print(f'Continuous Summary {ivs_count}')
    freq_iv_count=rp.summarize(df[ivs_count], ci_level = 0.95, decimals = 3)
    print(freq_iv_count)
    freq_iv_count.to_csv(f'{table_save_path}frequencies {df_name} - Gender and Age Counts.csv')
    freq_iv_count.style.to_latex(f'{table_save_path}frequencies {df_name} - Gender and Age Counts.text')
    print('-'*20)
    print('\n')

    # Warmth and Competence
    print('-'*20)
    print(f'Categorical Summary {dvs}')
    freq_dv=rp.summary_cat(df[dvs]).round(3)
    print(freq_dv)
    freq_dv.to_csv(f'{table_save_path}frequencies {df_name} - Warmth and Competence.csv')
    freq_dv.style.to_latex(f'{table_save_path}frequencies {df_name} - Warmth and Competence.tex', hrules=True)
    print('-'*20)
    print('\n')

    if df_name == 'df_jobs':
        # Warmth and Competence Probabilities
        print('-'*20)
        print(f'Continuous Summary {dvs_prob}')
        freq_dv_prob=rp.summarize(df[dvs_prob], ci_level = 0.95, decimals = 3)
        print(freq_dv_prob)
        freq_dv_prob.to_csv(f'{table_save_path}frequencies {df_name} - Warmth and Competence Probabilities.csv')
        freq_dv_prob.style.to_latex(f'{table_save_path}frequencies {df_name} - Warmth and Competence Probabilities.tex', hrules=True)
        print('-'*20)
        print('\n')

    print('-'*20)
    print('Grouped Frequencies/ Summary ANOVAs Categorical Gender and Age')
    summary_aova = rp.summary_cont(df.groupby(ivs)[dvs_prob], conf=0.95, decimals=3)
    print(summary_aova)
    summary_aova.to_csv(f'{table_save_path}summary anova {df_name} - {ivs} x {dvs}.csv')
    summary_aova.style.to_latex(f'{table_save_path}summary anova {df_name} - {ivs} x {dvs}.tex', hrules=True)
    print('-'*20)
    print('\n')

    for iv, dv in tqdm_product(ivs, dvs):
        print('-'*20)
        print(f'Grouped Frequencies/ Summary ANOVAs {dv} with {iv} Dummies')
        summary_aova_probs_dummy = rp.summary_cont(df_jobs[dv].groupby(df_jobs[iv]), conf=0.95, decimals=3)
        print(summary_aova_probs_dummy)
        summary_aova_probs_dummy.to_csv(f'{table_save_path}summary anova probabilities dummy {df_name} - {iv} x {dv}.csv')
        summary_aova_probs_dummy.style.to_latex(f'{table_save_path}summary anova probabilities dummy {df_name} - {iv} x {dv}.tex', hrules=True)
        print('-'*20)
        print('\n')

    if df_name == 'df_jobs':
        print('-'*20)
        print('Grouped Frequencies/ Summary ANOVAs')
        summary_aova_probs = rp.summary_cont(df.groupby(ivs)[dvs_all], conf=0.95, decimals=3)
        print(summary_aova_probs)
        summary_aova_probs.to_csv(f'{table_save_path}summary anova probabilities {df_name} - {ivs} x {dvs_all}.csv')
        summary_aova_probs.style.to_latex(f'{table_save_path}summary anova probabilities {df_name} - {ivs} x {dvs_all}.tex', hrules=True)
        print('-'*20)
        print('\n')

        for iv, dv in tqdm_product(ivs, dvs_all):
            print('-'*20)
            print(f'Grouped Frequencies/ Summary ANOVAs {dv} with {iv} Dummies')
            summary_aova_probs_dummy = rp.summary_cont(df_jobs[dv].groupby(df_jobs[iv]), conf=0.95, decimals=3)
            print(summary_aova_probs_dummy)
            summary_aova_probs_dummy.to_csv(f'{table_save_path}summary anova probabilities dummy {df_name} - {iv} x {dv}.csv')
            summary_aova_probs_dummy.style.to_latex(f'{table_save_path}summary anova probabilities dummy {df_name} - {iv} x {dv}.tex', hrules=True)
            print('-'*20)
            print('\n')

    # # Histogram
    # df[ivs_perc].hist()
    # plt.show()
    # plt.clf()
    # plt.cla()
    # plt.close()
    # print('-'*20)
    # print('\n')

    # df[ivs_count].hist()
    # plt.show()
    # plt.clf()
    # plt.cla()
    # plt.close()
    # print('-'*20)
    # print('\n')

    # df[ivs_dummy].hist()
    # plt.show()
    # plt.clf()
    # plt.cla()
    # plt.close()
    # print('-'*20)
    # print('\n')

    # if df_name == 'df_jobs':
    #     # Histogram
    #     df[dvs_prob].hist()
    #     plt.show()
    #     plt.clf()
    #     plt.cla()
    #     plt.close()
    #     print('-'*20)
    #     print('\n')

    # # QQ plot
    # qq_plot = pg.qqplot(df[ivs_perc], dist='norm')
    # plt.show()
    # plt.clf()
    # plt.cla()
    # plt.close()
    # print('-'*20)
    # print('\n')

    # qq_plot = pg.qqplot(df[ivs_count], dist='norm')
    # plt.show()
    # plt.clf()
    # plt.cla()
    # plt.close()
    # print('-'*20)
    # print('\n')

    # qq_plot = pg.qqplot(df[ivs_dummy], dist='norm')
    # plt.show()
    # plt.clf()
    # plt.cla()
    # plt.close()
    # print('-'*20)
    # print('\n')

    # if df_name == 'df_jobs':
    #     # QQ plot dvs_prob
    #     qq_plot = pg.qqplot(df[dvs_prob], dist='norm')
    #     plt.show()
    #     plt.clf()
    #     plt.cla()
    #     plt.close()
    #     print('-'*20)
    #     print('\n')

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_freq_and_normality_tests_interactive(df_name):
        run_freq_and_normality_tests(df_name=df_name, df=dataframes[df_name])
else:
    run_freq_and_normality_tests(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
# ~~~~~~~~~~~~~~~~~~~~
# --------------------
# Categorical Summary ['Gender', 'Age']
#   Variable    Outcome      Count  Percent
# 0  Gender   Mixed Gender  116458  37.92
# 1                   Male  112604  36.66
# 2                 Female   78092  25.42
# 3     Age      Mixed Age  197512  64.30
# 4                  Older   62705  20.41
# 5                Younger   46937  15.28
# --------------------
#
#
# --------------------
# Continuous Summary ['Gender_Female_% per Sector', 'Gender_Male_% per Sector', 'Age_Older_% per Sector', 'Age_Younger_% per Sector', 'Interaction_Female_Older_% per Sector', 'Interaction_Female_Younger_% per Sector', 'Interaction_Male_Older_% per Sector', 'Interaction_Male_Younger_% per Sector']
#                     Name                      N      Mean   Median  Variance     SD    SE             95% Conf. Interval
# 0               Gender_Female_% per Sector  307154   45.36   43.13     380.01   19.49 0.04               Gender_Female_% per Sector
# 1                 Gender_Male_% per Sector  307154   54.59   56.87     381.15   19.52 0.04                 Gender_Male_% per Sector
# 2                   Age_Older_% per Sector  307154   40.86   41.67     102.36   10.12 0.02                   Age_Older_% per Sector
# 3                 Age_Younger_% per Sector  307154   59.04   56.82      99.67    9.98 0.02                 Age_Younger_% per Sector
# 4    Interaction_Female_Older_% per Sector  307154 1846.01 1366.56  949147.19  974.24 1.76    Interaction_Female_Older_% per Sector
# 5  Interaction_Female_Younger_% per Sector  307154 2681.76 2843.37 1295544.05 1138.22 2.05  Interaction_Female_Younger_% per Sector
# 6      Interaction_Male_Older_% per Sector  307154 2238.91 1938.78 1233876.68 1110.80 2.00      Interaction_Male_Older_% per Sector
# 7    Interaction_Male_Younger_% per Sector  307154 3219.13 3571.64 1458614.94 1207.73 2.18    Interaction_Male_Younger_% per Sector
# --------------------
#
#
# --------------------
# Continuous Summary ['Gender_Female', 'Gender_Mixed', 'Gender_Male', 'Age_Older', 'Age_Mixed', 'Age_Younger']
#        Name         N    Mean Median Variance  SD   SE  95% Conf. Interval
# 0  Gender_Female  307154 0.25  0.00    0.19   0.43 0.00    Gender_Female
# 1   Gender_Mixed  307154 0.38  0.00    0.23   0.48 0.00     Gender_Mixed
# 2    Gender_Male  307154 0.37  0.00    0.23   0.48 0.00      Gender_Male
# 3      Age_Older  307154 0.20  0.00    0.16   0.40 0.00        Age_Older
# 4      Age_Mixed  307154 0.64  1.00    0.23   0.48 0.00        Age_Mixed
# 5    Age_Younger  307154 0.15  0.00    0.13   0.36 0.00      Age_Younger
# --------------------
#
#
# --------------------
# Continuous Summary ['Gender_Female_n', 'Gender_Male_n', 'Age_Older_n', 'Age_Younger_n']
#         Name          N     Mean  Median  Variance     SD    SE  95% Conf. Interval
# 0  Gender_Female_n  307154 656.79 226.00 1097921.45 1047.82 1.89   Gender_Female_n
# 1    Gender_Male_n  307154 712.05 210.00 1526476.65 1235.51 2.23     Gender_Male_n
# 2      Age_Older_n  307154 528.39 205.00  634870.20  796.79 1.44       Age_Older_n
# 3    Age_Younger_n  307154 840.04 288.00 2067645.80 1437.93 2.60     Age_Younger_n
# --------------------
#
#
# --------------------
# Categorical Summary ['Warmth', 'Competence']
#     Variable   Outcome   Count  Percent
# 0      Warmth     0     211878  68.98
# 1                 1      95276  31.02
# 2  Competence     1     158797  51.70
# 3                 0     148357  48.30
# --------------------
#
#
# --------------------
# Continuous Summary ['Warmth_Probability', 'Competence_Probability']
#             Name             N    Mean Median Variance  SD   SE     95% Conf. Interval
# 0      Warmth_Probability  307154 0.31  0.07    0.14   0.38 0.00      Warmth_Probability
# 1  Competence_Probability  307154 0.47  0.54    0.12   0.35 0.00  Competence_Probability
# --------------------
#
#
# --------------------
# Grouped Frequencies/ Summary ANOVAs Categorical Gender and Age
#
#
#                        Warmth_Probability                                   Competence_Probability
#                                N          Mean  SD   SE  95% Conf. Interval           N            Mean  SD   SE  95% Conf. Interval
# Gender       Age
# Female       Older                0        NaN  NaN  NaN     NaN      NaN                0          NaN  NaN  NaN     NaN      NaN
#              Mixed Age        78092       0.32 0.38 0.00    0.31     0.32            78092         0.45 0.35 0.00    0.44     0.45
#              Younger              0        NaN  NaN  NaN     NaN      NaN                0          NaN  NaN  NaN     NaN      NaN
# Mixed Gender Older            12766       0.30 0.37 0.00    0.29     0.31            12766         0.50 0.35 0.00    0.50     0.51
#              Mixed Age        56755       0.34 0.38 0.00    0.34     0.35            56755         0.48 0.35 0.00    0.47     0.48
#              Younger          46937       0.34 0.38 0.00    0.34     0.34            46937         0.46 0.35 0.00    0.45     0.46
# Male         Older            49939       0.29 0.37 0.00    0.29     0.30            49939         0.49 0.35 0.00    0.49     0.50
#              Mixed Age        62665       0.29 0.36 0.00    0.29     0.29            62665         0.48 0.35 0.00    0.48     0.48
#              Younger              0        NaN  NaN  NaN     NaN      NaN                0          NaN  NaN  NaN     NaN      NaN
# --------------------
#   0%|          | 0/4 [00:00<?, ?it/s]
# --------------------
# Grouped Frequencies/ Summary ANOVAs Warmth with Gender Dummies
#
#
#                  N    Mean  SD   SE   95% Conf.  Interval
# Gender
# Female         78092  0.31 0.46 0.00    0.31       0.32
# Mixed Gender  116458  0.34 0.47 0.00    0.33       0.34
# Male          112604  0.28 0.45 0.00    0.28       0.28
# --------------------
#
#
# --------------------
# Grouped Frequencies/ Summary ANOVAs Competence with Gender Dummies
#
#
#                  N    Mean  SD   SE   95% Conf.  Interval
# Gender
# Female         78092  0.48 0.50 0.00    0.48       0.49
# Mixed Gender  116458  0.52 0.50 0.00    0.52       0.52
# Male          112604  0.54 0.50 0.00    0.54       0.54
# --------------------
#
#
# --------------------
# Grouped Frequencies/ Summary ANOVAs Warmth with Age Dummies
#
#
#               N    Mean  SD   SE   95% Conf.  Interval
# Age
# Older       62705  0.29 0.45 0.00    0.28       0.29
# Mixed Age  197512  0.31 0.46 0.00    0.31       0.31
# Younger     46937  0.34 0.47 0.00    0.34       0.34
# --------------------
#
#
# --------------------
# Grouped Frequencies/ Summary ANOVAs Competence with Age Dummies
#
#
#               N    Mean  SD   SE   95% Conf.  Interval
# Age
# Older       62705  0.55 0.50 0.00    0.55       0.56
# Mixed Age  197512  0.51 0.50 0.00    0.51       0.51
# Younger     46937  0.49 0.50 0.00    0.49       0.50
# --------------------
#
#
# --------------------
# Grouped Frequencies/ Summary ANOVAs
#
#
#                        Warmth                                   Competence                                   Warmth_Probability                                   Competence_Probability
#                          N    Mean  SD   SE  95% Conf. Interval     N      Mean  SD   SE  95% Conf. Interval         N          Mean  SD   SE  95% Conf. Interval           N            Mean  SD   SE  95% Conf. Interval
# Gender       Age
# Female       Older          0  NaN  NaN  NaN     NaN      NaN          0    NaN  NaN  NaN     NaN      NaN              0        NaN  NaN  NaN     NaN      NaN                0          NaN  NaN  NaN     NaN      NaN
#              Mixed Age  78092 0.31 0.46 0.00    0.31     0.32      78092   0.48 0.50 0.00    0.48     0.49          78092       0.32 0.38 0.00    0.31     0.32            78092         0.45 0.35 0.00    0.44     0.45
#              Younger        0  NaN  NaN  NaN     NaN      NaN          0    NaN  NaN  NaN     NaN      NaN              0        NaN  NaN  NaN     NaN      NaN                0          NaN  NaN  NaN     NaN      NaN
# Mixed Gender Older      12766 0.29 0.46 0.00    0.29     0.30      12766   0.56 0.50 0.00    0.55     0.57          12766       0.30 0.37 0.00    0.29     0.31            12766         0.50 0.35 0.00    0.50     0.51
#              Mixed Age  56755 0.34 0.47 0.00    0.34     0.34      56755   0.53 0.50 0.00    0.52     0.53          56755       0.34 0.38 0.00    0.34     0.35            56755         0.48 0.35 0.00    0.47     0.48
#              Younger    46937 0.34 0.47 0.00    0.34     0.34      46937   0.49 0.50 0.00    0.49     0.50          46937       0.34 0.38 0.00    0.34     0.34            46937         0.46 0.35 0.00    0.45     0.46
# Male         Older      49939 0.29 0.45 0.00    0.28     0.29      49939   0.55 0.50 0.00    0.54     0.55          49939       0.29 0.37 0.00    0.29     0.30            49939         0.49 0.35 0.00    0.49     0.50
#              Mixed Age  62665 0.28 0.45 0.00    0.28     0.28      62665   0.53 0.50 0.00    0.53     0.54          62665       0.29 0.36 0.00    0.29     0.29            62665         0.48 0.35 0.00    0.48     0.48
#              Younger        0  NaN  NaN  NaN     NaN      NaN          0    NaN  NaN  NaN     NaN      NaN              0        NaN  NaN  NaN     NaN      NaN                0          NaN  NaN  NaN     NaN      NaN
# --------------------
#   0%|          | 0/8 [00:00<?, ?it/s]
# --------------------
# Grouped Frequencies/ Summary ANOVAs Warmth with Gender Dummies
#
#
#                  N    Mean  SD   SE   95% Conf.  Interval
# Gender
# Female         78092  0.31 0.46 0.00    0.31       0.32
# Mixed Gender  116458  0.34 0.47 0.00    0.33       0.34
# Male          112604  0.28 0.45 0.00    0.28       0.28
# --------------------
#
#
# --------------------
# Grouped Frequencies/ Summary ANOVAs Competence with Gender Dummies
#
#
#                  N    Mean  SD   SE   95% Conf.  Interval
# Gender
# Female         78092  0.48 0.50 0.00    0.48       0.49
# Mixed Gender  116458  0.52 0.50 0.00    0.52       0.52
# Male          112604  0.54 0.50 0.00    0.54       0.54
# --------------------
#
#
# --------------------
# Grouped Frequencies/ Summary ANOVAs Warmth_Probability with Gender Dummies
#
#
#                  N    Mean  SD   SE   95% Conf.  Interval
# Gender
# Female         78092  0.32 0.38 0.00    0.31       0.32
# Mixed Gender  116458  0.34 0.38 0.00    0.34       0.34
# Male          112604  0.29 0.37 0.00    0.29       0.29
# --------------------
#
#
# --------------------
# Grouped Frequencies/ Summary ANOVAs Competence_Probability with Gender Dummies
#
#
#                  N    Mean  SD   SE   95% Conf.  Interval
# Gender
# Female         78092  0.45 0.35 0.00    0.44       0.45
# Mixed Gender  116458  0.47 0.35 0.00    0.47       0.47
# Male          112604  0.49 0.35 0.00    0.48       0.49
# --------------------
#
#
# --------------------
# Grouped Frequencies/ Summary ANOVAs Warmth with Age Dummies
#
#
#               N    Mean  SD   SE   95% Conf.  Interval
# Age
# Older       62705  0.29 0.45 0.00    0.28       0.29
# Mixed Age  197512  0.31 0.46 0.00    0.31       0.31
# Younger     46937  0.34 0.47 0.00    0.34       0.34
# --------------------
#
#
# --------------------
# Grouped Frequencies/ Summary ANOVAs Competence with Age Dummies
#
#
#               N    Mean  SD   SE   95% Conf.  Interval
# Age
# Older       62705  0.55 0.50 0.00    0.55       0.56
# Mixed Age  197512  0.51 0.50 0.00    0.51       0.51
# Younger     46937  0.49 0.50 0.00    0.49       0.50
# --------------------
#
#
# --------------------
# Grouped Frequencies/ Summary ANOVAs Warmth_Probability with Age Dummies
#
#
#               N    Mean  SD   SE   95% Conf.  Interval
# Age
# Older       62705  0.29 0.37 0.00    0.29       0.30
# Mixed Age  197512  0.32 0.38 0.00    0.31       0.32
# Younger     46937  0.34 0.38 0.00    0.34       0.34
# --------------------
#
#
# --------------------
# Grouped Frequencies/ Summary ANOVAs Competence_Probability with Age Dummies
#
#
#               N    Mean  SD   SE   95% Conf.  Interval
# Age
# Older       62705  0.50 0.35 0.00    0.49       0.50
# Mixed Age  197512  0.47 0.35 0.00    0.46       0.47
# Younger     46937  0.46 0.35 0.00    0.45       0.46
# --------------------
#
#
# CPU times: user 794 ms, sys: 189 ms, total: 983 ms
# Wall time: 2.05 s

# %% [markdown]
# # Normality Tests

# %%
def run_normality_tests(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    if df_name == 'df_manual':
        dvs_ = dvs
    elif df_name == 'df_jobs':
        dvs_ = dvs_all

    # Test of Normality for skew and kurtosis
    # if p < alpha, the null hypothesis is rejected,\nis not from a normal distribution
    norm = scipy.stats.normaltest(df[dvs_])
    print('\n')
    print('='*80)
    print(f'{dvs_} Test of Normality:')
    print('-'*80)
    for key, val in dict(zip(normality_tests_labels, norm)).items():
        print(key,': ', val) # not significant
    print('\n')

    # Shapir-Wilk Test of Normality
    # if p < alpha, the null hypothesis is rejected,\nis not from a normal distribution
    norm_res = scipy.stats.shapiro(df[dvs_])
    print('\n')
    print('='*80)
    print(f'{dvs_} Shapir-Wilk Test of Normality:')
    print('-'*80)
    for key, val in dict(zip(normality_tests_labels, norm_res)).items():
        print(key,': ', val) # significant
    print('\n')

    for dv, iv in tqdm_product(dvs_, ivs_dummy_perc_and_perc_interactions):
        print('\n')
        print('+'*120)
        print(f'Dependent Variable: {dv}\nIndependent Variable: {iv}')
        print('\n')
        print('~' * 20)

        # Anderson-Darling Test of Normality
        # if p < alpha, the null hypothesis is rejected, x is not from a normal distribution
        norm_and = scipy.stats.anderson(df[dv])
        print('\n')
        print('='*80)
        print('Anderson-Darling Test of Normality:')
        print('\n')
        print('~' * 20)
        print(f'{iv} x {dv}')
        for key, val in dict(zip(normality_tests_labels, norm_and)).items():
            print(key,': ', val) # not significant
        print('\n')
        if norm_and.fit_result.success:
            print('Anderson-Darling Test of Normality: The test was successful.')
        else:
            print('Anderson-Darling Test of Normality: The test was not successful.')
        print('~' * 20)
        print('\n')

        # NORMALITY TESTS
        print('\n')
        print('='*80)
        print('NORMALITY TEST')
        print('\n')
        print('~' * 20)
        print(f'{iv} x {dv}')
        norm = pg.normality(data=df, dv=dv, group=iv).round(3)
        if normal := all(norm.normal == True):
            print(f"{iv} x {dv} Normality test: All groups are normally distributed.")
        else:
            print(f"{iv} x {dv} Normality test: Not all groups are normally distributed.")
        print(f"{iv} x {dv} Normality test:\n{norm}")
        norm.to_csv(f'{table_save_path}normality {df_name} - {iv} x {dv}.csv')
        norm.style.to_latex(f'{table_save_path}normality {df_name} - {iv} x {dv}.tex', hrules=True)
        print('~' * 20)
        print('\n')

        # # ANOVA SPHERICITY TEST
        # print('\n')
        # print('='*80)
        # print('SPHERICITY TEST')
        # print('\n')
        # print('~' * 20)
        # print(f'{iv} x {dv}')
        # spher_all = pg.sphericity(data=df, dv=dv, within=iv, method='mauchly')
        # spher, test_stat, chisq, dof, pval = spher_all
        # print('-' * 20)
        # print(f"{iv} x {dv} Sphericity test:\n{spher} at p-value: {round(pval, 3)}, chi-square: {round(chisq, 3)}, degrees of freedom: {round(dof)}, Test statistic: {round(test_stat)}") # if p-value < 0.05, then the data are not spherically distributed = Multivariate analysis
        # # spher.to_csv(f'{table_save_path}sphericity {df_name} - {iv} x {dv}.csv')
        # # spher.style.to_latex(f'{table_save_path}sphericity {df_name} - {iv} x {dv}.tex', hrules=True)
        # print('~' * 20)
        # print('\n')

        # BARTLETTS TESTS
        print('\n')
        print('='*80)
        print("BARTLETT'S TEST")
        print('\n')
        print('~' * 20)
        print(f'{iv} x {dv}')
        bartlett = pg.homoscedasticity(data=df, dv=dv, group=iv, method='bartlett').round(3) #dv
        if equal_var_bartlett := eval(bartlett.equal_var.to_string(index=False)):
            print(f"{iv} x {dv} Bartlett's test: All groups have equal variances.")
        else:
            print(f"{iv} x {dv} Bartlett's test: Not all groups have equal variances.")
        print(f"{iv} x {dv} Bartlett's test:\n{bartlett}")
        bartlett.to_csv(f"{table_save_path}bartlett's {df_name} - {iv} x {dv}.csv")
        bartlett.style.to_latex(f"{table_save_path}bartlett's {df_name} - {iv} x {dv}.tex")
        print('~' * 20)
        print('\n')

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_normality_tests_interactive(df_name):
        run_normality_tests(df_name=df_name, df=dataframes[df_name])
else:
    run_normality_tests(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#
#
# ================================================================================
# ['Warmth', 'Competence', 'Warmth_Probability', 'Competence_Probability'] Test of Normality:
# --------------------------------------------------------------------------------
# Statistic :  [4682419.34807615 1049106.49887276  370304.24972688 1308837.29801538]
# p-value :  [0. 0. 0. 0.]
#
#
#
#
# ================================================================================
# ['Warmth', 'Competence', 'Warmth_Probability', 'Competence_Probability'] Shapir-Wilk Test of Normality:
# --------------------------------------------------------------------------------
# Statistic :  0.7383739352226257
# p-value :  0.0
#   0%|          | 0/56 [00:00<?, ?it/s]
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Warmth
# Independent Variable: Gender_Female
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Female x Warmth
# Statistic :  65855.49314465217
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Female x Warmth
# Gender_Female x Warmth Normality test: Not all groups are normally distributed.
# Gender_Female x Warmth Normality test:
#                 W   pval  normal
# Gender_Female
# 0             0.58  0.00   False
# 1             0.58  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Female x Warmth
# Gender_Female x Warmth Bartlett's test: All groups have equal variances.
# Gender_Female x Warmth Bartlett's test:
#            T   pval  equal_var
# bartlett 0.70  0.40    True
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Warmth
# Independent Variable: Gender_Mixed
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Mixed x Warmth
# Statistic :  65855.49314465217
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Mixed x Warmth
# Gender_Mixed x Warmth Normality test: Not all groups are normally distributed.
# Gender_Mixed x Warmth Normality test:
#                W   pval  normal
# Gender_Mixed
# 1            0.60  0.00   False
# 0            0.57  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Mixed x Warmth
# Gender_Mixed x Warmth Bartlett's test: Not all groups have equal variances.
# Gender_Mixed x Warmth Bartlett's test:
#             T    pval  equal_var
# bartlett 175.65  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Warmth
# Independent Variable: Gender_Male
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Male x Warmth
# Statistic :  65855.49314465217
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Male x Warmth
# Gender_Male x Warmth Normality test: Not all groups are normally distributed.
# Gender_Male x Warmth Normality test:
#               W   pval  normal
# Gender_Male
# 0           0.59  0.00   False
# 1           0.56  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Male x Warmth
# Gender_Male x Warmth Bartlett's test: Not all groups have equal variances.
# Gender_Male x Warmth Bartlett's test:
#             T    pval  equal_var
# bartlett 227.63  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Warmth
# Independent Variable: Gender_Female_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Female_% per Sector x Warmth
# Statistic :  65855.49314465217
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Female_% per Sector x Warmth
# Gender_Female_% per Sector x Warmth Normality test: Not all groups are normally distributed.
# Gender_Female_% per Sector x Warmth Normality test:
#                              W   pval  normal
# Gender_Female_% per Sector
# 43.13                      0.59  0.00   False
# 42.75                      0.59  0.00   False
# 50.25                      0.60  0.00   False
# 68.15                      0.56  0.00   False
# 12.50                      0.54  0.00   False
# 24.61                      0.56  0.00   False
# 22.72                      0.57  0.00   False
# 84.30                      0.59  0.00   False
# 48.53                      0.59  0.00   False
# 65.13                      0.58  0.00   False
# 27.59                      0.56  0.00   False
# 56.78                      0.61  0.00   False
# 22.16                      0.56  0.00   False
# 19.44                      0.59  0.00   False
# 42.13                      0.54  0.00   False
# 65.91                      0.59  0.00   False
# 39.42                      0.56  0.00   False
# 20.92                      0.53  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Female_% per Sector x Warmth
# Gender_Female_% per Sector x Warmth Bartlett's test: Not all groups have equal variances.
# Gender_Female_% per Sector x Warmth Bartlett's test:
#             T    pval  equal_var
# bartlett 472.68  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Warmth
# Independent Variable: Gender_Male_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Male_% per Sector x Warmth
# Statistic :  65855.49314465217
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Male_% per Sector x Warmth
# Gender_Male_% per Sector x Warmth Normality test: Not all groups are normally distributed.
# Gender_Male_% per Sector x Warmth Normality test:
#                            W   pval  normal
# Gender_Male_% per Sector
# 56.87                    0.59  0.00   False
# 57.25                    0.59  0.00   False
# 49.49                    0.60  0.00   False
# 31.85                    0.56  0.00   False
# 87.50                    0.54  0.00   False
# 75.39                    0.56  0.00   False
# 77.28                    0.57  0.00   False
# 15.63                    0.59  0.00   False
# 51.47                    0.59  0.00   False
# 34.87                    0.58  0.00   False
# 72.41                    0.56  0.00   False
# 42.96                    0.61  0.00   False
# 77.84                    0.56  0.00   False
# 80.56                    0.59  0.00   False
# 57.87                    0.54  0.00   False
# 34.09                    0.59  0.00   False
# 60.58                    0.56  0.00   False
# 79.08                    0.53  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Male_% per Sector x Warmth
# Gender_Male_% per Sector x Warmth Bartlett's test: Not all groups have equal variances.
# Gender_Male_% per Sector x Warmth Bartlett's test:
#             T    pval  equal_var
# bartlett 472.68  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Warmth
# Independent Variable: Age_Older
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Older x Warmth
# Statistic :  65855.49314465217
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Older x Warmth
# Age_Older x Warmth Normality test: Not all groups are normally distributed.
# Age_Older x Warmth Normality test:
#             W   pval  normal
# Age_Older
# 0         0.58  0.00   False
# 1         0.57  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Older x Warmth
# Age_Older x Warmth Bartlett's test: Not all groups have equal variances.
# Age_Older x Warmth Bartlett's test:
#             T   pval  equal_var
# bartlett 67.01  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Warmth
# Independent Variable: Age_Mixed
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Mixed x Warmth
# Statistic :  65855.49314465217
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Mixed x Warmth
# Age_Mixed x Warmth Normality test: Not all groups are normally distributed.
# Age_Mixed x Warmth Normality test:
#             W   pval  normal
# Age_Mixed
# 1         0.58  0.00   False
# 0         0.58  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Mixed x Warmth
# Age_Mixed x Warmth Bartlett's test: All groups have equal variances.
# Age_Mixed x Warmth Bartlett's test:
#            T   pval  equal_var
# bartlett 0.00  0.95    True
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Warmth
# Independent Variable: Age_Younger
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger x Warmth
# Statistic :  65855.49314465217
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger x Warmth
# Age_Younger x Warmth Normality test: Not all groups are normally distributed.
# Age_Younger x Warmth Normality test:
#               W   pval  normal
# Age_Younger
# 0           0.58  0.00   False
# 1           0.60  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger x Warmth
# Age_Younger x Warmth Bartlett's test: Not all groups have equal variances.
# Age_Younger x Warmth Bartlett's test:
#             T   pval  equal_var
# bartlett 63.56  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Warmth
# Independent Variable: Age_Older_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Older_% per Sector x Warmth
# Statistic :  65855.49314465217
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Older_% per Sector x Warmth
# Age_Older_% per Sector x Warmth Normality test: Not all groups are normally distributed.
# Age_Older_% per Sector x Warmth Normality test:
#                          W   pval  normal
# Age_Older_% per Sector
# 34.09                  0.59  0.00   False
# 31.96                  0.59  0.00   False
# 18.94                  0.60  0.00   False
# 48.82                  0.56  0.00   False
# 47.62                  0.54  0.00   False
# 53.11                  0.56  0.00   False
# 53.92                  0.57  0.00   False
# 46.13                  0.59  0.00   False
# 52.94                  0.59  0.00   False
# 46.68                  0.58  0.00   False
# 32.76                  0.56  0.00   False
# 38.94                  0.61  0.00   False
# 49.32                  0.56  0.00   False
# 58.33                  0.59  0.00   False
# 51.72                  0.54  0.00   False
# 35.69                  0.54  0.00   False
# 41.67                  0.59  0.00   False
# 53.28                  0.56  0.00   False
# 52.72                  0.53  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Older_% per Sector x Warmth
# Age_Older_% per Sector x Warmth Bartlett's test: Not all groups have equal variances.
# Age_Older_% per Sector x Warmth Bartlett's test:
#             T    pval  equal_var
# bartlett 480.94  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Warmth
# Independent Variable: Age_Younger_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger_% per Sector x Warmth
# Statistic :  65855.49314465217
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger_% per Sector x Warmth
# Age_Younger_% per Sector x Warmth Normality test: Not all groups are normally distributed.
# Age_Younger_% per Sector x Warmth Normality test:
#                            W   pval  normal
# Age_Younger_% per Sector
# 65.92                    0.59  0.00   False
# 67.83                    0.59  0.00   False
# 80.81                    0.60  0.00   False
# 51.18                    0.56  0.00   False
# 52.98                    0.54  0.00   False
# 46.89                    0.56  0.00   False
# 46.21                    0.57  0.00   False
# 53.73                    0.59  0.00   False
# 48.53                    0.59  0.00   False
# 53.14                    0.58  0.00   False
# 67.24                    0.56  0.00   False
# 60.55                    0.61  0.00   False
# 50.61                    0.56  0.00   False
# 44.44                    0.59  0.00   False
# 44.83                    0.54  0.00   False
# 64.26                    0.54  0.00   False
# 56.82                    0.59  0.00   False
# 46.72                    0.56  0.00   False
# 47.18                    0.53  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger_% per Sector x Warmth
# Age_Younger_% per Sector x Warmth Bartlett's test: Not all groups have equal variances.
# Age_Younger_% per Sector x Warmth Bartlett's test:
#             T    pval  equal_var
# bartlett 480.94  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Warmth
# Independent Variable: Interaction_Female_Older_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Older_% per Sector x Warmth
# Statistic :  65855.49314465217
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Older_% per Sector x Warmth
# Interaction_Female_Older_% per Sector x Warmth Normality test: Not all groups are normally distributed.
# Interaction_Female_Older_% per Sector x Warmth Normality test:
#                                         W   pval  normal
# Interaction_Female_Older_% per Sector
# 1470.63                               0.59  0.00   False
# 1366.56                               0.59  0.00   False
# 951.75                                0.60  0.00   False
# 3327.58                               0.56  0.00   False
# 595.24                                0.54  0.00   False
# 1307.08                               0.56  0.00   False
# 1224.73                               0.57  0.00   False
# 3888.45                               0.59  0.00   False
# 2569.20                               0.59  0.00   False
# 3040.16                               0.58  0.00   False
# 903.69                                0.56  0.00   False
# 2211.43                               0.61  0.00   False
# 1092.89                               0.56  0.00   False
# 1134.26                               0.59  0.00   False
# 1426.87                               0.54  0.00   False
# 1503.89                               0.54  0.00   False
# 2746.21                               0.59  0.00   False
# 2100.27                               0.56  0.00   False
# 1102.90                               0.53  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Older_% per Sector x Warmth
# Interaction_Female_Older_% per Sector x Warmth Bartlett's test: Not all groups have equal variances.
# Interaction_Female_Older_% per Sector x Warmth Bartlett's test:
#             T    pval  equal_var
# bartlett 480.94  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Warmth
# Independent Variable: Interaction_Female_Younger_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Younger_% per Sector x Warmth
# Statistic :  65855.49314465217
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Younger_% per Sector x Warmth
# Interaction_Female_Younger_% per Sector x Warmth Normality test: Not all groups are normally distributed.
# Interaction_Female_Younger_% per Sector x Warmth Normality test:
#                                           W   pval  normal
# Interaction_Female_Younger_% per Sector
# 2843.37                                 0.59  0.00   False
# 2900.09                                 0.59  0.00   False
# 4060.81                                 0.60  0.00   False
# 3487.87                                 0.56  0.00   False
# 662.20                                  0.54  0.00   False
# 1154.06                                 0.56  0.00   False
# 1049.77                                 0.57  0.00   False
# 4529.66                                 0.59  0.00   False
# 2355.10                                 0.59  0.00   False
# 3460.74                                 0.58  0.00   False
# 1854.93                                 0.56  0.00   False
# 3438.42                                 0.61  0.00   False
# 1121.40                                 0.56  0.00   False
# 864.20                                  0.59  0.00   False
# 1236.62                                 0.54  0.00   False
# 2707.41                                 0.54  0.00   False
# 3744.83                                 0.59  0.00   False
# 1841.33                                 0.56  0.00   False
# 987.02                                  0.53  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Younger_% per Sector x Warmth
# Interaction_Female_Younger_% per Sector x Warmth Bartlett's test: Not all groups have equal variances.
# Interaction_Female_Younger_% per Sector x Warmth Bartlett's test:
#             T    pval  equal_var
# bartlett 480.94  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Warmth
# Independent Variable: Interaction_Male_Older_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Male_Older_% per Sector x Warmth
# Statistic :  65855.49314465217
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Male_Older_% per Sector x Warmth
# Interaction_Male_Older_% per Sector x Warmth Normality test: Not all groups are normally distributed.
# Interaction_Male_Older_% per Sector x Warmth Normality test:
#                                       W   pval  normal
# Interaction_Male_Older_% per Sector
# 1938.77                             0.59  0.00   False
# 1829.74                             0.59  0.00   False
# 937.40                              0.60  0.00   False
# 1554.83                             0.56  0.00   False
# 4166.67                             0.54  0.00   False
# 4003.80                             0.56  0.00   False
# 4166.91                             0.57  0.00   False
# 721.04                              0.59  0.00   False
# 2724.91                             0.59  0.00   False
# 1627.74                             0.58  0.00   False
# 2372.18                             0.56  0.00   False
# 1673.25                             0.61  0.00   False
# 3839.21                             0.56  0.00   False
# 4699.07                             0.59  0.00   False
# 3745.54                             0.54  0.00   False
# 2065.43                             0.54  0.00   False
# 1420.45                             0.59  0.00   False
# 3228.20                             0.56  0.00   False
# 4169.11                             0.53  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Male_Older_% per Sector x Warmth
# Interaction_Male_Older_% per Sector x Warmth Bartlett's test: Not all groups have equal variances.
# Interaction_Male_Older_% per Sector x Warmth Bartlett's test:
#             T    pval  equal_var
# bartlett 480.94  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Warmth
# Independent Variable: Interaction_Male_Younger_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Male_Younger_% per Sector x Warmth
# Statistic :  65855.49314465217
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Male_Younger_% per Sector x Warmth
# Interaction_Male_Younger_% per Sector x Warmth Normality test: Not all groups are normally distributed.
# Interaction_Male_Younger_% per Sector x Warmth Normality test:
#                                         W   pval  normal
# Interaction_Male_Younger_% per Sector
# 3748.49                               0.59  0.00   False
# 3883.05                               0.59  0.00   False
# 3999.59                               0.60  0.00   False
# 1629.72                               0.56  0.00   False
# 4635.42                               0.54  0.00   False
# 3535.06                               0.56  0.00   False
# 3571.64                               0.57  0.00   False
# 839.94                                0.59  0.00   False
# 2497.84                               0.59  0.00   False
# 1852.92                               0.58  0.00   False
# 4869.20                               0.56  0.00   False
# 2601.64                               0.61  0.00   False
# 3939.36                               0.56  0.00   False
# 3580.25                               0.59  0.00   False
# 3246.14                               0.54  0.00   False
# 3718.35                               0.54  0.00   False
# 1936.98                               0.59  0.00   False
# 2830.20                               0.56  0.00   False
# 3731.08                               0.53  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Male_Younger_% per Sector x Warmth
# Interaction_Male_Younger_% per Sector x Warmth Bartlett's test: Not all groups have equal variances.
# Interaction_Male_Younger_% per Sector x Warmth Bartlett's test:
#             T    pval  equal_var
# bartlett 480.94  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence
# Independent Variable: Gender_Female
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Female x Competence
# Statistic :  55262.6559407583
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Female x Competence
# Gender_Female x Competence Normality test: Not all groups are normally distributed.
# Gender_Female x Competence Normality test:
#                 W   pval  normal
# Gender_Female
# 0             0.64  0.00   False
# 1             0.64  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Female x Competence
# Gender_Female x Competence Bartlett's test: All groups have equal variances.
# Gender_Female x Competence Bartlett's test:
#            T   pval  equal_var
# bartlett 0.14  0.71    True
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence
# Independent Variable: Gender_Mixed
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Mixed x Competence
# Statistic :  55262.6559407583
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Mixed x Competence
# Gender_Mixed x Competence Normality test: Not all groups are normally distributed.
# Gender_Mixed x Competence Normality test:
#                W   pval  normal
# Gender_Mixed
# 1            0.64  0.00   False
# 0            0.64  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Mixed x Competence
# Gender_Mixed x Competence Bartlett's test: All groups have equal variances.
# Gender_Mixed x Competence Bartlett's test:
#            T   pval  equal_var
# bartlett 0.00  0.97    True
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence
# Independent Variable: Gender_Male
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Male x Competence
# Statistic :  55262.6559407583
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Male x Competence
# Gender_Male x Competence Normality test: Not all groups are normally distributed.
# Gender_Male x Competence Normality test:
#               W   pval  normal
# Gender_Male
# 0           0.64  0.00   False
# 1           0.63  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Male x Competence
# Gender_Male x Competence Bartlett's test: All groups have equal variances.
# Gender_Male x Competence Bartlett's test:
#            T   pval  equal_var
# bartlett 1.34  0.25    True
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence
# Independent Variable: Gender_Female_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Female_% per Sector x Competence
# Statistic :  55262.6559407583
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Female_% per Sector x Competence
# Gender_Female_% per Sector x Competence Normality test: Not all groups are normally distributed.
# Gender_Female_% per Sector x Competence Normality test:
#                              W   pval  normal
# Gender_Female_% per Sector
# 43.13                      0.63  0.00   False
# 42.75                      0.64  0.00   False
# 50.25                      0.64  0.00   False
# 68.15                      0.64  0.00   False
# 12.50                      0.63  0.00   False
# 24.61                      0.63  0.00   False
# 22.72                      0.63  0.00   False
# 84.30                      0.64  0.00   False
# 48.53                      0.63  0.00   False
# 65.13                      0.64  0.00   False
# 27.59                      0.64  0.00   False
# 56.78                      0.64  0.00   False
# 22.16                      0.64  0.00   False
# 19.44                      0.64  0.00   False
# 42.13                      0.63  0.00   False
# 65.91                      0.64  0.00   False
# 39.42                      0.63  0.00   False
# 20.92                      0.62  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Female_% per Sector x Competence
# Gender_Female_% per Sector x Competence Bartlett's test: All groups have equal variances.
# Gender_Female_% per Sector x Competence Bartlett's test:
#            T   pval  equal_var
# bartlett 8.62  0.95    True
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence
# Independent Variable: Gender_Male_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Male_% per Sector x Competence
# Statistic :  55262.6559407583
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Male_% per Sector x Competence
# Gender_Male_% per Sector x Competence Normality test: Not all groups are normally distributed.
# Gender_Male_% per Sector x Competence Normality test:
#                            W   pval  normal
# Gender_Male_% per Sector
# 56.87                    0.63  0.00   False
# 57.25                    0.64  0.00   False
# 49.49                    0.64  0.00   False
# 31.85                    0.64  0.00   False
# 87.50                    0.63  0.00   False
# 75.39                    0.63  0.00   False
# 77.28                    0.63  0.00   False
# 15.63                    0.64  0.00   False
# 51.47                    0.63  0.00   False
# 34.87                    0.64  0.00   False
# 72.41                    0.64  0.00   False
# 42.96                    0.64  0.00   False
# 77.84                    0.64  0.00   False
# 80.56                    0.64  0.00   False
# 57.87                    0.63  0.00   False
# 34.09                    0.64  0.00   False
# 60.58                    0.63  0.00   False
# 79.08                    0.62  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Gender_Male_% per Sector x Competence
# Gender_Male_% per Sector x Competence Bartlett's test: All groups have equal variances.
# Gender_Male_% per Sector x Competence Bartlett's test:
#            T   pval  equal_var
# bartlett 8.62  0.95    True
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence
# Independent Variable: Age_Older
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Older x Competence
# Statistic :  55262.6559407583
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Older x Competence
# Age_Older x Competence Normality test: Not all groups are normally distributed.
# Age_Older x Competence Normality test:
#             W   pval  normal
# Age_Older
# 0         0.64  0.00   False
# 1         0.63  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Older x Competence
# Age_Older x Competence Bartlett's test: All groups have equal variances.
# Age_Older x Competence Bartlett's test:
#            T   pval  equal_var
# bartlett 2.50  0.11    True
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence
# Independent Variable: Age_Mixed
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Mixed x Competence
# Statistic :  55262.6559407583
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Mixed x Competence
# Age_Mixed x Competence Normality test: Not all groups are normally distributed.
# Age_Mixed x Competence Normality test:
#             W   pval  normal
# Age_Mixed
# 1         0.64  0.00   False
# 0         0.64  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Mixed x Competence
# Age_Mixed x Competence Bartlett's test: All groups have equal variances.
# Age_Mixed x Competence Bartlett's test:
#            T   pval  equal_var
# bartlett 0.20  0.66    True
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence
# Independent Variable: Age_Younger
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger x Competence
# Statistic :  55262.6559407583
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger x Competence
# Age_Younger x Competence Normality test: Not all groups are normally distributed.
# Age_Younger x Competence Normality test:
#               W   pval  normal
# Age_Younger
# 0           0.64  0.00   False
# 1           0.64  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger x Competence
# Age_Younger x Competence Bartlett's test: All groups have equal variances.
# Age_Younger x Competence Bartlett's test:
#            T   pval  equal_var
# bartlett 0.06  0.81    True
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence
# Independent Variable: Age_Older_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Older_% per Sector x Competence
# Statistic :  55262.6559407583
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Older_% per Sector x Competence
# Age_Older_% per Sector x Competence Normality test: Not all groups are normally distributed.
# Age_Older_% per Sector x Competence Normality test:
#                          W   pval  normal
# Age_Older_% per Sector
# 34.09                  0.63  0.00   False
# 31.96                  0.64  0.00   False
# 18.94                  0.64  0.00   False
# 48.82                  0.64  0.00   False
# 47.62                  0.63  0.00   False
# 53.11                  0.63  0.00   False
# 53.92                  0.63  0.00   False
# 46.13                  0.64  0.00   False
# 52.94                  0.63  0.00   False
# 46.68                  0.64  0.00   False
# 32.76                  0.64  0.00   False
# 38.94                  0.64  0.00   False
# 49.32                  0.64  0.00   False
# 58.33                  0.64  0.00   False
# 51.72                  0.64  0.00   False
# 35.69                  0.63  0.00   False
# 41.67                  0.64  0.00   False
# 53.28                  0.63  0.00   False
# 52.72                  0.62  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Older_% per Sector x Competence
# Age_Older_% per Sector x Competence Bartlett's test: All groups have equal variances.
# Age_Older_% per Sector x Competence Bartlett's test:
#            T   pval  equal_var
# bartlett 8.60  0.97    True
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence
# Independent Variable: Age_Younger_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger_% per Sector x Competence
# Statistic :  55262.6559407583
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger_% per Sector x Competence
# Age_Younger_% per Sector x Competence Normality test: Not all groups are normally distributed.
# Age_Younger_% per Sector x Competence Normality test:
#                            W   pval  normal
# Age_Younger_% per Sector
# 65.92                    0.63  0.00   False
# 67.83                    0.64  0.00   False
# 80.81                    0.64  0.00   False
# 51.18                    0.64  0.00   False
# 52.98                    0.63  0.00   False
# 46.89                    0.63  0.00   False
# 46.21                    0.63  0.00   False
# 53.73                    0.64  0.00   False
# 48.53                    0.63  0.00   False
# 53.14                    0.64  0.00   False
# 67.24                    0.64  0.00   False
# 60.55                    0.64  0.00   False
# 50.61                    0.64  0.00   False
# 44.44                    0.64  0.00   False
# 44.83                    0.64  0.00   False
# 64.26                    0.63  0.00   False
# 56.82                    0.64  0.00   False
# 46.72                    0.63  0.00   False
# 47.18                    0.62  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger_% per Sector x Competence
# Age_Younger_% per Sector x Competence Bartlett's test: All groups have equal variances.
# Age_Younger_% per Sector x Competence Bartlett's test:
#            T   pval  equal_var
# bartlett 8.60  0.97    True
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence
# Independent Variable: Interaction_Female_Older_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Older_% per Sector x Competence
# Statistic :  55262.6559407583
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Older_% per Sector x Competence
# Interaction_Female_Older_% per Sector x Competence Normality test: Not all groups are normally distributed.
# Interaction_Female_Older_% per Sector x Competence Normality test:
#                                         W   pval  normal
# Interaction_Female_Older_% per Sector
# 1470.63                               0.63  0.00   False
# 1366.56                               0.64  0.00   False
# 951.75                                0.64  0.00   False
# 3327.58                               0.64  0.00   False
# 595.24                                0.63  0.00   False
# 1307.08                               0.63  0.00   False
# 1224.73                               0.63  0.00   False
# 3888.45                               0.64  0.00   False
# 2569.20                               0.63  0.00   False
# 3040.16                               0.64  0.00   False
# 903.69                                0.64  0.00   False
# 2211.43                               0.64  0.00   False
# 1092.89                               0.64  0.00   False
# 1134.26                               0.64  0.00   False
# 1426.87                               0.64  0.00   False
# 1503.89                               0.63  0.00   False
# 2746.21                               0.64  0.00   False
# 2100.27                               0.63  0.00   False
# 1102.90                               0.62  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Older_% per Sector x Competence
# Interaction_Female_Older_% per Sector x Competence Bartlett's test: All groups have equal variances.
# Interaction_Female_Older_% per Sector x Competence Bartlett's test:
#            T   pval  equal_var
# bartlett 8.60  0.97    True
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence
# Independent Variable: Interaction_Female_Younger_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Younger_% per Sector x Competence
# Statistic :  55262.6559407583
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Younger_% per Sector x Competence
# Interaction_Female_Younger_% per Sector x Competence Normality test: Not all groups are normally distributed.
# Interaction_Female_Younger_% per Sector x Competence Normality test:
#                                           W   pval  normal
# Interaction_Female_Younger_% per Sector
# 2843.37                                 0.63  0.00   False
# 2900.09                                 0.64  0.00   False
# 4060.81                                 0.64  0.00   False
# 3487.87                                 0.64  0.00   False
# 662.20                                  0.63  0.00   False
# ...
# Age_Younger x Competence_Probability Normality test:
#               W   pval  normal
# Age_Younger
# 0           0.83  0.00   False
# 1           0.83  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger x Competence_Probability
# Age_Younger x Competence_Probability Bartlett's test: Not all groups have equal variances.
# Age_Younger x Competence_Probability Bartlett's test:
#            T   pval  equal_var
# bartlett 7.52  0.01    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence_Probability
# Independent Variable: Age_Older_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Older_% per Sector x Competence_Probability
# Statistic :  19515.777265063953
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Older_% per Sector x Competence_Probability
# Age_Older_% per Sector x Competence_Probability Normality test: Not all groups are normally distributed.
# Age_Older_% per Sector x Competence_Probability Normality test:
#                          W   pval  normal
# Age_Older_% per Sector
# 34.09                  0.83  0.00   False
# 31.96                  0.83  0.00   False
# 18.94                  0.83  0.00   False
# 48.82                  0.84  0.00   False
# 47.62                  0.83  0.00   False
# 53.11                  0.83  0.00   False
# 53.92                  0.82  0.00   False
# 46.13                  0.84  0.00   False
# 52.94                  0.83  0.00   False
# 46.68                  0.84  0.00   False
# 32.76                  0.84  0.00   False
# 38.94                  0.84  0.00   False
# 49.32                  0.84  0.00   False
# 58.33                  0.84  0.00   False
# 51.72                  0.84  0.00   False
# 35.69                  0.82  0.00   False
# 41.67                  0.83  0.00   False
# 53.28                  0.83  0.00   False
# 52.72                  0.82  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Older_% per Sector x Competence_Probability
# Age_Older_% per Sector x Competence_Probability Bartlett's test: Not all groups have equal variances.
# Age_Older_% per Sector x Competence_Probability Bartlett's test:
#             T   pval  equal_var
# bartlett 57.30  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence_Probability
# Independent Variable: Age_Younger_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger_% per Sector x Competence_Probability
# Statistic :  19515.777265063953
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger_% per Sector x Competence_Probability
# Age_Younger_% per Sector x Competence_Probability Normality test: Not all groups are normally distributed.
# Age_Younger_% per Sector x Competence_Probability Normality test:
#                            W   pval  normal
# Age_Younger_% per Sector
# 65.92                    0.83  0.00   False
# 67.83                    0.83  0.00   False
# 80.81                    0.83  0.00   False
# 51.18                    0.84  0.00   False
# 52.98                    0.83  0.00   False
# 46.89                    0.83  0.00   False
# 46.21                    0.82  0.00   False
# 53.73                    0.84  0.00   False
# 48.53                    0.83  0.00   False
# 53.14                    0.84  0.00   False
# 67.24                    0.84  0.00   False
# 60.55                    0.84  0.00   False
# 50.61                    0.84  0.00   False
# 44.44                    0.84  0.00   False
# 44.83                    0.84  0.00   False
# 64.26                    0.82  0.00   False
# 56.82                    0.83  0.00   False
# 46.72                    0.83  0.00   False
# 47.18                    0.82  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Age_Younger_% per Sector x Competence_Probability
# Age_Younger_% per Sector x Competence_Probability Bartlett's test: Not all groups have equal variances.
# Age_Younger_% per Sector x Competence_Probability Bartlett's test:
#             T   pval  equal_var
# bartlett 57.30  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence_Probability
# Independent Variable: Interaction_Female_Older_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Older_% per Sector x Competence_Probability
# Statistic :  19515.777265063953
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Older_% per Sector x Competence_Probability
# Interaction_Female_Older_% per Sector x Competence_Probability Normality test: Not all groups are normally distributed.
# Interaction_Female_Older_% per Sector x Competence_Probability Normality test:
#                                         W   pval  normal
# Interaction_Female_Older_% per Sector
# 1470.63                               0.83  0.00   False
# 1366.56                               0.83  0.00   False
# 951.75                                0.83  0.00   False
# 3327.58                               0.84  0.00   False
# 595.24                                0.83  0.00   False
# 1307.08                               0.83  0.00   False
# 1224.73                               0.82  0.00   False
# 3888.45                               0.84  0.00   False
# 2569.20                               0.83  0.00   False
# 3040.16                               0.84  0.00   False
# 903.69                                0.84  0.00   False
# 2211.43                               0.84  0.00   False
# 1092.89                               0.84  0.00   False
# 1134.26                               0.84  0.00   False
# 1426.87                               0.84  0.00   False
# 1503.89                               0.82  0.00   False
# 2746.21                               0.83  0.00   False
# 2100.27                               0.83  0.00   False
# 1102.90                               0.82  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Older_% per Sector x Competence_Probability
# Interaction_Female_Older_% per Sector x Competence_Probability Bartlett's test: Not all groups have equal variances.
# Interaction_Female_Older_% per Sector x Competence_Probability Bartlett's test:
#             T   pval  equal_var
# bartlett 57.30  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence_Probability
# Independent Variable: Interaction_Female_Younger_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Younger_% per Sector x Competence_Probability
# Statistic :  19515.777265063953
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Younger_% per Sector x Competence_Probability
# Interaction_Female_Younger_% per Sector x Competence_Probability Normality test: Not all groups are normally distributed.
# Interaction_Female_Younger_% per Sector x Competence_Probability Normality test:
#                                           W   pval  normal
# Interaction_Female_Younger_% per Sector
# 2843.37                                 0.83  0.00   False
# 2900.09                                 0.83  0.00   False
# 4060.81                                 0.83  0.00   False
# 3487.87                                 0.84  0.00   False
# 662.20                                  0.83  0.00   False
# 1154.06                                 0.83  0.00   False
# 1049.77                                 0.82  0.00   False
# 4529.66                                 0.84  0.00   False
# 2355.10                                 0.83  0.00   False
# 3460.74                                 0.84  0.00   False
# 1854.93                                 0.84  0.00   False
# 3438.42                                 0.84  0.00   False
# 1121.40                                 0.84  0.00   False
# 864.20                                  0.84  0.00   False
# 1236.62                                 0.84  0.00   False
# 2707.41                                 0.82  0.00   False
# 3744.83                                 0.83  0.00   False
# 1841.33                                 0.83  0.00   False
# 987.02                                  0.82  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Female_Younger_% per Sector x Competence_Probability
# Interaction_Female_Younger_% per Sector x Competence_Probability Bartlett's test: Not all groups have equal variances.
# Interaction_Female_Younger_% per Sector x Competence_Probability Bartlett's test:
#             T   pval  equal_var
# bartlett 57.30  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence_Probability
# Independent Variable: Interaction_Male_Older_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Male_Older_% per Sector x Competence_Probability
# Statistic :  19515.777265063953
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Male_Older_% per Sector x Competence_Probability
# Interaction_Male_Older_% per Sector x Competence_Probability Normality test: Not all groups are normally distributed.
# Interaction_Male_Older_% per Sector x Competence_Probability Normality test:
#                                       W   pval  normal
# Interaction_Male_Older_% per Sector
# 1938.77                             0.83  0.00   False
# 1829.74                             0.83  0.00   False
# 937.40                              0.83  0.00   False
# 1554.83                             0.84  0.00   False
# 4166.67                             0.83  0.00   False
# 4003.80                             0.83  0.00   False
# 4166.91                             0.82  0.00   False
# 721.04                              0.84  0.00   False
# 2724.91                             0.83  0.00   False
# 1627.74                             0.84  0.00   False
# 2372.18                             0.84  0.00   False
# 1673.25                             0.84  0.00   False
# 3839.21                             0.84  0.00   False
# 4699.07                             0.84  0.00   False
# 3745.54                             0.84  0.00   False
# 2065.43                             0.82  0.00   False
# 1420.45                             0.83  0.00   False
# 3228.20                             0.83  0.00   False
# 4169.11                             0.82  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Male_Older_% per Sector x Competence_Probability
# Interaction_Male_Older_% per Sector x Competence_Probability Bartlett's test: Not all groups have equal variances.
# Interaction_Male_Older_% per Sector x Competence_Probability Bartlett's test:
#             T   pval  equal_var
# bartlett 57.30  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Dependent Variable: Competence_Probability
# Independent Variable: Interaction_Male_Younger_% per Sector
#
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ================================================================================
# Anderson-Darling Test of Normality:
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Male_Younger_% per Sector x Competence_Probability
# Statistic :  19515.777265063953
# p-value :  [0.576 0.656 0.787 0.918 1.092]
#
#
# Anderson-Darling Test of Normality: The test was successful.
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# NORMALITY TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Male_Younger_% per Sector x Competence_Probability
# Interaction_Male_Younger_% per Sector x Competence_Probability Normality test: Not all groups are normally distributed.
# Interaction_Male_Younger_% per Sector x Competence_Probability Normality test:
#                                         W   pval  normal
# Interaction_Male_Younger_% per Sector
# 3748.49                               0.83  0.00   False
# 3883.05                               0.83  0.00   False
# 3999.59                               0.83  0.00   False
# 1629.72                               0.84  0.00   False
# 4635.42                               0.83  0.00   False
# 3535.06                               0.83  0.00   False
# 3571.64                               0.82  0.00   False
# 839.94                                0.84  0.00   False
# 2497.84                               0.83  0.00   False
# 1852.92                               0.84  0.00   False
# 4869.20                               0.84  0.00   False
# 2601.64                               0.84  0.00   False
# 3939.36                               0.84  0.00   False
# 3580.25                               0.84  0.00   False
# 3246.14                               0.84  0.00   False
# 3718.35                               0.82  0.00   False
# 1936.98                               0.83  0.00   False
# 2830.20                               0.83  0.00   False
# 3731.08                               0.82  0.00   False
# ~~~~~~~~~~~~~~~~~~~~
#
#
#
#
# ================================================================================
# BARTLETT'S TEST
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Interaction_Male_Younger_% per Sector x Competence_Probability
# Interaction_Male_Younger_% per Sector x Competence_Probability Bartlett's test: Not all groups have equal variances.
# Interaction_Male_Younger_% per Sector x Competence_Probability Bartlett's test:
#             T   pval  equal_var
# bartlett 57.30  0.00    False
# ~~~~~~~~~~~~~~~~~~~~
#
#
# CPU times: user 14.2 s, sys: 4.62 s, total: 18.8 s
# Wall time: 23.5 s

# %% [markdown]
# ## Correlation between IVs and Control Variables (Multicollinearity)

# %% [markdown]
# ### Categorical Gender Sectors

# %%
def run_corr_cat_gender_sectors(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    # Full chi-square
    expected, observed, full_chisqt = pg.chi2_independence(data=df, x=ivs_dummy[0], y=ivs_dummy[2])
    print('\n')
    print('+'*120)
    print(f'IV 1: {ivs_dummy[0]}\nIV 2: {ivs_dummy[2]}')
    print('\n')
    print('~' * 20)
    print('FULL CHI-SQUARE TEST:')
    print('-'*20)
    print(f'Observed Count:\n{observed}\n')
    print('-'*20)
    print(f'Expected Count:\n{expected}\n')
    print('-'*20)
    print(f'Chi-square:\n{full_chisqt.round(3)}\n')
    print('~' * 20)
    chi_to_save = pd.concat([pd.concat([observed, pd.DataFrame(expected)], axis='index'), full_chisqt], axis='index')
    chi_to_save.to_csv(f'{table_save_path}chi-square {df_name} - {ivs_dummy[0]} x {ivs_dummy[2]}.csv')
    chi_to_save.style.to_latex(f'{table_save_path}chi-square {df_name} - {ivs_dummy[0]} x {ivs_dummy[2]}.tex', hrules=True)

    # Chi-square
    chisqt = pd.crosstab(df[ivs_dummy[0]], df[ivs_dummy[2]])
    pearson_r, p_value, dof, expected = scipy.stats.chi2_contingency(chisqt)
    reject_H0 = p_value > alpha
    reject_H = p_value < alpha

    # if not reject_H0 and reject_H:
    #     print('\n')
    #     print('+'*120)
    #     print(f'IV 1: {ivs_dummy[0]}\nIV 2: {ivs_dummy[2]}\nNOT SIGNIFICANT at p-value: {p_value:.3f}!')
    #     print('\n')
    #     print('~' * 20)
    #     print(f"Pearsons's R: {pearson_r}.\np-value: {p_value:.3f}.\nDegree of freedom: {dof}.\nH0 Rejected: {reject_H0}\nH Rejected: {reject_H}")
    #     print('\n')
    # elif reject_H0 and not reject_H:
    print('\n')
    print('+'*120)
    print(f'IV 1: {ivs_dummy[0]}\nIV 2: {ivs_dummy[2]}')
    print('\n')
    print('~' * 20)
    print(f"Pearsons's R: {pearson_r}.\np-value: {p_value:.3f}.\nDegree of freedom: {dof}.\nH0 Rejected: {reject_H0}\nH Rejected: {reject_H}")
    print('-'*20)
    print(f'Observed Count:\n{chisqt}\n')
    print('-'*20)
    print(f'Expected Count:\n{expected}\n')
    print('~' * 20)

# %% [markdown]
# ### Categorical Age Sectors

# %%
def run_corr_cat_age_sectors(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    # Full chi-square
    expected, observed, full_chisqt = pg.chi2_independence(data=df, x=ivs_dummy[3], y=ivs_dummy[5])
    print('\n')
    print('+'*120)
    print(f'IV 1: {ivs_dummy[3]}\nIV 2: {ivs_dummy[5]}')
    print('\n')
    print('~' * 20)
    print('FULL CHI-SQUARE TEST:')
    print('-'*20)
    print(f'Observed Count:\n{observed}\n')
    print('-'*20)
    print(f'Expected Count:\n{expected}\n')
    print('-'*20)
    print(f'Chi-square:\n{full_chisqt.round(3)}\n')
    print('~' * 20)
    chi_to_save = pd.concat([pd.concat([observed, pd.DataFrame(expected)], axis='index'), full_chisqt], axis='index')
    chi_to_save.to_csv(f'{table_save_path}chi-square {df_name} - {ivs_dummy[3]} x {ivs_dummy[5]}.csv')
    chi_to_save.style.to_latex(f'{table_save_path}chi-square {df_name} - {ivs_dummy[3]} x {ivs_dummy[5]}.tex', hrules=True)

    # Chi-square
    chisqt = pd.crosstab(df[ivs_dummy[3]], df[ivs_dummy[5]])
    pearson_r, p_value, dof, expected = scipy.stats.chi2_contingency(chisqt)
    reject_H0 = p_value > alpha
    reject_H = p_value < alpha

    # if not reject_H0 and reject_H:
    #     print('\n')
    #     print('+'*120)
    #     print(f'IV 1: {ivs_dummy[3]}\nIV 2: {ivs_dummy[5]}\nNOT SIGNIFICANT at p-value: {p_value:.3f}!')
    #     print('\n')
    #     print('~' * 20)
    #     print(f"Pearsons's R: {pearson_r}.\np-value: {p_value:.3f}.\nDegree of freedom: {dof}.\nH0 Rejected: {reject_H0}\nH Rejected: {reject_H}")
    #     print('\n')
    # elif reject_H0 and not reject_H:
    print('\n')
    print('+'*120)
    print(f'IV 1: {ivs_dummy[3]}\nIV 2: {ivs_dummy[5]}')
    print('\n')
    print('~' * 20)
    print(f"Pearsons's R: {pearson_r}.\np-value: {p_value:.3f}.\nDegree of freedom: {dof}.\nH0 Rejected: {reject_H0}\nH Rejected: {reject_H}")
    print('-'*20)
    print(f'Observed Count:\n{chisqt}\n')
    print('-'*20)
    print(f'Expected Count:\n{expected}\n')
    print('~' * 20)

# %% [markdown]
# ### Categorical Gender and Age Sectors

# %%
def run_corr_cat_gender_and_age_sectors(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    for iv_gender_dummy, iv_age_dummy in tqdm_product(ivs_gender_dummy, ivs_age_dummy):
        # Full chi-square
        expected, observed, full_chisqt = pg.chi2_independence(data=df, x=iv_gender_dummy, y=iv_age_dummy)
        print('\n')
        print('+'*120)
        print(f'IV 1: {iv_gender_dummy}\nIV 2: {iv_age_dummy}')
        print('\n')
        print('~' * 20)
        print('FULL CHI-SQUARE TEST:')
        print('-'*20)
        print(f'Observed Count:\n{observed}\n')
        print('-'*20)
        print(f'Expected Count:\n{expected}\n')
        print('-'*20)
        print(f'Chi-square:\n{full_chisqt.round(3)}\n')
        print('~' * 20)
        chi_to_save = pd.concat([pd.concat([observed, pd.DataFrame(expected)], axis='index'), full_chisqt], axis='index')
        chi_to_save.to_csv(f'{table_save_path}chi-square {df_name} - {iv_gender_dummy} x {iv_age_dummy}.csv')
        chi_to_save.style.to_latex(f'{table_save_path}chi-square {df_name} - {iv_gender_dummy} x {iv_age_dummy}.tex', hrules=True)

        # Chi-square
        chisqt = pd.crosstab(df[iv_gender_dummy], df[iv_age_dummy])
        pearson_r, p_value, dof, expected = scipy.stats.chi2_contingency(chisqt)
        reject_H0 = p_value > alpha
        reject_H = p_value < alpha

        # if not reject_H0 and reject_H:
        #     print('\n')
        #     print('+'*120)
        #     print(f'IV 1: {iv_gender_dummy}\nIV 2: {iv_age_dummy}\nNOT SIGNIFICANT at p-value: {p_value:.3f}!')
        #     print('\n')
        #     print('~' * 20)
        #     print(f"Pearsons's R: {pearson_r}.\np-value: {p_value:.3f}.\nDegree of freedom: {dof}.\nH0 Rejected: {reject_H0}\nH Rejected: {reject_H}")
        #     print('\n')
        # elif reject_H0 and not reject_H:
        print('\n')
        print('+'*120)
        print(f'IV 1: {iv_gender_dummy}\nIV 2: {iv_age_dummy}')
        print('\n')
        print('~' * 20)
        print(f"Pearsons's R: {pearson_r}.\np-value: {p_value:.3f}.\nDegree of freedom: {dof}.\nH0 Rejected: {reject_H0}\nH Rejected: {reject_H}")
        print('-'*20)
        print(f'Observed Count:\n{chisqt}\n')
        print('-'*20)
        print(f'Expected Count:\n{expected}\n')
        print('~' * 20)

# %% [markdown]
# ### Binary Warmth and Competence

# %%
def run_corr_bi_warmth_and_competence(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    # Full chi-square
    expected, observed, full_chisqt = pg.chi2_independence(data=df, x=dvs[0], y=dvs[1])
    print('\n')
    print('+'*120)
    print(f'DV 1: {dvs[0]}\nDV 2: {dvs[1]}')
    print('\n')
    print('~' * 20)
    print('FULL CHI-SQUARE TEST:')
    print('-'*20)
    print(f'Observed Count:\n{observed}\n')
    print('-'*20)
    print(f'Expected Count:\n{expected}\n')
    print('-'*20)
    print(f'Chi-square:\n{full_chisqt.round(3)}\n')
    print('~' * 20)
    chi_to_save = pd.concat([pd.concat([observed, pd.DataFrame(expected)], axis='index'), full_chisqt], axis='index')
    chi_to_save.to_csv(f'{table_save_path}chi-square {df_name} - {dvs[0]} x {dvs[1]}.csv')
    chi_to_save.style.to_latex(f'{table_save_path}chi-square {df_name} - {dvs[0]} x {dvs[1]}.tex', hrules=True)

    # Chi-square
    chisqt = pd.crosstab(df[dvs[0]], df[dvs[1]])
    pearson_r, p_value, dof, expected = scipy.stats.chi2_contingency(chisqt)
    reject_H0 = p_value > alpha
    reject_H = p_value < alpha

    # if not reject_H0 and reject_H:
    #     print('\n')
    #     print('+'*120)
    #     print(f'IV 1: {dvs[0]}\nIV 2: {dvs[1]}\nNOT SIGNIFICANT at p-value: {p_value:.3f}!')
    #     print('\n')
    #     print('~' * 20)
    #     print(f"Pearsons's R: {pearson_r}.\np-value: {p_value:.3f}.\nDegree of freedom: {dof}.\nH0 Rejected: {reject_H0}\nH Rejected: {reject_H}")
    #     print('\n')
    # elif reject_H0 and not reject_H:
    print('\n')
    print('+'*120)
    print(f'DV 1: {dvs[0]}\nDV 2: {dvs[1]}')
    print('\n')
    print('~' * 20)
    print(f"Pearsons's R: {pearson_r}.\np-value: {p_value:.3f}.\nDegree of freedom: {dof}.\nH0 Rejected: {reject_H0}\nH Rejected: {reject_H}")
    print('-'*20)
    print(f'Observed Count:\n{chisqt}\n')
    print('-'*20)
    print(f'Expected Count:\n{expected}\n')
    print('~' * 20)

# %% [markdown]
# ### Categorical Language Requirement

# %%
def run_corr_cat_lang_req(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    # Full chi-square
    expected, observed, full_chisqt = pg.chi2_independence(data=df, x=controls[2], y=controls[3])
    print('\n')
    print('+'*120)
    print(f'Control 1: {controls[2]}\nControl 2: {controls[3]}')
    print('\n')
    print('~' * 20)
    print('FULL CHI-SQUARE TEST:')
    print('-'*20)
    print(f'Observed Count:\n{observed}\n')
    print('-'*20)
    print(f'Expected Count:\n{expected}\n')
    print('-'*20)
    print(f'Chi-square:\n{full_chisqt.round(3)}\n')
    print('~' * 20)
    chi_to_save = pd.concat([pd.concat([observed, pd.DataFrame(expected)], axis='index'), full_chisqt], axis='index')
    chi_to_save.to_csv(f'{table_save_path}chi-square {df_name} - {controls[2]} x {controls[3]}.csv')
    chi_to_save.style.to_latex(f'{table_save_path}chi-square {df_name} - {controls[2]} x {controls[3]}.tex', hrules=True)

    # Chi-square
    chisqt = pd.crosstab(df[controls[2]], df[controls[3]])
    pearson_r, p_value, dof, expected = scipy.stats.chi2_contingency(chisqt)
    reject_H0 = p_value > alpha
    reject_H = p_value < alpha

    # if not reject_H0 and reject_H:
    #     print('\n')
    #     print('+'*120)
    #     print(f'Control 1: {controls[2]}\nControl 2: {controls[3]}\nNOT SIGNIFICANT at p-value: {p_value:.3f}!')
    #     print('\n')
    #     print('~' * 20)
    #     print(f"Pearsons's R: {pearson_r}.\np-value: {p_value:.3f}.\nDegree of freedom: {dof}.\nH0 Rejected: {reject_H0}\nH Rejected: {reject_H}")
    #     print('\n')
    # elif reject_H0 and not reject_H:
    print('\n')
    print('+'*120)
    print(f'Control 1: {controls[2]}\nControl 2: {controls[3]}')
    print('\n')
    print('~' * 20)
    print(f"Pearsons's R: {pearson_r}.\np-value: {p_value:.3f}.\nDegree of freedom: {dof}.\nH0 Rejected: {reject_H0}\nH Rejected: {reject_H}")
    print('-'*20)
    print(f'Observed Count:\n{chisqt}\n')
    print('-'*20)
    print(f'Expected Count:\n{expected}\n')
    print('~' * 20)

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_corr_interactive(df_name):
        run_corr_cat_gender_sectors(df_name=df_name, df=dataframes[df_name])
        run_corr_cat_age_sectors(df_name=df_name, df=dataframes[df_name])
        run_corr_cat_gender_and_age_sectors(df_name=df_name, df=dataframes[df_name])
        run_corr_bi_warmth_and_competence(df_name=df_name, df=dataframes[df_name])
        run_corr_cat_lang_req(df_name=df_name, df=dataframes[df_name])
else:
    run_corr_cat_gender_sectors(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
    run_corr_cat_age_sectors(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
    run_corr_cat_gender_and_age_sectors(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
    run_corr_bi_warmth_and_competence(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
    run_corr_cat_lang_req(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Female
# IV 2: Gender_Male
#
#
# ~~~~~~~~~~~~~~~~~~~~
# FULL CHI-SQUARE TEST:
# --------------------
# Observed Count:
# Gender_Male        0         1
# Gender_Female
# 0             116458.50 112603.50
# 1              78091.50      0.50
#
# --------------------
# Expected Count:
# Gender_Male        0        1
# Gender_Female
# 0             145086.87 83975.13
# 1              49463.13 28628.87
#
# --------------------
# Chi-square:
#           test         lambda      chi2      dof  pval  cramer  power
# 0             pearson   1.00       60606.20 1.00  0.00   0.44   1.00
# 1        cressie-read   0.67       65228.69 1.00  0.00   0.46   1.00
# 2      log-likelihood   0.00       86180.91 1.00  0.00   0.53   1.00
# 3       freeman-tukey  -0.50      141246.37 1.00  0.00   0.68   1.00
# 4  mod-log-likelihood  -1.00      596612.64 1.00  0.00   1.39   1.00
# 5              neyman  -2.00  1639191811.74 1.00  0.00  73.05   1.00
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Female
# IV 2: Gender_Male
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pearsons's R: 60606.20433324059.
# p-value: 0.000.
# Degree of freedom: 1.
# H0 Rejected: False
# H Rejected: True
# --------------------
# Observed Count:
# Gender_Male       0       1
# Gender_Female
# 0              116458  112604
# 1               78092       0
#
# --------------------
# Expected Count:
# [[145086.86880197  83975.13119803]
#  [ 49463.13119803  28628.86880197]]
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Age_Older
# IV 2: Age_Younger
#
#
# ~~~~~~~~~~~~~~~~~~~~
# FULL CHI-SQUARE TEST:
# --------------------
# Observed Count:
# Age_Younger      0        1
# Age_Older
# 0           197512.50 46936.50
# 1            62704.50     0.50
#
# --------------------
# Expected Count:
# Age_Younger      0        1
# Age_Older
# 0           207094.11 37354.89
# 1            53122.89  9582.11
#
# --------------------
# Chi-square:
#           test         lambda     chi2      dof  pval  cramer  power
# 0             pearson   1.00      14210.34 1.00  0.00   0.21   1.00
# 1        cressie-read   0.67      16031.18 1.00  0.00   0.23   1.00
# 2      log-likelihood   0.00      23507.42 1.00  0.00   0.28   1.00
# 3       freeman-tukey  -0.50      42003.97 1.00  0.00   0.37   1.00
# 4  mod-log-likelihood  -1.00     173918.46 1.00  0.00   0.75   1.00
# 5              neyman  -2.00  183618531.32 1.00  0.00  24.45   1.00
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Age_Older
# IV 2: Age_Younger
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pearsons's R: 14210.338405478768.
# p-value: 0.000.
# Degree of freedom: 1.
# H0 Rejected: False
# H Rejected: True
# --------------------
# Observed Count:
# Age_Younger     0      1
# Age_Older
# 0            197512  46937
# 1             62705      0
#
# --------------------
# Expected Count:
# [[207094.11380936  37354.88619064]
#  [ 53122.88619064   9582.11380936]]
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#   0%|          | 0/9 [00:00<?, ?it/s]
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Female
# IV 2: Age_Older
#
#
# ~~~~~~~~~~~~~~~~~~~~
# FULL CHI-SQUARE TEST:
# --------------------
# Observed Count:
# Age_Older          0        1
# Gender_Female
# 0             166357.50 62704.50
# 1              78091.50     0.50
#
# --------------------
# Expected Count:
# Age_Older          0        1
# Gender_Female
# 0             182299.36 46762.64
# 1              62149.64 15942.36
#
# --------------------
# Chi-square:
#           test         lambda     chi2      dof  pval  cramer  power
# 0             pearson   1.00      26859.40 1.00  0.00   0.30   1.00
# 1        cressie-read   0.67      29768.10 1.00  0.00   0.31   1.00
# 2      log-likelihood   0.00      41993.30 1.00  0.00   0.37   1.00
# 3       freeman-tukey  -0.50      72820.09 1.00  0.00   0.49   1.00
# 4  mod-log-likelihood  -1.00     308188.02 1.00  0.00   1.00   1.00
# 5              neyman  -2.00  508294473.01 1.00  0.00  40.68   1.00
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Female
# IV 2: Age_Older
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pearsons's R: 26859.401916306026.
# p-value: 0.000.
# Degree of freedom: 1.
# H0 Rejected: False
# H Rejected: True
# --------------------
# Observed Count:
# Age_Older         0      1
# Gender_Female
# 0              166357  62705
# 1               78092      0
#
# --------------------
# Expected Count:
# [[182299.35744936  46762.64255064]
#  [ 62149.64255064  15942.35744936]]
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Female
# IV 2: Age_Mixed
#
#
# ~~~~~~~~~~~~~~~~~~~~
# FULL CHI-SQUARE TEST:
# --------------------
# Observed Count:
# Age_Mixed          0         1
# Gender_Female
# 0             109641.50 119420.50
# 1                  0.50  78091.50
#
# --------------------
# Expected Count:
# Age_Mixed         0         1
# Gender_Female
# 0             81766.20 147295.80
# 1             27875.80  50216.20
#
# --------------------
# Chi-square:
#           test         lambda      chi2      dof  pval  cramer  power
# 0             pearson   1.00       58126.95 1.00  0.00   0.43   1.00
# 1        cressie-read   0.67       62682.68 1.00  0.00   0.45   1.00
# 2      log-likelihood   0.00       83170.85 1.00  0.00   0.52   1.00
# 3       freeman-tukey  -0.50      136824.43 1.00  0.00   0.67   1.00
# 4  mod-log-likelihood  -1.00      578775.44 1.00  0.00   1.37   1.00
# 5              neyman  -2.00  1554088095.63 1.00  0.00  71.13   1.00
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Female
# IV 2: Age_Mixed
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pearsons's R: 58126.952636756636.
# p-value: 0.000.
# Degree of freedom: 1.
# H0 Rejected: False
# H Rejected: True
# --------------------
# Observed Count:
# Age_Mixed         0       1
# Gender_Female
# 0              109642  119420
# 1                   0   78092
#
# --------------------
# Expected Count:
# [[ 81766.20133223 147295.79866777]
#  [ 27875.79866777  50216.20133223]]
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Female
# IV 2: Age_Younger
#
#
# ~~~~~~~~~~~~~~~~~~~~
# FULL CHI-SQUARE TEST:
# --------------------
# Observed Count:
# Age_Younger        0        1
# Gender_Female
# 0             182125.50 46936.50
# 1              78091.50     0.50
#
# --------------------
# Expected Count:
# Age_Younger        0        1
# Gender_Female
# 0             194058.44 35003.56
# 1              66158.56 11933.44
#
# --------------------
# Chi-square:
#           test         lambda     chi2      dof  pval  cramer  power
# 0             pearson   1.00      18886.56 1.00  0.00   0.25   1.00
# 1        cressie-read   0.67      21098.20 1.00  0.00   0.26   1.00
# 2      log-likelihood   0.00      30309.94 1.00  0.00   0.31   1.00
# 3       freeman-tukey  -0.50      53346.94 1.00  0.00   0.42   1.00
# 4  mod-log-likelihood  -1.00     222737.23 1.00  0.00   0.85   1.00
# 5              neyman  -2.00  284795811.32 1.00  0.00  30.45   1.00
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Female
# IV 2: Age_Younger
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pearsons's R: 18886.56341575828.
# p-value: 0.000.
# Degree of freedom: 1.
# H0 Rejected: False
# H Rejected: True
# --------------------
# Observed Count:
# Age_Younger       0      1
# Gender_Female
# 0              182125  46937
# 1               78092      0
#
# --------------------
# Expected Count:
# [[194058.44121841  35003.55878159]
#  [ 66158.55878159  11933.44121841]]
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Mixed
# IV 2: Age_Older
#
#
# ~~~~~~~~~~~~~~~~~~~~
# FULL CHI-SQUARE TEST:
# --------------------
# Observed Count:
# Age_Older         0        1
# Gender_Mixed
# 0            140757.50 49938.50
# 1            103691.50 12766.50
#
# --------------------
# Expected Count:
# Age_Older         0        1
# Gender_Mixed
# 0            151765.72 38930.28
# 1             92683.28 23774.72
#
# --------------------
# Chi-square:
#           test         lambda   chi2    dof  pval  cramer  power
# 0             pearson   1.00  10315.75 1.00  0.00   0.18   1.00
# 1        cressie-read   0.67  10530.75 1.00  0.00   0.18   1.00
# 2      log-likelihood   0.00  11072.07 1.00  0.00   0.19   1.00
# 3       freeman-tukey  -0.50  11591.97 1.00  0.00   0.19   1.00
# 4  mod-log-likelihood  -1.00  12229.01 1.00  0.00   0.20   1.00
# 5              neyman  -2.00  13948.28 1.00  0.00   0.21   1.00
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Mixed
# IV 2: Age_Older
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pearsons's R: 10315.754658393325.
# p-value: 0.000.
# Degree of freedom: 1.
# H0 Rejected: False
# H Rejected: True
# --------------------
# Observed Count:
# Age_Older        0      1
# Gender_Mixed
# 0             140757  49939
# 1             103692  12766
#
# --------------------
# Expected Count:
# [[151765.71525684  38930.28474316]
#  [ 92683.28474316  23774.71525684]]
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Mixed
# IV 2: Age_Mixed
#
#
# ~~~~~~~~~~~~~~~~~~~~
# FULL CHI-SQUARE TEST:
# --------------------
# Observed Count:
# Age_Mixed        0         1
# Gender_Mixed
# 0            49939.50 140756.50
# 1            59702.50  56755.50
#
# --------------------
# Expected Count:
# Age_Mixed        0         1
# Gender_Mixed
# 0            68071.04 122624.96
# 1            41570.96  74887.04
#
# --------------------
# Chi-square:
#           test         lambda   chi2    dof  pval  cramer  power
# 0             pearson   1.00  19808.72 1.00  0.00   0.25   1.00
# 1        cressie-read   0.67  19716.37 1.00  0.00   0.25   1.00
# 2      log-likelihood   0.00  19637.21 1.00  0.00   0.25   1.00
# 3       freeman-tukey  -0.50  19668.01 1.00  0.00   0.25   1.00
# 4  mod-log-likelihood  -1.00  19774.97 1.00  0.00   0.25   1.00
# 5              neyman  -2.00  20217.58 1.00  0.00   0.26   1.00
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Mixed
# IV 2: Age_Mixed
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pearsons's R: 19808.717025232785.
# p-value: 0.000.
# Degree of freedom: 1.
# H0 Rejected: False
# H Rejected: True
# --------------------
# Observed Count:
# Age_Mixed       0       1
# Gender_Mixed
# 0             49939  140757
# 1             59703   56755
#
# --------------------
# Expected Count:
# [[ 68071.03548057 122624.96451943]
#  [ 41570.96451943  74887.03548057]]
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Mixed
# IV 2: Age_Younger
#
#
# ~~~~~~~~~~~~~~~~~~~~
# FULL CHI-SQUARE TEST:
# --------------------
# Observed Count:
# Age_Younger       0        1
# Gender_Mixed
# 0            190695.50     0.50
# 1             69521.50 46936.50
#
# --------------------
# Expected Count:
# Age_Younger       0        1
# Gender_Mixed
# 0            161555.25 29140.75
# 1             98661.75 17796.25
#
# --------------------
# Chi-square:
#           test         lambda      chi2      dof  pval  cramer  power
# 0             pearson   1.00       90717.94 1.00  0.00   0.54   1.00
# 1        cressie-read   0.67       90868.21 1.00  0.00   0.54   1.00
# 2      log-likelihood   0.00      105600.58 1.00  0.00   0.59   1.00
# 3       freeman-tukey  -0.50      158323.25 1.00  0.00   0.72   1.00
# 4  mod-log-likelihood  -1.00      620501.03 1.00  0.00   1.42   1.00
# 5              neyman  -2.00  1698343184.83 1.00  0.00  74.36   1.00
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Mixed
# IV 2: Age_Younger
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pearsons's R: 90717.94219885931.
# p-value: 0.000.
# Degree of freedom: 1.
# H0 Rejected: False
# H Rejected: True
# --------------------
# Observed Count:
# Age_Younger      0      1
# Gender_Mixed
# 0             190696      0
# 1              69521  46937
#
# --------------------
# Expected Count:
# [[161555.24926258  29140.75073742]
#  [ 98661.75073742  17796.24926258]]
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Male
# IV 2: Age_Older
#
#
# ~~~~~~~~~~~~~~~~~~~~
# FULL CHI-SQUARE TEST:
# --------------------
# Observed Count:
# Age_Older        0        1
# Gender_Male
# 0           181783.50 12766.50
# 1            62665.50 49938.50
#
# --------------------
# Expected Count:
# Age_Older        0        1
# Gender_Male
# 0           154832.93 39717.07
# 1            89616.07 22987.93
#
# --------------------
# Chi-square:
#           test         lambda   chi2    dof  pval  cramer  power
# 0             pearson   1.00  62680.01 1.00  0.00   0.45   1.00
# 1        cressie-read   0.67  61702.62 1.00  0.00   0.45   1.00
# 2      log-likelihood   0.00  62015.69 1.00  0.00   0.45   1.00
# 3       freeman-tukey  -0.50  64380.72 1.00  0.00   0.46   1.00
# 4  mod-log-likelihood  -1.00  68908.74 1.00  0.00   0.47   1.00
# 5              neyman  -2.00  87024.49 1.00  0.00   0.53   1.00
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Male
# IV 2: Age_Older
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pearsons's R: 62680.00649568823.
# p-value: 0.000.
# Degree of freedom: 1.
# H0 Rejected: False
# H Rejected: True
# --------------------
# Observed Count:
# Age_Older       0      1
# Gender_Male
# 0            181784  12766
# 1             62665  49939
#
# --------------------
# Expected Count:
# [[154832.9272938  39717.0727062]
#  [ 89616.0727062  22987.9272938]]
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Male
# IV 2: Age_Mixed
#
#
# ~~~~~~~~~~~~~~~~~~~~
# FULL CHI-SQUARE TEST:
# --------------------
# Observed Count:
# Age_Mixed       0         1
# Gender_Male
# 0           59703.50 134846.50
# 1           49938.50  62665.50
#
# --------------------
# Expected Count:
# Age_Mixed       0         1
# Gender_Male
# 0           69446.76 125103.24
# 1           40195.24  72408.76
#
# --------------------
# Chi-square:
#           test         lambda   chi2   dof  pval  cramer  power
# 0             pearson   1.00  5798.58 1.00  0.00   0.14   1.00
# 1        cressie-read   0.67  5776.11 1.00  0.00   0.14   1.00
# 2      log-likelihood   0.00  5740.96 1.00  0.00   0.14   1.00
# 3       freeman-tukey  -0.50  5722.91 1.00  0.00   0.14   1.00
# 4  mod-log-likelihood  -1.00  5711.81 1.00  0.00   0.14   1.00
# 5              neyman  -2.00  5709.89 1.00  0.00   0.14   1.00
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Male
# IV 2: Age_Mixed
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pearsons's R: 5798.583364604478.
# p-value: 0.000.
# Degree of freedom: 1.
# H0 Rejected: False
# H Rejected: True
# --------------------
# Observed Count:
# Age_Mixed      0       1
# Gender_Male
# 0            59703  134847
# 1            49939   62665
#
# --------------------
# Expected Count:
# [[ 69446.7631872 125103.2368128]
#  [ 40195.2368128  72408.7631872]]
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Male
# IV 2: Age_Younger
#
#
# ~~~~~~~~~~~~~~~~~~~~
# FULL CHI-SQUARE TEST:
# --------------------
# Observed Count:
# Age_Younger      0        1
# Gender_Male
# 0           147613.50 46936.50
# 1           112603.50     0.50
#
# --------------------
# Expected Count:
# Age_Younger      0        1
# Gender_Male
# 0           164820.31 29729.69
# 1            95396.69 17207.31
#
# --------------------
# Chi-square:
#           test         lambda     chi2      dof  pval  cramer  power
# 0             pearson   1.00      32065.14 1.00  0.00   0.32   1.00
# 1        cressie-read   0.67      34926.65 1.00  0.00   0.34   1.00
# 2      log-likelihood   0.00      47651.15 1.00  0.00   0.39   1.00
# 3       freeman-tukey  -0.50      80661.18 1.00  0.00   0.51   1.00
# 4  mod-log-likelihood  -1.00     337057.78 1.00  0.00   1.05   1.00
# 5              neyman  -2.00  592159530.72 1.00  0.00  43.91   1.00
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# IV 1: Gender_Male
# IV 2: Age_Younger
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pearsons's R: 32065.143026886515.
# p-value: 0.000.
# Degree of freedom: 1.
# H0 Rejected: False
# H Rejected: True
# --------------------
# Observed Count:
# Age_Younger     0      1
# Gender_Male
# 0            147613  46937
# 1            112604      0
#
# --------------------
# Expected Count:
# [[164820.309519  29729.690481]
#  [ 95396.690481  17207.309519]]
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DV 1: Warmth
# DV 2: Competence
#
#
# ~~~~~~~~~~~~~~~~~~~~
# FULL CHI-SQUARE TEST:
# --------------------
# Observed Count:
# Competence      0         1
# Warmth
# 0          108538.50 103339.50
# 1           39818.50  55457.50
#
# --------------------
# Expected Count:
# Competence      0         1
# Warmth
# 0          102338.19 109539.81
# 1           46018.81  49257.19
#
# --------------------
# Chi-square:
#           test         lambda   chi2   dof  pval  cramer  power
# 0             pearson   1.00  2342.48 1.00  0.00   0.09   1.00
# 1        cressie-read   0.67  2344.87 1.00  0.00   0.09   1.00
# 2      log-likelihood   0.00  2351.37 1.00  0.00   0.09   1.00
# 3       freeman-tukey  -0.50  2357.76 1.00  0.00   0.09   1.00
# 4  mod-log-likelihood  -1.00  2365.46 1.00  0.00   0.09   1.00
# 5              neyman  -2.00  2384.90 1.00  0.00   0.09   1.00
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# DV 1: Warmth
# DV 2: Competence
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pearsons's R: 2342.478433120727.
# p-value: 0.000.
# Degree of freedom: 1.
# H0 Rejected: False
# H Rejected: True
# --------------------
# Observed Count:
# Competence     0       1
# Warmth
# 0           108539  103339
# 1            39818   55458
#
# --------------------
# Expected Count:
# [[102338.1901131 109539.8098869]
#  [ 46018.8098869  49257.1901131]]
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Control 1: English Requirement in Job Ad_Yes
# Control 2: Dutch Requirement in Job Ad_Yes
#
#
# ~~~~~~~~~~~~~~~~~~~~
# FULL CHI-SQUARE TEST:
# --------------------
# Observed Count:
# Dutch Requirement in Job Ad_Yes        0        1
# English Requirement in Job Ad_Yes
# 0                                 280972.50 8679.50
# 1                                  16492.50 1009.50
#
# --------------------
# Expected Count:
# Dutch Requirement in Job Ad_Yes        0        1
# English Requirement in Job Ad_Yes
# 0                                 280515.09 9136.91
# 1                                  16949.91  552.09
#
# --------------------
# Chi-square:
#           test         lambda  chi2   dof  pval  cramer  power
# 0             pearson   1.00  414.95 1.00  0.00   0.04   1.00
# 1        cressie-read   0.67  387.29 1.00  0.00   0.04   1.00
# 2      log-likelihood   0.00  340.14 1.00  0.00   0.03   1.00
# 3       freeman-tukey  -0.50  310.72 1.00  0.00   0.03   1.00
# 4  mod-log-likelihood  -1.00  285.45 1.00  0.00   0.03   1.00
# 5              neyman  -2.00  244.79 1.00  0.00   0.03   1.00
#
# ~~~~~~~~~~~~~~~~~~~~
#
#
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# Control 1: English Requirement in Job Ad_Yes
# Control 2: Dutch Requirement in Job Ad_Yes
#
#
# ~~~~~~~~~~~~~~~~~~~~
# Pearsons's R: 414.9534670878676.
# p-value: 0.000.
# Degree of freedom: 1.
# H0 Rejected: False
# H Rejected: True
# --------------------
# Observed Count:
# Dutch Requirement in Job Ad_Yes       0      1
# English Requirement in Job Ad_Yes
# 0                                  280973  8679
# 1                                   16492  1010
#
# --------------------
# Expected Count:
# [[280515.09073624   9136.90926376]
#  [ 16949.90926376    552.09073624]]
#
# ~~~~~~~~~~~~~~~~~~~~
# CPU times: user 442 ms, sys: 132 ms, total: 573 ms
# Wall time: 886 ms

# %% [markdown]
# # VIF

# %%
# compute the vif for all given features
def compute_vif(df, considered_features):

    X = df[considered_features]
    # the calculation of variance inflation requires a constant
    X.insert(0, 'intercept', 1)

    # create dataframe to store vif values
    vif = pd.DataFrame()
    vif['Variable'] = X.columns
    vif['VIF'] = [variance_inflation_factor(X.values, i) for i in range(X.shape[1])]
    vif = vif.loc[vif['Variable']!='intercept']

    return vif

# %% [markdown]
# ### VIF for Percentage IVs

# %%
def run_vif_ivs_perc_controls(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    for iv_gender_perc, iv_age_perc in tqdm_product(ivs_gender_perc, ivs_age_perc):
        considered_features = [iv_gender_perc, iv_age_perc] + controls[:2]
        vif = compute_vif(df, considered_features)
        print(vif.sort_values('VIF', ascending=False))

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_vif_ivs_perc_controls_interactive(df_name):
        run_vif_ivs_perc_controls(df_name=df_name, df=dataframes[df_name])
else:
    run_vif_ivs_perc_controls(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#   0%|          | 0/4 [00:00<?, ?it/s]
#             Variable           VIF
# 3      % Sector per Workforce 1.03
# 2      Age_Older_% per Sector 1.02
# 1  Gender_Female_% per Sector 1.01
# 4   Job Description num_words 1.00
#             Variable           VIF
# 3      % Sector per Workforce 1.03
# 2    Age_Younger_% per Sector 1.02
# 1  Gender_Female_% per Sector 1.01
# 4   Job Description num_words 1.00
#            Variable           VIF
# 3     % Sector per Workforce 1.03
# 2     Age_Older_% per Sector 1.02
# 1   Gender_Male_% per Sector 1.01
# 4  Job Description num_words 1.00
#            Variable           VIF
# 3     % Sector per Workforce 1.03
# 2   Age_Younger_% per Sector 1.02
# 1   Gender_Male_% per Sector 1.01
# 4  Job Description num_words 1.00
# CPU times: user 6.8 s, sys: 479 ms, total: 7.28 s
# Wall time: 1.67 s

# %% [markdown]
# ### VIF for Categorical Dummy IVs

# %%
def run_vif_ivs_dummy(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    considered_features = ivs_dummy[:]
    vif = compute_vif(df, considered_features)
    print(vif.sort_values('VIF', ascending=False))

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_vif_ivs_dummy_interactive(df_name):
        run_vif_ivs_dummy(df_name=df_name, df=dataframes[df_name])
else:
    run_vif_ivs_dummy(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#      Variable          VIF
# 1  Gender_Female           inf
# 6    Age_Younger           inf
# 4      Age_Older 9758675847.02
# 3    Gender_Male 1012006085.47
# 5      Age_Mixed    1177254.53
# 2   Gender_Mixed     408868.81
# CPU times: user 3.09 s, sys: 408 ms, total: 3.5 s
# Wall time: 562 ms

# %%
def run_vif_ivs_dummy_no_mixed(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    considered_features = ivs_dummy[:]
    considered_features.remove('Age_Mixed')
    considered_features.remove('Gender_Mixed')
    vif = compute_vif(df, considered_features)
    print(vif.sort_values('VIF', ascending=False))

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_vif_ivs_dummy_no_mixed_interactive(df_name):
        run_vif_ivs_dummy_no_mixed(df_name=df_name, df=dataframes[df_name])
else:
    run_vif_ivs_dummy_no_mixed(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#      Variable     VIF
# 2    Gender_Male 1.79
# 1  Gender_Female 1.63
# 4    Age_Younger 1.45
# 3      Age_Older 1.31
# CPU times: user 1.61 s, sys: 99.4 ms, total: 1.71 s
# Wall time: 345 ms

# %%
def run_vif_num(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    considered_features = ['Gender_Num', 'Age_Num']
    vif = compute_vif(df, considered_features)
    print(vif.sort_values('VIF', ascending=False))

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_vif_num_interactive(df_name):
        run_vif_num(df_name=df_name, df=dataframes[df_name])
else:
    run_vif_num(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#     Variable   VIF
# 2     Age_Num 1.13
# 1  Gender_Num 1.13
# CPU times: user 646 ms, sys: 50.3 ms, total: 696 ms
# Wall time: 133 ms

# %%
def run_vif_ivs_dummy_genxage_controls(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    for iv_gender_dummy, iv_age_dummy in tqdm_product(ivs_gender_dummy, ivs_age_dummy):
        print('-'*20)
        print(f'VIF for {iv_gender_dummy} x {iv_age_dummy}')
        considered_features = [iv_gender_dummy, iv_age_dummy] + controls[:2]
        vif = compute_vif(df, considered_features)
        print(vif.sort_values('VIF', ascending=False))

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_vif_ivs_dummy_genxage_controls_interactive(df_name):
        run_vif_ivs_dummy_genxage_controls(df_name=df_name, df=dataframes[df_name])
else:
    run_vif_ivs_dummy_genxage_controls(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#   0%|          | 0/9 [00:00<?, ?it/s]
# --------------------
# VIF for Gender_Female x Age_Older
#            Variable           VIF
# 2                  Age_Older 1.15
# 1              Gender_Female 1.11
# 3     % Sector per Workforce 1.05
# 4  Job Description num_words 1.00
# --------------------
# VIF for Gender_Female x Age_Mixed
#            Variable           VIF
# 2                  Age_Mixed 1.36
# 1              Gender_Female 1.27
# 3     % Sector per Workforce 1.10
# 4  Job Description num_words 1.00
# --------------------
# VIF for Gender_Female x Age_Younger
#            Variable           VIF
# 2                Age_Younger 1.09
# 1              Gender_Female 1.07
# 3     % Sector per Workforce 1.02
# 4  Job Description num_words 1.00
# --------------------
# VIF for Gender_Mixed x Age_Older
#            Variable           VIF
# 3     % Sector per Workforce 1.15
# 1               Gender_Mixed 1.15
# 2                  Age_Older 1.06
# 4  Job Description num_words 1.00
# --------------------
# VIF for Gender_Mixed x Age_Mixed
#            Variable           VIF
# 3     % Sector per Workforce 1.31
# 1               Gender_Mixed 1.31
# 2                  Age_Mixed 1.24
# 4  Job Description num_words 1.00
# --------------------
# VIF for Gender_Mixed x Age_Younger
#            Variable           VIF
# 1               Gender_Mixed 1.86
# 2                Age_Younger 1.68
# 3     % Sector per Workforce 1.33
# 4  Job Description num_words 1.00
# --------------------
# VIF for Gender_Male x Age_Older
#            Variable           VIF
# 1                Gender_Male 1.34
# 2                  Age_Older 1.26
# 3     % Sector per Workforce 1.10
# 4  Job Description num_words 1.00
# --------------------
# VIF for Gender_Male x Age_Mixed
#            Variable           VIF
# 3     % Sector per Workforce 1.16
# 1                Gender_Male 1.10
# 2                  Age_Mixed 1.08
# 4  Job Description num_words 1.00
# --------------------
# VIF for Gender_Male x Age_Younger
#            Variable           VIF
# 1                Gender_Male 1.29
# 2                Age_Younger 1.19
# 3     % Sector per Workforce 1.17
# 4  Job Description num_words 1.00
# CPU times: user 13.2 s, sys: 1.74 s, total: 14.9 s
# Wall time: 2.6 s

# %%
def run_vif_ivs_dummy_controls(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    considered_features = ivs_dummy[:] + controls[:2]
    vif = compute_vif(df, considered_features)
    print(vif.sort_values('VIF', ascending=False))
    vif.to_csv(f'{table_save_path}vif {df_name} - {ivs_dummy} x Controls.csv')
    vif.style.to_latex(f'{table_save_path}vif {df_name} - {ivs_dummy} x Controls.tex', hrules=True)

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_vif_ivs_dummy_controls_interactive(df_name):
        run_vif_ivs_dummy_controls(df_name=df_name, df=dataframes[df_name])
else:
    run_vif_ivs_dummy_controls(df_name=list(dataframes.keys())[0], df=dataframes[list(dataframes.keys())[0]])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#            Variable                 VIF
# 6                Age_Younger 8685823775063.64
# 4                  Age_Older 4428318217670.10
# 3                Gender_Male  207486564574.44
# 1              Gender_Female    1332108662.69
# 2               Gender_Mixed      16076297.56
# 5                  Age_Mixed       8551293.10
# 7     % Sector per Workforce             1.40
# 8  Job Description num_words             1.00
# CPU times: user 5.08 s, sys: 483 ms, total: 5.56 s
# Wall time: 919 ms

# %%
def run_vif_ivs_dummy_no_mixed_controls(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    considered_features = ivs_dummy[:] + controls[:2]
    considered_features.remove('Age_Mixed')
    considered_features.remove('Gender_Mixed')
    vif = compute_vif(df, considered_features)
    print(vif.sort_values('VIF', ascending=False))
    vif.to_csv(f'{table_save_path}vif {df_name} - MIXED REMOVED {ivs_dummy} x Controls.csv')
    vif.style.to_latex(f'{table_save_path}vif {df_name} - MIXED REMOVED {ivs_dummy} x Controls.tex', hrules=True)

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_vif_ivs_dummy_no_mixed_controls_interactive(df_name):
        run_vif_ivs_dummy_no_mixed_controls(df_name=df_name, df=dataframes[df_name])
else:
    run_vif_ivs_dummy_no_mixed_controls(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#            Variable           VIF
# 2                Gender_Male 2.26
# 1              Gender_Female 1.94
# 4                Age_Younger 1.76
# 5     % Sector per Workforce 1.40
# 3                  Age_Older 1.34
# 6  Job Description num_words 1.00
# CPU times: user 3.37 s, sys: 340 ms, total: 3.71 s
# Wall time: 681 ms

# %%
def run_vif_ivs_num_controls(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    print('-'*20)
    print('VIF for Gender_Num x Age_Num')
    considered_features = ['Gender_Num', 'Age_Num'] + controls[:2]
    vif = compute_vif(df, considered_features)
    print(vif.sort_values('VIF', ascending=False))

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_vif_ivs_num_controls_interactive(df_name):
        run_vif_ivs_num_controls(df_name=df_name, df=dataframes[df_name])
else:
    run_vif_ivs_num_controls(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
# --------------------
# VIF for Gender_Num x Age_Num
#            Variable           VIF
# 1                 Gender_Num 1.16
# 2                    Age_Num 1.13
# 3     % Sector per Workforce 1.03
# 4  Job Description num_words 1.00
# CPU times: user 1.76 s, sys: 131 ms, total: 1.89 s
# Wall time: 340 ms

# %%
def run_vif_ivs_perc_controls(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    considered_features = ivs_perc[:] + controls[:2]
    vif = compute_vif(df, considered_features)
    print(vif.sort_values('VIF', ascending=False))
    vif.to_csv(f'{table_save_path}vif {df_name} - {ivs_perc} x Controls.csv')
    vif.style.to_latex(f'{table_save_path}vif {df_name} - {ivs_perc} x Controls.tex', hrules=True)

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_vif_ivs_perc_controls_interactive(df_name):
        run_vif_ivs_perc_controls(df_name=df_name, df=dataframes[df_name])
else:
    run_vif_ivs_perc_controls(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#             Variable             VIF
# 1  Gender_Female_% per Sector 73666.42
# 2    Gender_Male_% per Sector 73656.35
# 4    Age_Younger_% per Sector   211.78
# 3      Age_Older_% per Sector   211.33
# 5      % Sector per Workforce     1.16
# 6   Job Description num_words     1.01
# CPU times: user 3.56 s, sys: 226 ms, total: 3.79 s
# Wall time: 794 ms

# %%
def run_vif_ivs_dummy_and_perc_controls(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    considered_features = ivs_dummy_and_perc[:] + controls[:2]
    vif = compute_vif(df, considered_features)
    print(vif.sort_values('VIF', ascending=False))
    vif.to_csv(f'{table_save_path}vif {df_name} - {ivs_dummy_and_perc} x Controls.csv')
    vif.style.to_latex(f'{table_save_path}vif {df_name} - {ivs_dummy_and_perc} x Controls.tex', hrules=True)

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_vif_ivs_dummy_and_perc_controls_interactive(df_name):
        run_vif_ivs_dummy_and_perc_controls(df_name=df_name, df=dataframes[df_name])
else:
    run_vif_ivs_dummy_and_perc_controls(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#              Variable                  VIF
# 8                  Age_Younger 44152937523240.16
# 6                    Age_Older 12025633183899.86
# 3                  Gender_Male  1012499916225.38
# 1                Gender_Female    63990219131.57
# 7                    Age_Mixed      427558746.48
# 2                 Gender_Mixed       35098491.43
# 5     Gender_Male_% per Sector         140603.21
# 4   Gender_Female_% per Sector         129666.87
# 9       Age_Older_% per Sector            256.32
# 10    Age_Younger_% per Sector            235.30
# 11      % Sector per Workforce              1.93
# 12   Job Description num_words              1.01
# CPU times: user 13 s, sys: 1.04 s, total: 14.1 s
# Wall time: 2.74 s

# %%
def run_vif_ivs_dummy_and_perc_controls_no_mixed(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    considered_features = ivs_dummy_and_perc[:] + controls[:2]
    considered_features.remove('Age_Mixed')
    considered_features.remove('Gender_Mixed')
    vif = compute_vif(df, considered_features)
    print(vif.sort_values('VIF', ascending=False))
    vif.to_csv(f'{table_save_path}vif {df_name} - MIXED REMOVED {ivs_dummy_and_perc} x Controls.csv')
    vif.style.to_latex(f'{table_save_path}vif {df_name} - MIXED REMOVED {ivs_dummy_and_perc} x Controls.tex', hrules=True)

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_vif_ivs_dummy_and_perc_controls_no_mixed_interactive(df_name):
        run_vif_ivs_dummy_and_perc_controls_no_mixed(df_name=df_name, df=dataframes[df_name])
else:
    run_vif_ivs_dummy_and_perc_controls_no_mixed(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#              Variable              VIF
# 3   Gender_Female_% per Sector 152227.55
# 4     Gender_Male_% per Sector 150480.32
# 7       Age_Older_% per Sector    256.62
# 8     Age_Younger_% per Sector    237.10
# 1                Gender_Female     10.86
# 2                  Gender_Male      7.13
# 5                    Age_Older      4.37
# 6                  Age_Younger      2.85
# 9       % Sector per Workforce      1.93
# 10   Job Description num_words      1.01
# CPU times: user 9.13 s, sys: 872 ms, total: 10 s
# Wall time: 1.89 s

# %%
def run_vif_ivs_num_and_perc_controls(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    considered_features = ivs_num_and_perc[:] + controls[:2]
    vif = compute_vif(df, considered_features)
    print(vif.sort_values('VIF', ascending=False))
    vif.to_csv(f'{table_save_path}vif {df_name} - {ivs_dummy_and_perc} x Controls.csv')
    vif.style.to_latex(f'{table_save_path}vif {df_name} - {ivs_dummy_and_perc} x Controls.tex', hrules=True)

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_vif_ivs_num_and_perc_controls_interactive(df_name):
        run_vif_ivs_num_and_perc_controls(df_name=df_name, df=dataframes[df_name])
else:
    run_vif_ivs_num_and_perc_controls(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#             Variable             VIF
# 2  Gender_Female_% per Sector 92507.27
# 3    Gender_Male_% per Sector 91612.57
# 5      Age_Older_% per Sector   233.76
# 6    Age_Younger_% per Sector   219.06
# 1                  Gender_Num    15.23
# 4                     Age_Num     5.56
# 7      % Sector per Workforce     1.30
# 8   Job Description num_words     1.01
# CPU times: user 4.7 s, sys: 628 ms, total: 5.33 s
# Wall time: 942 ms

# %%
def run_vif_dvs(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    if df_name == 'df_manual':
        considered_features_list = [dvs]
    elif df_name == 'df_jobs':
        considered_features_list = [dvs, dvs_prob]

    for considered_features in considered_features_list:
        vif = compute_vif(df, considered_features)
        print(vif.sort_values('VIF', ascending=False))

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_vif_dvs_interactive(df_name):
        run_vif_dvs(df_name=df_name, df=dataframes[df_name])
else:
    run_vif_dvs(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#     Variable   VIF
# 1      Warmth 1.01
# 2  Competence 1.01
#           Variable         VIF
# 2  Competence_Probability 1.02
# 1      Warmth_Probability 1.02
# CPU times: user 1.37 s, sys: 131 ms, total: 1.5 s
# Wall time: 280 ms

# %%
def run_vif_controls(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    considered_features = controls[:2]
    vif = compute_vif(df, considered_features)
    print(vif.sort_values('VIF', ascending=False))
    vif.to_csv(f'{table_save_path}vif {df_name} - Controls.csv')
    vif.style.to_latex(f'{table_save_path}vif {df_name} - Controls.tex', hrules=True)

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_vif_controls_interactive(df_name):
        run_vif_controls(df_name=df_name, df=dataframes[df_name])
else:
    run_vif_controls(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
#            Variable           VIF
# 2  Job Description num_words 1.00
# 1     % Sector per Workforce 1.00
# CPU times: user 611 ms, sys: 52.9 ms, total: 664 ms
# Wall time: 110 ms

# %% [markdown]
# # Double LASSO Regression

# %% [markdown]
# ### Double LASSO Regression for Controls x DVs

# %%
def run_double_lasso_dvs_controls(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    endog_names = dvs
    exog_names = controls[:2]

    endog = df[endog_names]
    exog = df[exog_names]
    constant = sm.add_constant(exog)

    lasso = Lasso(alpha=0.1)
    lasso.fit(constant, endog)
    print('Estimate coefficients for Lasso')
    for i, name in enumerate(exog_names):
        print(f'{name}: {lasso.coef_[i]}')

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_double_lasso_dvs_controls_interactive(df_name):
        run_double_lasso_dvs_controls(df_name=df_name, df=dataframes[df_name])
else:
    run_double_lasso_dvs_controls(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
# Estimate coefficients for Lasso
# % Sector per Workforce: [0.        0.        0.0086891]
# Job Description num_words: [0.         0.         0.00910675]
# CPU times: user 289 ms, sys: 87.7 ms, total: 376 ms
# Wall time: 67.1 ms

# %% [markdown]
# ### Double LASSO Regression for Controls x IVs Percentage

# %%
def run_double_lasso_ivs_controls(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    for iv in ivs_perc:
        print(f'{"-"*20} {iv} {"-"*20}')
        endog_names = iv
        exog_names = controls[:2]

        endog = df[endog_names]
        exog = df[exog_names]
        constant = sm.add_constant(exog)

        lasso = Lasso(alpha=0.1)
        lasso.fit(constant, endog)
        print('Estimate coefficients for Lasso')
        for i, name in enumerate(exog_names):
            print(f'{name}: {lasso.coef_[i]}')

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_double_lasso_ivs_controls_interactive(df_name):
        run_double_lasso_ivs_controls(df_name=df_name, df=dataframes[df_name])
else:
    run_double_lasso_ivs_controls(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
# -------------------- Gender_Female_% per Sector --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: 0.18278866072755492
# -------------------- Gender_Male_% per Sector --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: -0.18090290187253508
# -------------------- Age_Older_% per Sector --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: -0.15846468613597195
# -------------------- Age_Younger_% per Sector --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: 0.16198829760689715
# CPU times: user 1.2 s, sys: 95.2 ms, total: 1.3 s
# Wall time: 243 ms

# %% [markdown]
# ### Double LASSO Regression for Controls x IVs Dummy

# %%
def run_double_lasso_ivs_dummy_controls(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    for iv in ivs_dummy:
        print(f'{"-"*20} {iv} {"-"*20}')
        endog_names = iv
        exog_names = controls[:2]

        endog = df[endog_names]
        exog = df[exog_names]
        constant = sm.add_constant(exog)

        lasso = Lasso(alpha=0.1)
        lasso.fit(constant, endog)
        print('Estimate coefficients for Lasso')
        for i, name in enumerate(exog_names):
            print(f'{name}: {lasso.coef_[i]}')

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_double_lasso_ivs_dummy_controls_interactive(df_name):
        run_double_lasso_ivs_dummy_controls(df_name=df_name, df=dataframes[df_name])
else:
    run_double_lasso_ivs_dummy_controls(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
# -------------------- Gender_Female --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: -0.0008096938965960975
# -------------------- Gender_Mixed --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: 0.01734856225336216
# -------------------- Gender_Male --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: -0.015238283314682622
# -------------------- Age_Older --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: -0.007475028912782448
# -------------------- Age_Mixed --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: 0.012660307278027822
# -------------------- Age_Younger --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: -0.0038844792938054528
# CPU times: user 1.32 s, sys: 165 ms, total: 1.48 s
# Wall time: 251 ms

# %% [markdown]
# ### Double LASSO Regression for Controls x IVs Dummy and Percentage

# %%
def run_double_lasso_ivs_dummy_and_perc_controls(df_name, df):
    print('\n')
    print('+'*120)
    print(f'{"="*50} RESULTS FOR {df_name} {"="*50}')

    for iv in ivs_dummy_and_perc:
        print(f'{"-"*20} {iv} {"-"*20}')
        endog_names = iv
        exog_names = controls[:2]

        endog = df[endog_names]
        exog = df[exog_names]
        constant = sm.add_constant(exog)

        lasso = Lasso(alpha=0.1)
        lasso.fit(constant, endog)
        print('Estimate coefficients for Lasso')
        for i, name in enumerate(exog_names):
            print(f'{name}: {lasso.coef_[i]}')

# %%
# %%time
if len(dataframes) > 1:
    @interact(df_name=dataframes.keys())
    def run_double_lasso_ivs_dummy_and_perc_controls_interactive(df_name):
        run_double_lasso_ivs_dummy_and_perc_controls(df_name=df_name, df=dataframes[df_name])
else:
    run_double_lasso_ivs_dummy_and_perc_controls(df_name=list(dataframes.keys())[0], df=list(dataframes.values())[0])
# Out:
# ++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++++
# ================================================== RESULTS FOR df_jobs ==================================================
# -------------------- Gender_Female --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: -0.0008096938965960975
# -------------------- Gender_Mixed --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: 0.01734856225336216
# -------------------- Gender_Male --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: -0.015238283314682622
# -------------------- Gender_Female_% per Sector --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: 0.18278866072755492
# -------------------- Gender_Male_% per Sector --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: -0.18090290187253508
# -------------------- Age_Older --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: -0.007475028912782448
# -------------------- Age_Mixed --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: 0.012660307278027822
# -------------------- Age_Younger --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: -0.0038844792938054528
# -------------------- Age_Older_% per Sector --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: -0.15846468613597195
# -------------------- Age_Younger_% per Sector --------------------
# Estimate coefficients for Lasso
# % Sector per Workforce: 0.0
# Job Description num_words: 0.16198829760689715
# CPU times: user 2.27 s, sys: 328 ms, total: 2.6 s
# Wall time: 446 ms
